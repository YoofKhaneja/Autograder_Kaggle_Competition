# %% [markdown]
# # Trying a pipeline-based approach

# %%
pip install -U atom-ml

# %%
pip install catboost

# %%
import pandas as pd
import numpy as np

train_data = pd.read_csv("/content/drive/MyDrive/B565 Data/train.csv")
train_data.head()
# Out:
#         text_id                                          full_text  cohesion  \
# 0  0016926B079C  I think that students would benefit from learn...       3.5
# 1  0022683E9EA5  When a problem is a change you have to let it ...       2.5
# 2  00299B378633  Dear, Principal\n\nIf u change the school poli...       3.0
# 3  003885A45F42  The best time in life is when you become yours...       4.5
# 4  0049B1DF5CCC  Small act of kindness can impact in other peop...       2.5
#
#    syntax  vocabulary  phraseology  grammar  conventions
# 0     3.5         3.0          3.0      4.0          3.0
# 1     2.5         3.0          2.0      2.0          2.5
# 2     3.5         3.0          3.0      3.0          2.5
# 3     4.5         4.5          4.5      4.0          5.0
# 4     3.0         3.0          3.0      2.5          2.5

# %%
story = []
for i in train_data['full_text']:
    story.append(i.lower().replace("\n", "").strip())

# %%
story = np.array(story).reshape(-1, 1)
story.shape
# Out:
# (3911, 1)

# %%
cohesion = np.array(train_data['cohesion']).astype(float)
syntax = np.array(train_data['syntax']).astype(float)
vocabulary = np.array(train_data['vocabulary']).astype(float)
phraseology = np.array(train_data['phraseology']).astype(float)
grammar = np.array(train_data['grammar']).astype(float)
conventions = np.array(train_data['conventions']).astype(float)
conventions.shape
# Out:
# (3911,)

# %%
test_data = pd.read_csv("/content/drive/MyDrive/B565 Data/test.csv")
test_data
# Out:
#         text_id                                          full_text
# 0  0000C359D63E  when a person has no experience on a job their...
# 1  000BAD50D026  Do you think students would benefit from being...
# 2  00367BB2546B  Thomas Jefferson once states that "it is wonde...

# %%
story_pred = []
for i in test_data['full_text']:
    story_pred.append(i.lower().replace("\n", "").strip())
story_pred = np.array(story_pred).reshape(-1, 1)

# %%
from atom import ATOMRegressor

atom1 = ATOMRegressor(story, cohesion, test_size = 0.33, random_state = 42, verbose = 2)
atom2 = ATOMRegressor(story, syntax, test_size = 0.33, random_state = 42, verbose = 2)
atom3 = ATOMRegressor(story, vocabulary, test_size = 0.33, random_state = 42, verbose = 2)
atom4 = ATOMRegressor(story, phraseology, test_size = 0.33, random_state = 42, verbose = 2)
atom5 = ATOMRegressor(story, grammar, test_size = 0.33, random_state = 42, verbose = 2)
atom6 = ATOMRegressor(story, conventions, test_size = 0.33, random_state = 42, verbose = 2)
# Out:
# Woodwork may not support Python 3.7 in next non-bugfix release.
# Featuretools may not support Python 3.7 in next non-bugfix release.
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# Outlier values: 6 (0.1%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290
#
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# Outlier values: 23 (0.4%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290
#
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# Outlier values: 1 (0.0%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290
#
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# Outlier values: 8 (0.2%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290
#
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290
#
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# Outlier values: 9 (0.2%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290

# %%
atom1.dataset
# Out:
#                                                  corpus  target
# 0     the great artist michelangelo i thinking he is...     2.0
# 1     one of the things i want to acumplish in the f...     2.5
# 2     its always good to ask people how it feels or ...     3.0
# 3     in order for students to have a good experienc...     3.0
# 4     dear, principal,i will like to star in saying ...     3.5
# ...                                                 ...     ...
# 3906  i think an enjoyable educational activity for ...     4.0
# 3907  some people may say that oppocite but to start...     3.5
# 3908  "unles you try to do somthing beyond what you ...     2.5
# 3909  having activities after school are good ideas ...     4.0
# 3910  explain how small acts of kindness can have a ...     3.5
#
# [3911 rows x 2 columns]

# %%
atom1.tokenize(bigram_freq = 100)
atom2.tokenize(bigram_freq = 100)
atom3.tokenize(bigram_freq = 100)
atom4.tokenize(bigram_freq = 100)
atom5.tokenize(bigram_freq = 100)
atom6.tokenize(bigram_freq = 100)
# Out:
# Tokenizing the corpus...
#  --> Creating 2505 bigrams on 857871 locations.
# Tokenizing the corpus...
#  --> Creating 2505 bigrams on 857871 locations.
# Tokenizing the corpus...
#  --> Creating 2505 bigrams on 857871 locations.
# Tokenizing the corpus...
#  --> Creating 2505 bigrams on 857871 locations.
# Tokenizing the corpus...
#  --> Creating 2505 bigrams on 857871 locations.
# Tokenizing the corpus...
#  --> Creating 2505 bigrams on 857871 locations.

# %%
atom1.vectorize(strategy = 'tfidf')
atom2.vectorize(strategy = 'tfidf')
atom3.vectorize(strategy = 'tfidf')
atom4.vectorize(strategy = 'tfidf')
atom5.vectorize(strategy = 'tfidf')
atom6.vectorize(strategy = 'tfidf')
# Out:
# Fitting Vectorizer...
# Vectorizing the corpus...
# Fitting Vectorizer...
# Vectorizing the corpus...
# Fitting Vectorizer...
# Vectorizing the corpus...
# Fitting Vectorizer...
# Vectorizing the corpus...
# Fitting Vectorizer...
# Vectorizing the corpus...
# Fitting Vectorizer...
# Vectorizing the corpus...

# %%
atom1.available_models()
# Out:
#    acronym                          fullname                      estimator  \
# 0    Dummy                   Dummy Estimator                 DummyRegressor
# 1       GP                  Gaussian Process       GaussianProcessRegressor
# 2      OLS            Ordinary Least Squares               LinearRegression
# 3    Ridge                   Ridge Estimator                          Ridge
# 4    Lasso                  Lasso Regression                          Lasso
# 5       EN             ElasticNet Regression                     ElasticNet
# 6     Lars            Least Angle Regression                           Lars
# 7       BR                    Bayesian Ridge                  BayesianRidge
# 8      ARD  Automatic Relevant Determination                  ARDRegression
# 9    Huber                  Huber Regression                 HuberRegressor
# 10     KNN               K-Nearest Neighbors            KNeighborsRegressor
# 11     RNN          Radius Nearest Neighbors       RadiusNeighborsRegressor
# 12    Tree                     Decision Tree          DecisionTreeRegressor
# 13     Bag                           Bagging               BaggingRegressor
# 14      ET                       Extra-Trees            ExtraTreesRegressor
# 15      RF                     Random Forest          RandomForestRegressor
# 16    AdaB                          AdaBoost              AdaBoostRegressor
# 17     GBM         Gradient Boosting Machine      GradientBoostingRegressor
# 18    hGBM                           HistGBM  HistGradientBoostingRegressor
# 19     XGB                           XGBoost                   XGBRegressor
# 20     LGB                          LightGBM                  LGBMRegressor
# 21    CatB                          CatBoost              CatBoostRegressor
# 22    lSVM                        Linear SVM                      LinearSVR
# 23    kSVM                        Kernel SVM                            SVR
# 24      PA                Passive Aggressive     PassiveAggressiveRegressor
# 25     SGD       Stochastic Gradient Descent                   SGDRegressor
# 26     MLP            Multi-layer Perceptron                   MLPRegressor
#
#                                                module needs_scaling  \
# 0                                       sklearn.dummy         False
# 1                       sklearn.gaussian_process._gpr         False
# 2                          sklearn.linear_model._base          True
# 3                         sklearn.linear_model._ridge          True
# 4            sklearn.linear_model._coordinate_descent          True
# 5            sklearn.linear_model._coordinate_descent          True
# 6                   sklearn.linear_model._least_angle          True
# 7                         sklearn.linear_model._bayes          True
# 8                         sklearn.linear_model._bayes          True
# 9                         sklearn.linear_model._huber          True
# 10                      sklearn.neighbors._regression          True
# 11                      sklearn.neighbors._regression          True
# 12                              sklearn.tree._classes         False
# 13                          sklearn.ensemble._bagging         False
# 14                           sklearn.ensemble._forest         False
# 15                           sklearn.ensemble._forest         False
# 16                  sklearn.ensemble._weight_boosting         False
# 17                               sklearn.ensemble._gb         False
# 18  sklearn.ensemble._hist_gradient_boosting.gradi...         False
# 19                                    xgboost.sklearn          True
# 20                                   lightgbm.sklearn          True
# 21                                      catboost.core          True
# 22                               sklearn.svm._classes          True
# 23                               sklearn.svm._classes          True
# 24           sklearn.linear_model._passive_aggressive          True
# 25          sklearn.linear_model._stochastic_gradient          True
# 26      sklearn.neural_network._multilayer_perceptron          True
#
#    accepts_sparse supports_gpu
# 0           False        False
# 1           False        False
# 2            True         True
# 3            True         True
# 4            True         True
# 5            True         True
# 6           False         True
# 7           False        False
# 8           False        False
# 9           False        False
# 10           True         True
# 11           True        False
# 12           True        False
# 13           True        False
# 14           True        False
# 15           True         True
# 16           True        False
# 17           True        False
# 18          False        False
# 19           True         True
# 20           True         True
# 21           True         True
# 22           True         True
# 23           True         True
# 24           True        False
# 25           True        False
# 26           True        False

# %%
atom1.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
atom2.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
atom3.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
atom4.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
atom5.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
atom6.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
# Out:
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for Decision Tree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.6777
# Time elapsed: 40.410s
# -------------------------------------------------
# Total time: 40.410s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0645
# Test evaluation --> neg_mean_squared_error: -0.3671
# Time elapsed: 57.503s
# -------------------------------------------------
# Total time: 57.503s
#
#
# Results for Extra-Trees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.3198
# Time elapsed: 5m:08s
# -------------------------------------------------
# Total time: 5m:08s
#
#
# Results for Random Forest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0474
# Test evaluation --> neg_mean_squared_error: -0.3346
# Time elapsed: 3m:40s
# -------------------------------------------------
# Total time: 3m:40s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.308
# Test evaluation --> neg_mean_squared_error: -0.3416
# Time elapsed: 47.435s
# -------------------------------------------------
# Total time: 47.435s
#
#
# Results for Gradient Boosting Machine:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.1963
# Test evaluation --> neg_mean_squared_error: -0.3207
# Time elapsed: 56.553s
# -------------------------------------------------
# Total time: 56.554s
#
#
# Final results ==================== >>
# Duration: 12m:10s
# -------------------------------------
# Decision Tree             --> neg_mean_squared_error: -0.6777 ~
# Bagging                   --> neg_mean_squared_error: -0.3671 ~
# Extra-Trees               --> neg_mean_squared_error: -0.3198 ~ !
# Random Forest             --> neg_mean_squared_error: -0.3346 ~
# AdaBoost                  --> neg_mean_squared_error: -0.3416 ~
# Gradient Boosting Machine --> neg_mean_squared_error: -0.3207 ~
#
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for Decision Tree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.6089
# Time elapsed: 42.623s
# -------------------------------------------------
# Total time: 42.625s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0626
# Test evaluation --> neg_mean_squared_error: -0.342
# Time elapsed: 1m:03s
# -------------------------------------------------
# Total time: 1m:03s
#
#
# Results for Extra-Trees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.3033
# Time elapsed: 5m:12s
# -------------------------------------------------
# Total time: 5m:12s
#
#
# Results for Random Forest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0446
# Test evaluation --> neg_mean_squared_error: -0.3161
# Time elapsed: 3m:46s
# -------------------------------------------------
# Total time: 3m:46s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.2878
# Test evaluation --> neg_mean_squared_error: -0.3349
# Time elapsed: 46.615s
# -------------------------------------------------
# Total time: 46.615s
#
#
# Results for Gradient Boosting Machine:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.1815
# Test evaluation --> neg_mean_squared_error: -0.3083
# Time elapsed: 1m:04s
# -------------------------------------------------
# Total time: 1m:04s
#
#
# Final results ==================== >>
# Duration: 12m:34s
# -------------------------------------
# Decision Tree             --> neg_mean_squared_error: -0.6089 ~
# Bagging                   --> neg_mean_squared_error: -0.342 ~
# Extra-Trees               --> neg_mean_squared_error: -0.3033 ~ !
# Random Forest             --> neg_mean_squared_error: -0.3161 ~
# AdaBoost                  --> neg_mean_squared_error: -0.3349 ~
# Gradient Boosting Machine --> neg_mean_squared_error: -0.3083 ~
#
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for Decision Tree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.5227
# Time elapsed: 41.498s
# -------------------------------------------------
# Total time: 41.498s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0511
# Test evaluation --> neg_mean_squared_error: -0.2709
# Time elapsed: 58.862s
# -------------------------------------------------
# Total time: 58.862s
#
#
# Results for Extra-Trees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.2446
# Time elapsed: 5m:06s
# -------------------------------------------------
# Total time: 5m:06s
#
#
# Results for Random Forest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0358
# Test evaluation --> neg_mean_squared_error: -0.2513
# Time elapsed: 3m:43s
# -------------------------------------------------
# Total time: 3m:43s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.2196
# Test evaluation --> neg_mean_squared_error: -0.2628
# Time elapsed: 52.191s
# -------------------------------------------------
# Total time: 52.192s
#
#
# Results for Gradient Boosting Machine:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.14
# Test evaluation --> neg_mean_squared_error: -0.2438
# Time elapsed: 56.067s
# -------------------------------------------------
# Total time: 56.068s
#
#
# Final results ==================== >>
# Duration: 12m:18s
# -------------------------------------
# Decision Tree             --> neg_mean_squared_error: -0.5227 ~
# Bagging                   --> neg_mean_squared_error: -0.2709 ~
# Extra-Trees               --> neg_mean_squared_error: -0.2446 ~
# Random Forest             --> neg_mean_squared_error: -0.2513 ~
# AdaBoost                  --> neg_mean_squared_error: -0.2628 ~
# Gradient Boosting Machine --> neg_mean_squared_error: -0.2438 ~ !
#
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for Decision Tree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.6329
# Time elapsed: 39.990s
# -------------------------------------------------
# Total time: 39.990s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.064
# Test evaluation --> neg_mean_squared_error: -0.3476
# Time elapsed: 55.803s
# -------------------------------------------------
# Total time: 55.803s
#
#
# Results for Extra-Trees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.3023
# Time elapsed: 5m:07s
# -------------------------------------------------
# Total time: 5m:07s
#
#
# Results for Random Forest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0453
# Test evaluation --> neg_mean_squared_error: -0.3141
# Time elapsed: 3m:49s
# -------------------------------------------------
# Total time: 3m:49s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.3008
# Test evaluation --> neg_mean_squared_error: -0.3334
# Time elapsed: 47.415s
# -------------------------------------------------
# Total time: 47.415s
#
#
# Results for Gradient Boosting Machine:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.1845
# Test evaluation --> neg_mean_squared_error: -0.3007
# Time elapsed: 58.444s
# -------------------------------------------------
# Total time: 58.444s
#
#
# Final results ==================== >>
# Duration: 12m:18s
# -------------------------------------
# Decision Tree             --> neg_mean_squared_error: -0.6329 ~
# Bagging                   --> neg_mean_squared_error: -0.3476 ~
# Extra-Trees               --> neg_mean_squared_error: -0.3023 ~
# Random Forest             --> neg_mean_squared_error: -0.3141 ~
# AdaBoost                  --> neg_mean_squared_error: -0.3334 ~
# Gradient Boosting Machine --> neg_mean_squared_error: -0.3007 ~ !
#
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for Decision Tree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.7413
# Time elapsed: 43.191s
# -------------------------------------------------
# Total time: 43.191s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0733
# Test evaluation --> neg_mean_squared_error: -0.4108
# Time elapsed: 1m:03s
# -------------------------------------------------
# Total time: 1m:03s
#
#
# Results for Extra-Trees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.3582
# Time elapsed: 5m:20s
# -------------------------------------------------
# Total time: 5m:20s
#
#
# Results for Random Forest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0525
# Test evaluation --> neg_mean_squared_error: -0.3693
# Time elapsed: 3m:56s
# -------------------------------------------------
# Total time: 3m:56s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.3571
# Test evaluation --> neg_mean_squared_error: -0.4046
# Time elapsed: 48.673s
# -------------------------------------------------
# Total time: 48.673s
#
#
# Results for Gradient Boosting Machine:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.2222
# Test evaluation --> neg_mean_squared_error: -0.3652
# Time elapsed: 57.828s
# -------------------------------------------------
# Total time: 57.828s
#
#
# Final results ==================== >>
# Duration: 12m:50s
# -------------------------------------
# Decision Tree             --> neg_mean_squared_error: -0.7413 ~
# Bagging                   --> neg_mean_squared_error: -0.4108 ~
# Extra-Trees               --> neg_mean_squared_error: -0.3582 ~ !
# Random Forest             --> neg_mean_squared_error: -0.3693 ~
# AdaBoost                  --> neg_mean_squared_error: -0.4046 ~
# Gradient Boosting Machine --> neg_mean_squared_error: -0.3652 ~
#
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for Decision Tree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.6963
# Time elapsed: 49.006s
# -------------------------------------------------
# Total time: 49.006s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.069
# Test evaluation --> neg_mean_squared_error: -0.3871
# Time elapsed: 59.803s
# -------------------------------------------------
# Total time: 59.803s
#
#
# Results for Extra-Trees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.3568
# Time elapsed: 5m:15s
# -------------------------------------------------
# Total time: 5m:15s
#
#
# Results for Random Forest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.05
# Test evaluation --> neg_mean_squared_error: -0.369
# Time elapsed: 3m:51s
# -------------------------------------------------
# Total time: 3m:51s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.3368
# Test evaluation --> neg_mean_squared_error: -0.3932
# Time elapsed: 47.248s
# -------------------------------------------------
# Total time: 47.249s
#
#
# Results for Gradient Boosting Machine:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.2131
# Test evaluation --> neg_mean_squared_error: -0.357
# Time elapsed: 1m:02s
# -------------------------------------------------
# Total time: 1m:02s
#
#
# Final results ==================== >>
# Duration: 12m:43s
# -------------------------------------
# Decision Tree             --> neg_mean_squared_error: -0.6963 ~
# Bagging                   --> neg_mean_squared_error: -0.3871 ~
# Extra-Trees               --> neg_mean_squared_error: -0.3568 ~ !
# Random Forest             --> neg_mean_squared_error: -0.369 ~
# AdaBoost                  --> neg_mean_squared_error: -0.3932 ~
# Gradient Boosting Machine --> neg_mean_squared_error: -0.357 ~

# %%
atom1.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                -0.644574                           -0.220837  -2.500000
# Bag                 -0.486628                           -0.171688  -2.050000
# ET                  -0.456147                           -0.160444  -1.950000
# RF                  -0.465837                           -0.164299  -2.040000
# AdaB                -0.468824                           -0.166629  -2.089450
# GBM                 -0.456029                           -0.160756  -1.960315
#
#       neg_mean_squared_error  neg_mean_squared_log_error        r2  \
# Tree               -0.677713                   -0.042077 -0.579238
# Bag                -0.367079                   -0.023280  0.144615
# ET                 -0.319848                   -0.020323  0.254677
# RF                 -0.334605                   -0.021288  0.220289
# AdaB               -0.341602                   -0.021808  0.203983
# GBM                -0.320718                   -0.020451  0.252647
#
#       neg_root_mean_squared_error
# Tree                    -0.823233
# Bag                     -0.605871
# ET                      -0.565551
# RF                      -0.578450
# AdaB                    -0.584467
# GBM                     -0.566320

# %%
atom2.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                -0.600775                           -0.214254  -3.000000
# Bag                 -0.473023                           -0.171868  -1.950000
# ET                  -0.445783                           -0.161819  -1.915000
# RF                  -0.456705                           -0.165654  -1.960000
# AdaB                -0.475105                           -0.174720  -2.057439
# GBM                 -0.447699                           -0.163016  -1.995969
#
#       neg_mean_squared_error  neg_mean_squared_log_error        r2  \
# Tree               -0.608915                   -0.039445 -0.473839
# Bag                -0.341996                   -0.022508  0.172221
# ET                 -0.303283                   -0.020081  0.265924
# RF                 -0.316071                   -0.020831  0.234971
# AdaB               -0.334906                   -0.022326  0.189382
# GBM                -0.308269                   -0.020419  0.253856
#
#       neg_root_mean_squared_error
# Tree                    -0.780330
# Bag                     -0.584804
# ET                      -0.550711
# RF                      -0.562202
# AdaB                    -0.578710
# GBM                     -0.555220

# %%
atom3.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                -0.543023                           -0.176660  -3.000000
# Bag                 -0.409109                           -0.136183  -1.950000
# ET                  -0.387756                           -0.129641  -1.940000
# RF                  -0.392105                           -0.130845  -1.955000
# AdaB                -0.396731                           -0.133347  -1.776540
# GBM                 -0.383607                           -0.128487  -1.857749
#
#       neg_mean_squared_error  neg_mean_squared_log_error        r2  \
# Tree               -0.522674                   -0.030122 -0.566469
# Bag                -0.270909                   -0.015972  0.188079
# ET                 -0.244641                   -0.014558  0.266806
# RF                 -0.251337                   -0.014899  0.246735
# AdaB               -0.262776                   -0.015618  0.212452
# GBM                -0.243849                   -0.014546  0.269179
#
#       neg_root_mean_squared_error
# Tree                    -0.722962
# Bag                     -0.520489
# ET                      -0.494611
# RF                      -0.501336
# AdaB                    -0.512617
# GBM                     -0.493810

# %%
atom4.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                -0.617054                           -0.211559  -2.500000
# Bag                 -0.479341                           -0.167103  -1.850000
# ET                  -0.448775                           -0.157119  -1.680000
# RF                  -0.455965                           -0.159472  -1.700000
# AdaB                -0.473447                           -0.167002  -1.754032
# GBM                 -0.448816                           -0.157375  -1.798041
#
#       neg_mean_squared_error  neg_mean_squared_log_error        r2  \
# Tree               -0.632946                   -0.039846 -0.487258
# Bag                -0.347614                   -0.021780  0.183197
# ET                 -0.302267                   -0.019070  0.289752
# RF                 -0.314063                   -0.019766  0.262035
# AdaB               -0.333396                   -0.021122  0.216605
# GBM                -0.300680                   -0.019060  0.293479
#
#       neg_root_mean_squared_error
# Tree                    -0.795579
# Bag                     -0.589588
# ET                      -0.549788
# RF                      -0.560413
# AdaB                    -0.577405
# GBM                     -0.548343

# %%
atom5.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                -0.666279                           -0.234355  -3.000000
# Bag                 -0.519496                           -0.184975  -2.100000
# ET                  -0.488190                           -0.174009  -2.120000
# RF                  -0.497481                           -0.177713  -1.980000
# AdaB                -0.526484                           -0.191827  -2.154859
# GBM                 -0.494726                           -0.177531  -2.180357
#
#       neg_mean_squared_error  neg_mean_squared_log_error        r2  \
# Tree               -0.741279                   -0.046944 -0.527741
# Bag                -0.410828                   -0.026087  0.153304
# ET                 -0.358170                   -0.022733  0.261829
# RF                 -0.369326                   -0.023476  0.238836
# AdaB               -0.404588                   -0.026221  0.166163
# GBM                -0.365160                   -0.023385  0.247422
#
#       neg_root_mean_squared_error
# Tree                    -0.860976
# Bag                     -0.640958
# ET                      -0.598473
# RF                      -0.607722
# AdaB                    -0.636072
# GBM                     -0.604285

# %%
atom6.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                -0.638372                           -0.221577  -2.500000
# Bag                 -0.498682                           -0.178031  -2.300000
# ET                  -0.482388                           -0.173484  -2.070000
# RF                  -0.489605                           -0.176308  -1.945000
# AdaB                -0.508908                           -0.186825  -2.138813
# GBM                 -0.484567                           -0.174907  -1.952277
#
#       neg_mean_squared_error  neg_mean_squared_log_error        r2  \
# Tree               -0.696318                   -0.043851 -0.516587
# Bag                -0.387109                   -0.024760  0.156874
# ET                 -0.356823                   -0.023022  0.222836
# RF                 -0.369017                   -0.023828  0.196278
# AdaB               -0.393158                   -0.025781  0.143698
# GBM                -0.357026                   -0.023158  0.222394
#
#       neg_root_mean_squared_error
# Tree                    -0.834457
# Bag                     -0.622180
# ET                      -0.597346
# RF                      -0.607467
# AdaB                    -0.627023
# GBM                     -0.597516
