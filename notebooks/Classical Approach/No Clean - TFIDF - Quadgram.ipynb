# %% [markdown]
# # Trying a pipeline-based approach

# %%
import pandas as pd
import numpy as np

train_data = pd.read_csv("/content/drive/MyDrive/B565 Data/train.csv")
train_data.head()
# Out:
#         text_id                                          full_text  cohesion  \
# 0  0016926B079C  I think that students would benefit from learn...       3.5
# 1  0022683E9EA5  When a problem is a change you have to let it ...       2.5
# 2  00299B378633  Dear, Principal\n\nIf u change the school poli...       3.0
# 3  003885A45F42  The best time in life is when you become yours...       4.5
# 4  0049B1DF5CCC  Small act of kindness can impact in other peop...       2.5
#
#    syntax  vocabulary  phraseology  grammar  conventions
# 0     3.5         3.0          3.0      4.0          3.0
# 1     2.5         3.0          2.0      2.0          2.5
# 2     3.5         3.0          3.0      3.0          2.5
# 3     4.5         4.5          4.5      4.0          5.0
# 4     3.0         3.0          3.0      2.5          2.5

# %%
story = []
for i in train_data['full_text']:
    story.append(i.lower().replace("\n", "").strip())

# %%
story = np.array(story).reshape(-1, 1)
story.shape
# Out:
# (3911, 1)

# %%
cohesion = np.array(train_data['cohesion']).astype(float)
syntax = np.array(train_data['syntax']).astype(float)
vocabulary = np.array(train_data['vocabulary']).astype(float)
phraseology = np.array(train_data['phraseology']).astype(float)
grammar = np.array(train_data['grammar']).astype(float)
conventions = np.array(train_data['conventions']).astype(float)
conventions.shape
# Out:
# (3911,)

# %%
test_data = pd.read_csv("/content/drive/MyDrive/B565 Data/test.csv")
test_data
# Out:
#         text_id                                          full_text
# 0  0000C359D63E  when a person has no experience on a job their...
# 1  000BAD50D026  Do you think students would benefit from being...
# 2  00367BB2546B  Thomas Jefferson once states that "it is wonde...

# %%
story_pred = []
for i in test_data['full_text']:
    story_pred.append(i.lower().replace("\n", "").strip())
story_pred = np.array(story_pred).reshape(-1, 1)

# %%
from atom import ATOMRegressor

atom1 = ATOMRegressor(story, cohesion, test_size = 0.33, random_state = 42, verbose = 2)
atom2 = ATOMRegressor(story, syntax, test_size = 0.33, random_state = 42, verbose = 2)
atom3 = ATOMRegressor(story, vocabulary, test_size = 0.33, random_state = 42, verbose = 2)
atom4 = ATOMRegressor(story, phraseology, test_size = 0.33, random_state = 42, verbose = 2)
atom5 = ATOMRegressor(story, grammar, test_size = 0.33, random_state = 42, verbose = 2)
atom6 = ATOMRegressor(story, conventions, test_size = 0.33, random_state = 42, verbose = 2)
# Out:
# Woodwork may not support Python 3.7 in next non-bugfix release.
# Featuretools may not support Python 3.7 in next non-bugfix release.
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# Outlier values: 6 (0.1%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290
#
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# Outlier values: 23 (0.4%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290
#
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# Outlier values: 1 (0.0%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290
#
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# Outlier values: 8 (0.2%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290
#
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290
#
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# Outlier values: 9 (0.2%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290

# %%
atom1.dataset
# Out:
#                                                  corpus  target
# 0     the great artist michelangelo i thinking he is...     2.0
# 1     one of the things i want to acumplish in the f...     2.5
# 2     its always good to ask people how it feels or ...     3.0
# 3     in order for students to have a good experienc...     3.0
# 4     dear, principal,i will like to star in saying ...     3.5
# ...                                                 ...     ...
# 3906  i think an enjoyable educational activity for ...     4.0
# 3907  some people may say that oppocite but to start...     3.5
# 3908  "unles you try to do somthing beyond what you ...     2.5
# 3909  having activities after school are good ideas ...     4.0
# 3910  explain how small acts of kindness can have a ...     3.5
#
# [3911 rows x 2 columns]

# %%
atom1.tokenize(quadgram_freq = 100)
atom2.tokenize(quadgram_freq = 100)
atom3.tokenize(quadgram_freq = 100)
atom4.tokenize(quadgram_freq = 100)
atom5.tokenize(quadgram_freq = 100)
atom6.tokenize(quadgram_freq = 100)
# Out:
# Tokenizing the corpus...
#  --> Creating 140 quadgrams on 22517 locations.
# Tokenizing the corpus...
#  --> Creating 140 quadgrams on 22517 locations.
# Tokenizing the corpus...
#  --> Creating 140 quadgrams on 22517 locations.
# Tokenizing the corpus...
#  --> Creating 140 quadgrams on 22517 locations.
# Tokenizing the corpus...
#  --> Creating 140 quadgrams on 22517 locations.
# Tokenizing the corpus...
#  --> Creating 140 quadgrams on 22517 locations.

# %%
atom1.vectorize(strategy = 'tfidf')
atom2.vectorize(strategy = 'tfidf')
atom3.vectorize(strategy = 'tfidf')
atom4.vectorize(strategy = 'tfidf')
atom5.vectorize(strategy = 'tfidf')
atom6.vectorize(strategy = 'tfidf')
# Out:
# Fitting Vectorizer...
# Vectorizing the corpus...
# Fitting Vectorizer...
# Vectorizing the corpus...
# Fitting Vectorizer...
# Vectorizing the corpus...
# Fitting Vectorizer...
# Vectorizing the corpus...
# Fitting Vectorizer...
# Vectorizing the corpus...
# Fitting Vectorizer...
# Vectorizing the corpus...

# %%
atom1.available_models()
# Out:
#    acronym                          fullname                      estimator  \
# 0    Dummy                   Dummy Estimator                 DummyRegressor
# 1       GP                  Gaussian Process       GaussianProcessRegressor
# 2      OLS            Ordinary Least Squares               LinearRegression
# 3    Ridge                   Ridge Estimator                          Ridge
# 4    Lasso                  Lasso Regression                          Lasso
# 5       EN             ElasticNet Regression                     ElasticNet
# 6     Lars            Least Angle Regression                           Lars
# 7       BR                    Bayesian Ridge                  BayesianRidge
# 8      ARD  Automatic Relevant Determination                  ARDRegression
# 9    Huber                  Huber Regression                 HuberRegressor
# 10     KNN               K-Nearest Neighbors            KNeighborsRegressor
# 11     RNN          Radius Nearest Neighbors       RadiusNeighborsRegressor
# 12    Tree                     Decision Tree          DecisionTreeRegressor
# 13     Bag                           Bagging               BaggingRegressor
# 14      ET                       Extra-Trees            ExtraTreesRegressor
# 15      RF                     Random Forest          RandomForestRegressor
# 16    AdaB                          AdaBoost              AdaBoostRegressor
# 17     GBM         Gradient Boosting Machine      GradientBoostingRegressor
# 18    hGBM                           HistGBM  HistGradientBoostingRegressor
# 19     XGB                           XGBoost                   XGBRegressor
# 20     LGB                          LightGBM                  LGBMRegressor
# 21    CatB                          CatBoost              CatBoostRegressor
# 22    lSVM                        Linear SVM                      LinearSVR
# 23    kSVM                        Kernel SVM                            SVR
# 24      PA                Passive Aggressive     PassiveAggressiveRegressor
# 25     SGD       Stochastic Gradient Descent                   SGDRegressor
# 26     MLP            Multi-layer Perceptron                   MLPRegressor
#
#                                                module needs_scaling  \
# 0                                       sklearn.dummy         False
# 1                       sklearn.gaussian_process._gpr         False
# 2                          sklearn.linear_model._base          True
# 3                         sklearn.linear_model._ridge          True
# 4            sklearn.linear_model._coordinate_descent          True
# 5            sklearn.linear_model._coordinate_descent          True
# 6                   sklearn.linear_model._least_angle          True
# 7                         sklearn.linear_model._bayes          True
# 8                         sklearn.linear_model._bayes          True
# 9                         sklearn.linear_model._huber          True
# 10                      sklearn.neighbors._regression          True
# 11                      sklearn.neighbors._regression          True
# 12                              sklearn.tree._classes         False
# 13                          sklearn.ensemble._bagging         False
# 14                           sklearn.ensemble._forest         False
# 15                           sklearn.ensemble._forest         False
# 16                  sklearn.ensemble._weight_boosting         False
# 17                               sklearn.ensemble._gb         False
# 18  sklearn.ensemble._hist_gradient_boosting.gradi...         False
# 19                                    xgboost.sklearn          True
# 20                                   lightgbm.sklearn          True
# 21                                      catboost.core          True
# 22                               sklearn.svm._classes          True
# 23                               sklearn.svm._classes          True
# 24           sklearn.linear_model._passive_aggressive          True
# 25          sklearn.linear_model._stochastic_gradient          True
# 26      sklearn.neural_network._multilayer_perceptron          True
#
#    accepts_sparse supports_gpu
# 0           False        False
# 1           False        False
# 2            True         True
# 3            True         True
# 4            True         True
# 5            True         True
# 6           False         True
# 7           False        False
# 8           False        False
# 9           False        False
# 10           True         True
# 11           True        False
# 12           True        False
# 13           True        False
# 14           True        False
# 15           True         True
# 16           True        False
# 17           True        False
# 18          False        False
# 19           True         True
# 20           True         True
# 21           True         True
# 22           True         True
# 23           True         True
# 24           True        False
# 25           True        False
# 26           True        False

# %%
atom1.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
atom2.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
atom3.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
atom4.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
atom5.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
atom6.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
# Out:
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for Decision Tree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.6657
# Time elapsed: 39.289s
# -------------------------------------------------
# Total time: 39.289s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0641
# Test evaluation --> neg_mean_squared_error: -0.3541
# Time elapsed: 42.767s
# -------------------------------------------------
# Total time: 42.768s
#
#
# Results for Extra-Trees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.3157
# Time elapsed: 3m:25s
# -------------------------------------------------
# Total time: 3m:25s
#
#
# Results for Random Forest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0462
# Test evaluation --> neg_mean_squared_error: -0.3254
# Time elapsed: 2m:31s
# -------------------------------------------------
# Total time: 2m:31s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.3016
# Test evaluation --> neg_mean_squared_error: -0.3323
# Time elapsed: 37.361s
# -------------------------------------------------
# Total time: 37.361s
#
#
# Results for Gradient Boosting Machine:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.1972
# Test evaluation --> neg_mean_squared_error: -0.3173
# Time elapsed: 45.157s
# -------------------------------------------------
# Total time: 45.157s
#
#
# Final results ==================== >>
# Duration: 8m:41s
# -------------------------------------
# Decision Tree             --> neg_mean_squared_error: -0.6657 ~
# Bagging                   --> neg_mean_squared_error: -0.3541 ~
# Extra-Trees               --> neg_mean_squared_error: -0.3157 ~ !
# Random Forest             --> neg_mean_squared_error: -0.3254 ~
# AdaBoost                  --> neg_mean_squared_error: -0.3323 ~
# Gradient Boosting Machine --> neg_mean_squared_error: -0.3173 ~
#
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for Decision Tree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.637
# Time elapsed: 32.980s
# -------------------------------------------------
# Total time: 32.980s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0623
# Test evaluation --> neg_mean_squared_error: -0.3428
# Time elapsed: 47.418s
# -------------------------------------------------
# Total time: 47.418s
#
#
# Results for Extra-Trees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.3031
# Time elapsed: 3m:29s
# -------------------------------------------------
# Total time: 3m:29s
#
#
# Results for Random Forest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.044
# Test evaluation --> neg_mean_squared_error: -0.3149
# Time elapsed: 2m:34s
# -------------------------------------------------
# Total time: 2m:34s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.2737
# Test evaluation --> neg_mean_squared_error: -0.3279
# Time elapsed: 37.792s
# -------------------------------------------------
# Total time: 37.792s
#
#
# Results for Gradient Boosting Machine:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.1833
# Test evaluation --> neg_mean_squared_error: -0.3029
# Time elapsed: 44.846s
# -------------------------------------------------
# Total time: 44.846s
#
#
# Final results ==================== >>
# Duration: 8m:46s
# -------------------------------------
# Decision Tree             --> neg_mean_squared_error: -0.637 ~
# Bagging                   --> neg_mean_squared_error: -0.3428 ~
# Extra-Trees               --> neg_mean_squared_error: -0.3031 ~
# Random Forest             --> neg_mean_squared_error: -0.3149 ~
# AdaBoost                  --> neg_mean_squared_error: -0.3279 ~
# Gradient Boosting Machine --> neg_mean_squared_error: -0.3029 ~ !
#
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for Decision Tree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.4924
# Time elapsed: 33.141s
# -------------------------------------------------
# Total time: 33.141s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0488
# Test evaluation --> neg_mean_squared_error: -0.2739
# Time elapsed: 49.169s
# -------------------------------------------------
# Total time: 49.169s
#
#
# Results for Extra-Trees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.2434
# Time elapsed: 3m:19s
# -------------------------------------------------
# Total time: 3m:19s
#
#
# Results for Random Forest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0346
# Test evaluation --> neg_mean_squared_error: -0.2517
# Time elapsed: 2m:23s
# -------------------------------------------------
# Total time: 2m:23s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.205
# Test evaluation --> neg_mean_squared_error: -0.2597
# Time elapsed: 42.906s
# -------------------------------------------------
# Total time: 42.906s
#
#
# Results for Gradient Boosting Machine:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.1418
# Test evaluation --> neg_mean_squared_error: -0.2473
# Time elapsed: 44.436s
# -------------------------------------------------
# Total time: 44.436s
#
#
# Final results ==================== >>
# Duration: 8m:31s
# -------------------------------------
# Decision Tree             --> neg_mean_squared_error: -0.4924 ~
# Bagging                   --> neg_mean_squared_error: -0.2739 ~
# Extra-Trees               --> neg_mean_squared_error: -0.2434 ~ !
# Random Forest             --> neg_mean_squared_error: -0.2517 ~
# AdaBoost                  --> neg_mean_squared_error: -0.2597 ~
# Gradient Boosting Machine --> neg_mean_squared_error: -0.2473 ~
#
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for Decision Tree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.6636
# Time elapsed: 32.726s
# -------------------------------------------------
# Total time: 32.727s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0629
# Test evaluation --> neg_mean_squared_error: -0.3352
# Time elapsed: 42.838s
# -------------------------------------------------
# Total time: 42.838s
#
#
# Results for Extra-Trees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.2944
# Time elapsed: 3m:24s
# -------------------------------------------------
# Total time: 3m:24s
#
#
# Results for Random Forest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0446
# Test evaluation --> neg_mean_squared_error: -0.3023
# Time elapsed: 2m:31s
# -------------------------------------------------
# Total time: 2m:31s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.2959
# Test evaluation --> neg_mean_squared_error: -0.3281
# Time elapsed: 41.320s
# -------------------------------------------------
# Total time: 41.320s
#
#
# Results for Gradient Boosting Machine:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.1876
# Test evaluation --> neg_mean_squared_error: -0.2895
# Time elapsed: 47.390s
# -------------------------------------------------
# Total time: 47.391s
#
#
# Final results ==================== >>
# Duration: 8m:39s
# -------------------------------------
# Decision Tree             --> neg_mean_squared_error: -0.6636 ~
# Bagging                   --> neg_mean_squared_error: -0.3352 ~
# Extra-Trees               --> neg_mean_squared_error: -0.2944 ~
# Random Forest             --> neg_mean_squared_error: -0.3023 ~
# AdaBoost                  --> neg_mean_squared_error: -0.3281 ~
# Gradient Boosting Machine --> neg_mean_squared_error: -0.2895 ~ !
#
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for Decision Tree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.7516
# Time elapsed: 32.874s
# -------------------------------------------------
# Total time: 32.875s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0744
# Test evaluation --> neg_mean_squared_error: -0.3935
# Time elapsed: 43.769s
# -------------------------------------------------
# Total time: 43.770s
#
#
# Results for Extra-Trees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.349
# Time elapsed: 3m:30s
# -------------------------------------------------
# Total time: 3m:30s
#
#
# Results for Random Forest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0522
# Test evaluation --> neg_mean_squared_error: -0.3547
# Time elapsed: 2m:31s
# -------------------------------------------------
# Total time: 2m:31s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.3487
# Test evaluation --> neg_mean_squared_error: -0.3885
# Time elapsed: 38.128s
# -------------------------------------------------
# Total time: 38.128s
#
#
# Results for Gradient Boosting Machine:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.217
# Test evaluation --> neg_mean_squared_error: -0.3512
# Time elapsed: 50.378s
# -------------------------------------------------
# Total time: 50.378s
#
#
# Final results ==================== >>
# Duration: 8m:46s
# -------------------------------------
# Decision Tree             --> neg_mean_squared_error: -0.7516 ~
# Bagging                   --> neg_mean_squared_error: -0.3935 ~
# Extra-Trees               --> neg_mean_squared_error: -0.349 ~ !
# Random Forest             --> neg_mean_squared_error: -0.3547 ~
# AdaBoost                  --> neg_mean_squared_error: -0.3885 ~
# Gradient Boosting Machine --> neg_mean_squared_error: -0.3512 ~
#
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for Decision Tree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.7029
# Time elapsed: 33.471s
# -------------------------------------------------
# Total time: 33.471s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0695
# Test evaluation --> neg_mean_squared_error: -0.3989
# Time elapsed: 43.467s
# -------------------------------------------------
# Total time: 43.467s
#
#
# Results for Extra-Trees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.3499
# Time elapsed: 3m:28s
# -------------------------------------------------
# Total time: 3m:28s
#
#
# Results for Random Forest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0491
# Test evaluation --> neg_mean_squared_error: -0.3668
# Time elapsed: 2m:33s
# -------------------------------------------------
# Total time: 2m:33s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.3169
# Test evaluation --> neg_mean_squared_error: -0.3764
# Time elapsed: 37.644s
# -------------------------------------------------
# Total time: 37.644s
#
#
# Results for Gradient Boosting Machine:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.213
# Test evaluation --> neg_mean_squared_error: -0.3453
# Time elapsed: 50.098s
# -------------------------------------------------
# Total time: 50.098s
#
#
# Final results ==================== >>
# Duration: 8m:46s
# -------------------------------------
# Decision Tree             --> neg_mean_squared_error: -0.7029 ~
# Bagging                   --> neg_mean_squared_error: -0.3989 ~
# Extra-Trees               --> neg_mean_squared_error: -0.3499 ~
# Random Forest             --> neg_mean_squared_error: -0.3668 ~
# AdaBoost                  --> neg_mean_squared_error: -0.3764 ~
# Gradient Boosting Machine --> neg_mean_squared_error: -0.3453 ~ !

# %%
atom1.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                -0.634496                           -0.217529  -2.500000
# Bag                 -0.476899                           -0.166728  -2.050000
# ET                  -0.453349                           -0.159193  -2.060000
# RF                  -0.458713                           -0.161096  -1.950000
# AdaB                -0.460475                           -0.162417  -1.861219
# GBM                 -0.455385                           -0.159819  -1.846675
#
#       neg_mean_squared_error  neg_mean_squared_log_error        r2  \
# Tree               -0.665698                   -0.042082 -0.551238
# Bag                -0.354140                   -0.022292  0.174768
# ET                 -0.315652                   -0.020010  0.264453
# RF                 -0.325377                   -0.020611  0.241792
# AdaB               -0.332299                   -0.021102  0.225662
# GBM                -0.317271                   -0.020094  0.260682
#
#       neg_root_mean_squared_error
# Tree                    -0.815903
# Bag                     -0.595096
# ET                      -0.561829
# RF                      -0.570418
# AdaB                    -0.576454
# GBM                     -0.563268

# %%
atom2.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                -0.605814                           -0.212880  -3.000000
# Bag                 -0.468876                           -0.170171  -2.050000
# ET                  -0.445093                           -0.161072  -1.955000
# RF                  -0.454585                           -0.164601  -1.850000
# AdaB                -0.465133                           -0.170755  -2.137664
# GBM                 -0.443803                           -0.160820  -1.808989
#
#       neg_mean_squared_error  neg_mean_squared_log_error        r2  \
# Tree               -0.637016                   -0.040737 -0.541855
# Bag                -0.342758                   -0.022588  0.170377
# ET                 -0.303053                   -0.019955  0.266480
# RF                 -0.314861                   -0.020718  0.237899
# AdaB               -0.327945                   -0.021810  0.206230
# GBM                -0.302865                   -0.019975  0.266934
#
#       neg_root_mean_squared_error
# Tree                    -0.798133
# Bag                     -0.585455
# ET                      -0.550502
# RF                      -0.561125
# AdaB                    -0.572665
# GBM                     -0.550332

# %%
atom3.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                -0.531395                           -0.174524  -2.500000
# Bag                 -0.410155                           -0.136219  -2.000000
# ET                  -0.385213                           -0.128151  -1.885000
# RF                  -0.393942                           -0.130854  -1.970000
# AdaB                -0.403270                           -0.135501  -2.039683
# GBM                 -0.389598                           -0.129762  -2.011416
#
#       neg_mean_squared_error  neg_mean_squared_log_error        r2  \
# Tree               -0.492442                   -0.028173 -0.475862
# Bag                -0.273942                   -0.016107  0.178989
# ET                 -0.243379                   -0.014379  0.270588
# RF                 -0.251689                   -0.014825  0.245683
# AdaB               -0.259726                   -0.015396  0.221593
# GBM                -0.247271                   -0.014608  0.258922
#
#       neg_root_mean_squared_error
# Tree                    -0.701742
# Bag                     -0.523395
# ET                      -0.493334
# RF                      -0.501686
# AdaB                    -0.509634
# GBM                     -0.497264

# %%
atom4.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                -0.633333                           -0.215953  -2.500000
# Bag                 -0.472868                           -0.163427  -2.100000
# ET                  -0.442039                           -0.153903  -1.605000
# RF                  -0.448341                           -0.155201  -1.855000
# AdaB                -0.466331                           -0.161792  -1.728477
# GBM                 -0.435729                           -0.151983  -1.630755
#
#       neg_mean_squared_error  neg_mean_squared_log_error        r2  \
# Tree               -0.663566                   -0.040966 -0.559207
# Bag                -0.335217                   -0.020808  0.212327
# ET                 -0.294372                   -0.018444  0.308303
# RF                 -0.302259                   -0.018781  0.289769
# AdaB               -0.328095                   -0.020457  0.229061
# GBM                -0.289469                   -0.018199  0.319824
#
#       neg_root_mean_squared_error
# Tree                    -0.814596
# Bag                     -0.578979
# ET                      -0.542560
# RF                      -0.549781
# AdaB                    -0.572796
# GBM                     -0.538023

# %%
atom5.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                -0.672093                           -0.234408  -2.500000
# Bag                 -0.502829                           -0.176712  -2.250000
# ET                  -0.480457                           -0.170090  -1.995000
# RF                  -0.482174                           -0.170969  -2.205000
# AdaB                -0.510356                           -0.185681  -2.266144
# GBM                 -0.477996                           -0.169993  -2.162893
#
#       neg_mean_squared_error  neg_mean_squared_log_error        r2  \
# Tree               -0.751550                   -0.047214 -0.548910
# Bag                -0.393452                   -0.024576  0.189115
# ET                 -0.349014                   -0.021959  0.280699
# RF                 -0.354655                   -0.022309  0.269073
# AdaB               -0.388533                   -0.025019  0.199253
# GBM                -0.351214                   -0.022213  0.276165
#
#       neg_root_mean_squared_error
# Tree                    -0.866920
# Bag                     -0.627257
# ET                      -0.590774
# RF                      -0.595529
# AdaB                    -0.623324
# GBM                     -0.592633

# %%
atom6.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                -0.653876                           -0.229873  -2.500000
# Bag                 -0.507403                           -0.181801  -2.150000
# ET                  -0.475058                           -0.170608  -2.210000
# RF                  -0.486512                           -0.175095  -2.085000
# AdaB                -0.494362                           -0.179764  -2.096509
# GBM                 -0.470892                           -0.169299  -1.916166
#
#       neg_mean_squared_error  neg_mean_squared_log_error        r2  \
# Tree               -0.702907                   -0.045173 -0.530939
# Bag                -0.398893                   -0.025550  0.131206
# ET                 -0.349931                   -0.022526  0.237847
# RF                 -0.366849                   -0.023644  0.200999
# AdaB               -0.376440                   -0.024554  0.180109
# GBM                -0.345297                   -0.022339  0.247940
#
#       neg_root_mean_squared_error
# Tree                    -0.838395
# Bag                     -0.631580
# ET                      -0.591549
# RF                      -0.605681
# AdaB                    -0.613547
# GBM                     -0.587620
