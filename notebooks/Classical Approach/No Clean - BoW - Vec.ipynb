# %% [markdown]
# # Trying a pipeline-based approach

# %%
import pandas as pd
import numpy as np

train_data = pd.read_csv("train.csv")
train_data.head()
# Out:
#         text_id                                          full_text  cohesion  \
# 0  0016926B079C  I think that students would benefit from learn...       3.5
# 1  0022683E9EA5  When a problem is a change you have to let it ...       2.5
# 2  00299B378633  Dear, Principal\n\nIf u change the school poli...       3.0
# 3  003885A45F42  The best time in life is when you become yours...       4.5
# 4  0049B1DF5CCC  Small act of kindness can impact in other peop...       2.5
#
#    syntax  vocabulary  phraseology  grammar  conventions
# 0     3.5         3.0          3.0      4.0          3.0
# 1     2.5         3.0          2.0      2.0          2.5
# 2     3.5         3.0          3.0      3.0          2.5
# 3     4.5         4.5          4.5      4.0          5.0
# 4     3.0         3.0          3.0      2.5          2.5

# %%
story = []
for i in train_data['full_text']:
    story.append(i.lower().replace("\n", "").strip())

# %%
story = np.array(story).reshape(-1, 1)
story.shape
# Out:
# (3911, 1)

# %%
cohesion = np.array(train_data['cohesion']).astype(float)
syntax = np.array(train_data['syntax']).astype(float)
vocabulary = np.array(train_data['vocabulary']).astype(float)
phraseology = np.array(train_data['phraseology']).astype(float)
grammar = np.array(train_data['grammar']).astype(float)
conventions = np.array(train_data['conventions']).astype(float)
conventions.shape
# Out:
# (3911,)

# %%
test_data = pd.read_csv("test.csv")
test_data
# Out:
#         text_id                                          full_text
# 0  0000C359D63E  when a person has no experience on a job their...
# 1  000BAD50D026  Do you think students would benefit from being...
# 2  00367BB2546B  Thomas Jefferson once states that "it is wonde...

# %%
story_pred = []
for i in test_data['full_text']:
    story_pred.append(i.lower().replace("\n", "").strip())
story_pred = np.array(story_pred).reshape(-1, 1)

# %%
from atom import ATOMRegressor

atom1 = ATOMRegressor(story, cohesion, test_size = 0.33, random_state = 42, verbose = 2)
atom2 = ATOMRegressor(story, syntax, test_size = 0.33, random_state = 42, verbose = 2)
atom3 = ATOMRegressor(story, vocabulary, test_size = 0.33, random_state = 42, verbose = 2)
atom4 = ATOMRegressor(story, phraseology, test_size = 0.33, random_state = 42, verbose = 2)
atom5 = ATOMRegressor(story, grammar, test_size = 0.33, random_state = 42, verbose = 2)
atom6 = ATOMRegressor(story, conventions, test_size = 0.33, random_state = 42, verbose = 2)
# Out:
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# Outlier values: 4 (0.1%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290
#
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# Outlier values: 17 (0.3%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290
#
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# Outlier values: 23 (0.4%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290
#
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# Outlier values: 3 (0.1%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290
#
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290
#
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# Outlier values: 8 (0.2%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290

# %%
atom1.dataset
# Out:
#                                                  corpus  target
# 0     i agreed that the greater of us lies and not i...     3.5
# 1     the most enjoyable educational activity would ...     3.0
# 2     people always argue when it comes to does posi...     3.0
# 3     i dont like becuase the student forget all inf...     3.0
# 4     a first impression is the key to succes, becau...     3.0
# ...                                                 ...     ...
# 3906  why does most people want multiple advice when...     3.5
# 3907  make sure you have your seat belts. that is th...     2.5
# 3908  people can check out books, shop and play game...     3.0
# 3909  doing projects at school is really fun when it...     4.0
# 3910  people say first impressions are almost imposs...     3.5
#
# [3911 rows x 2 columns]

# %%
atom1.tokenize()
atom2.tokenize()
atom3.tokenize()
atom4.tokenize()
atom5.tokenize()
atom6.tokenize()
# Out:
# Fitting Tokenizer...
# Tokenizing the corpus...
# Fitting Tokenizer...
# Tokenizing the corpus...
# Fitting Tokenizer...
# Tokenizing the corpus...
# Fitting Tokenizer...
# Tokenizing the corpus...
# Fitting Tokenizer...
# Tokenizing the corpus...
# Fitting Tokenizer...
# Tokenizing the corpus...

# %%
atom1.vectorize(strategy = 'bow')
atom2.vectorize(strategy = 'bow')
atom3.vectorize(strategy = 'bow')
atom4.vectorize(strategy = 'bow')
atom5.vectorize(strategy = 'bow')
atom6.vectorize(strategy = 'bow')
# Out:
# Fitting Vectorizer...
# Vectorizing the corpus...
# Fitting Vectorizer...
# Vectorizing the corpus...
# Fitting Vectorizer...
# Vectorizing the corpus...
# Fitting Vectorizer...
# Vectorizing the corpus...
# Fitting Vectorizer...
# Vectorizing the corpus...
# Fitting Vectorizer...
# Vectorizing the corpus...

# %%
atom1.available_models()
# Out:
#    acronym                            model                      estimator  \
# 0     AdaB                         AdaBoost              AdaBoostRegressor
# 1      ARD  AutomaticRelevanceDetermination                  ARDRegression
# 2      Bag                          Bagging               BaggingRegressor
# 3       BR                    BayesianRidge                  BayesianRidge
# 4     CatB                         CatBoost              CatBoostRegressor
# 5     Tree                     DecisionTree          DecisionTreeRegressor
# 6    Dummy                            Dummy                 DummyRegressor
# 7       EN                       ElasticNet                     ElasticNet
# 8    ETree                        ExtraTree             ExtraTreeRegressor
# 9       ET                       ExtraTrees            ExtraTreesRegressor
# 10      GP                  GaussianProcess       GaussianProcessRegressor
# 11     GBM                 GradientBoosting      GradientBoostingRegressor
# 12   Huber                  HuberRegression                 HuberRegressor
# 13    hGBM             HistGradientBoosting  HistGradientBoostingRegressor
# 14     KNN                KNearestNeighbors            KNeighborsRegressor
# 15   Lasso                            Lasso                          Lasso
# 16    Lars             LeastAngleRegression                           Lars
# 17     LGB                         LightGBM                  LGBMRegressor
# 18    lSVM                        LinearSVM                      LinearSVR
# 19     MLP             MultiLayerPerceptron                   MLPRegressor
# 20     OLS             OrdinaryLeastSquares               LinearRegression
# 21     OMP        OrthogonalMatchingPursuit      OrthogonalMatchingPursuit
# 22      PA                PassiveAggressive     PassiveAggressiveRegressor
# 23     RNN           RadiusNearestNeighbors       RadiusNeighborsRegressor
# 24      RF                     RandomForest          RandomForestRegressor
# 25   Ridge                            Ridge                          Ridge
# 26     SGD        StochasticGradientDescent                   SGDRegressor
# 27     SVM             SupportVectorMachine                            SVR
# 28     XGB                          XGBoost                   XGBRegressor
#
#                       module  needs_scaling  accepts_sparse  has_validation  \
# 0            sklearnensemble          False            True           False
# 1        sklearnlinear_model           True           False           False
# 2            sklearnensemble          False            True           False
# 3        sklearnlinear_model           True           False           False
# 4           catboostcatboost           True            True            True
# 5                sklearntree          False            True           False
# 6               sklearndummy          False           False           False
# 7        sklearnlinear_model           True            True           False
# 8                sklearntree          False            True           False
# 9            sklearnensemble          False            True           False
# 10   sklearngaussian_process          False           False           False
# 11           sklearnensemble          False            True           False
# 12       sklearnlinear_model           True           False           False
# 13           sklearnensemble          False           False           False
# 14          sklearnneighbors           True            True           False
# 15       sklearnlinear_model           True            True           False
# 16       sklearnlinear_model           True           False           False
# 17  lightgbmlightgbm.sklearn           True            True            True
# 18                sklearnsvm           True            True           False
# 19     sklearnneural_network           True            True            True
# 20       sklearnlinear_model           True            True           False
# 21       sklearnlinear_model           True           False           False
# 22       sklearnlinear_model           True            True            True
# 23          sklearnneighbors           True            True           False
# 24           sklearnensemble          False            True           False
# 25       sklearnlinear_model           True            True           False
# 26       sklearnlinear_model           True            True            True
# 27                sklearnsvm           True            True           False
# 28            xgboostxgboost           True            True            True
#
#             supports_engines
# 0                    sklearn
# 1                    sklearn
# 2                    sklearn
# 3                    sklearn
# 4                   catboost
# 5                    sklearn
# 6                    sklearn
# 7   sklearn, sklearnex, cuml
# 8                    sklearn
# 9                    sklearn
# 10                   sklearn
# 11                   sklearn
# 12                   sklearn
# 13                   sklearn
# 14  sklearn, sklearnex, cuml
# 15  sklearn, sklearnex, cuml
# 16                   sklearn
# 17                  lightgbm
# 18             sklearn, cuml
# 19                   sklearn
# 20  sklearn, sklearnex, cuml
# 21                   sklearn
# 22                   sklearn
# 23                   sklearn
# 24  sklearn, sklearnex, cuml
# 25  sklearn, sklearnex, cuml
# 26                   sklearn
# 27  sklearn, sklearnex, cuml
# 28                   xgboost

# %%
atom1.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
atom2.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
atom3.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
atom4.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
atom5.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
atom6.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
# Out:
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for DecisionTree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.6767
# Time elapsed: 19.075s
# -------------------------------------------------
# Total time: 19.075s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0638
# Test evaluation --> neg_mean_squared_error: -0.3808
# Time elapsed: 30.389s
# -------------------------------------------------
# Total time: 30.389s
#
#
# Results for ExtraTrees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.3304
# Time elapsed: 04m:12s
# -------------------------------------------------
# Total time: 04m:12s
#
#
# Results for RandomForest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0457
# Test evaluation --> neg_mean_squared_error: -0.3367
# Time elapsed: 02m:36s
# -------------------------------------------------
# Total time: 02m:36s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.3112
# Test evaluation --> neg_mean_squared_error: -0.3534
# Time elapsed: 25.920s
# -------------------------------------------------
# Total time: 25.920s
#
#
# Results for GradientBoosting:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.2071
# Test evaluation --> neg_mean_squared_error: -0.3256
# Time elapsed: 28.941s
# -------------------------------------------------
# Total time: 28.941s
#
#
# Final results ==================== >>
# Total time: 08m:32s
# -------------------------------------
# DecisionTree     --> neg_mean_squared_error: -0.6767 ~
# Bagging          --> neg_mean_squared_error: -0.3808 ~
# ExtraTrees       --> neg_mean_squared_error: -0.3304 ~
# RandomForest     --> neg_mean_squared_error: -0.3367 ~
# AdaBoost         --> neg_mean_squared_error: -0.3534 ~
# GradientBoosting --> neg_mean_squared_error: -0.3256 ~ !
#
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for DecisionTree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.6064
# Time elapsed: 22.865s
# -------------------------------------------------
# Total time: 22.865s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0588
# Test evaluation --> neg_mean_squared_error: -0.3423
# Time elapsed: 36.180s
# -------------------------------------------------
# Total time: 36.180s
#
#
# Results for ExtraTrees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.3028
# Time elapsed: 04m:46s
# -------------------------------------------------
# Total time: 04m:46s
#
#
# Results for RandomForest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0435
# Test evaluation --> neg_mean_squared_error: -0.3115
# Time elapsed: 02m:42s
# -------------------------------------------------
# Total time: 02m:42s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.3019
# Test evaluation --> neg_mean_squared_error: -0.3396
# Time elapsed: 25.866s
# -------------------------------------------------
# Total time: 25.866s
#
#
# Results for GradientBoosting:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.203
# Test evaluation --> neg_mean_squared_error: -0.3051
# Time elapsed: 32.081s
# -------------------------------------------------
# Total time: 32.081s
#
#
# Final results ==================== >>
# Total time: 09m:26s
# -------------------------------------
# DecisionTree     --> neg_mean_squared_error: -0.6064 ~
# Bagging          --> neg_mean_squared_error: -0.3423 ~
# ExtraTrees       --> neg_mean_squared_error: -0.3028 ~ !
# RandomForest     --> neg_mean_squared_error: -0.3115 ~
# AdaBoost         --> neg_mean_squared_error: -0.3396 ~
# GradientBoosting --> neg_mean_squared_error: -0.3051 ~
#
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for DecisionTree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.5035
# Time elapsed: 23.299s
# -------------------------------------------------
# Total time: 23.299s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0448
# Test evaluation --> neg_mean_squared_error: -0.2832
# Time elapsed: 32.577s
# -------------------------------------------------
# Total time: 32.577s
#
#
# Results for ExtraTrees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.2568
# Time elapsed: 04m:34s
# -------------------------------------------------
# Total time: 04m:34s
#
#
# Results for RandomForest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0335
# Test evaluation --> neg_mean_squared_error: -0.2656
# Time elapsed: 02m:38s
# -------------------------------------------------
# Total time: 02m:38s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.2158
# Test evaluation --> neg_mean_squared_error: -0.2753
# Time elapsed: 26.583s
# -------------------------------------------------
# Total time: 26.583s
#
#
# Results for GradientBoosting:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.1497
# Test evaluation --> neg_mean_squared_error: -0.2521
# Time elapsed: 28.390s
# -------------------------------------------------
# Total time: 28.390s
#
#
# Final results ==================== >>
# Total time: 09m:03s
# -------------------------------------
# DecisionTree     --> neg_mean_squared_error: -0.5035 ~
# Bagging          --> neg_mean_squared_error: -0.2832 ~
# ExtraTrees       --> neg_mean_squared_error: -0.2568 ~
# RandomForest     --> neg_mean_squared_error: -0.2656 ~
# AdaBoost         --> neg_mean_squared_error: -0.2753 ~
# GradientBoosting --> neg_mean_squared_error: -0.2521 ~ !
#
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for DecisionTree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.6254
# Time elapsed: 22.058s
# -------------------------------------------------
# Total time: 22.058s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0579
# Test evaluation --> neg_mean_squared_error: -0.3545
# Time elapsed: 34.961s
# -------------------------------------------------
# Total time: 34.961s
#
#
# Results for ExtraTrees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.3048
# Time elapsed: 04m:39s
# -------------------------------------------------
# Total time: 04m:39s
#
#
# Results for RandomForest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0436
# Test evaluation --> neg_mean_squared_error: -0.3181
# Time elapsed: 02m:39s
# -------------------------------------------------
# Total time: 02m:39s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.307
# Test evaluation --> neg_mean_squared_error: -0.3421
# Time elapsed: 24.940s
# -------------------------------------------------
# Total time: 24.940s
#
#
# Results for GradientBoosting:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.2005
# Test evaluation --> neg_mean_squared_error: -0.3032
# Time elapsed: 29.978s
# -------------------------------------------------
# Total time: 29.978s
#
#
# Final results ==================== >>
# Total time: 09m:09s
# -------------------------------------
# DecisionTree     --> neg_mean_squared_error: -0.6254 ~
# Bagging          --> neg_mean_squared_error: -0.3545 ~
# ExtraTrees       --> neg_mean_squared_error: -0.3048 ~
# RandomForest     --> neg_mean_squared_error: -0.3181 ~
# AdaBoost         --> neg_mean_squared_error: -0.3421 ~
# GradientBoosting --> neg_mean_squared_error: -0.3032 ~ !
#
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for DecisionTree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.7913
# Time elapsed: 23.731s
# -------------------------------------------------
# Total time: 23.731s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0716
# Test evaluation --> neg_mean_squared_error: -0.419
# Time elapsed: 34.725s
# -------------------------------------------------
# Total time: 34.725s
#
#
# Results for ExtraTrees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.3568
# Time elapsed: 04m:48s
# -------------------------------------------------
# Total time: 04m:48s
#
#
# Results for RandomForest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0523
# Test evaluation --> neg_mean_squared_error: -0.378
# Time elapsed: 02m:43s
# -------------------------------------------------
# Total time: 02m:43s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.3731
# Test evaluation --> neg_mean_squared_error: -0.4179
# Time elapsed: 25.367s
# -------------------------------------------------
# Total time: 25.367s
#
#
# Results for GradientBoosting:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.2374
# Test evaluation --> neg_mean_squared_error: -0.3566
# Time elapsed: 31.229s
# -------------------------------------------------
# Total time: 31.229s
#
#
# Final results ==================== >>
# Total time: 09m:26s
# -------------------------------------
# DecisionTree     --> neg_mean_squared_error: -0.7913 ~
# Bagging          --> neg_mean_squared_error: -0.419 ~
# ExtraTrees       --> neg_mean_squared_error: -0.3568 ~
# RandomForest     --> neg_mean_squared_error: -0.378 ~
# AdaBoost         --> neg_mean_squared_error: -0.4179 ~
# GradientBoosting --> neg_mean_squared_error: -0.3566 ~ !
#
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for DecisionTree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.7581
# Time elapsed: 24.281s
# -------------------------------------------------
# Total time: 24.281s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0678
# Test evaluation --> neg_mean_squared_error: -0.4173
# Time elapsed: 35.069s
# -------------------------------------------------
# Total time: 35.069s
#
#
# Results for ExtraTrees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.3602
# Time elapsed: 04m:55s
# -------------------------------------------------
# Total time: 04m:55s
#
#
# Results for RandomForest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0495
# Test evaluation --> neg_mean_squared_error: -0.375
# Time elapsed: 02m:47s
# -------------------------------------------------
# Total time: 02m:47s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.3431
# Test evaluation --> neg_mean_squared_error: -0.4014
# Time elapsed: 23.997s
# -------------------------------------------------
# Total time: 23.997s
#
#
# Results for GradientBoosting:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.2319
# Test evaluation --> neg_mean_squared_error: -0.3514
# Time elapsed: 29.438s
# -------------------------------------------------
# Total time: 29.438s
#
#
# Final results ==================== >>
# Total time: 09m:35s
# -------------------------------------
# DecisionTree     --> neg_mean_squared_error: -0.7581 ~
# Bagging          --> neg_mean_squared_error: -0.4173 ~
# ExtraTrees       --> neg_mean_squared_error: -0.3602 ~
# RandomForest     --> neg_mean_squared_error: -0.375 ~
# AdaBoost         --> neg_mean_squared_error: -0.4014 ~
# GradientBoosting --> neg_mean_squared_error: -0.3514 ~ !

# %%
atom1.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                  -0.6357                             -0.2182    -3.0000
# Bag                   -0.4994                             -0.1745    -1.9500
# ET                    -0.4652                             -0.1630    -1.9500
# RF                    -0.4701                             -0.1646    -1.9300
# AdaB                  -0.4848                             -0.1694    -2.1254
# GBM                   -0.4626                             -0.1629    -1.9249
#
#       neg_mean_squared_error      r2  neg_root_mean_squared_error
# Tree                 -0.6767 -0.5393                      -0.8226
# Bag                  -0.3808  0.1338                      -0.6171
# ET                   -0.3304  0.2485                      -0.5748
# RF                   -0.3367  0.2343                      -0.5802
# AdaB                 -0.3534  0.1961                      -0.5945
# GBM                  -0.3256  0.2594                      -0.5706

# %%
atom2.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                  -0.5926                             -0.2076    -3.0000
# Bag                   -0.4675                             -0.1671    -2.2000
# ET                    -0.4393                             -0.1578    -2.1250
# RF                    -0.4445                             -0.1594    -2.0700
# AdaB                  -0.4613                             -0.1694    -2.1317
# GBM                   -0.4409                             -0.1590    -2.0434
#
#       neg_mean_squared_error      r2  neg_root_mean_squared_error
# Tree                 -0.6064 -0.4638                      -0.7787
# Bag                  -0.3423  0.1737                      -0.5851
# ET                   -0.3028  0.2690                      -0.5503
# RF                   -0.3115  0.2482                      -0.5581
# AdaB                 -0.3396  0.1801                      -0.5828
# GBM                  -0.3051  0.2636                      -0.5523

# %%
atom3.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                  -0.5209                             -0.1685    -2.5000
# Bag                   -0.4137                             -0.1341    -2.2500
# ET                    -0.3900                             -0.1270    -2.0000
# RF                    -0.3980                             -0.1295    -2.1550
# AdaB                  -0.4046                             -0.1321    -2.1172
# GBM                   -0.3877                             -0.1268    -1.9163
#
#       neg_mean_squared_error      r2  neg_root_mean_squared_error
# Tree                 -0.5035 -0.4335                      -0.7096
# Bag                  -0.2832  0.1936                      -0.5322
# ET                   -0.2568  0.2689                      -0.5067
# RF                   -0.2656  0.2438                      -0.5153
# AdaB                 -0.2753  0.2160                      -0.5247
# GBM                  -0.2521  0.2821                      -0.5021

# %%
atom4.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                  -0.6182                             -0.2090    -2.5000
# Bag                   -0.4786                             -0.1645    -2.1500
# ET                    -0.4419                             -0.1527    -1.8000
# RF                    -0.4522                             -0.1560    -1.8400
# AdaB                  -0.4658                             -0.1613    -1.9466
# GBM                   -0.4412                             -0.1530    -1.9329
#
#       neg_mean_squared_error      r2  neg_root_mean_squared_error
# Tree                 -0.6254 -0.4652                      -0.7908
# Bag                  -0.3545  0.1693                      -0.5954
# ET                   -0.3048  0.2860                      -0.5521
# RF                   -0.3181  0.2547                      -0.5640
# AdaB                 -0.3421  0.1984                      -0.5849
# GBM                  -0.3032  0.2897                      -0.5506

# %%
atom5.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                  -0.6903                             -0.2415    -3.0000
# Bag                   -0.5261                             -0.1868    -2.1500
# ET                    -0.4887                             -0.1730    -1.9850
# RF                    -0.5044                             -0.1784    -2.0150
# AdaB                  -0.5279                             -0.1903    -2.0703
# GBM                   -0.4866                             -0.1741    -2.0890
#
#       neg_mean_squared_error      r2  neg_root_mean_squared_error
# Tree                 -0.7913 -0.6198                      -0.8895
# Bag                  -0.4190  0.1423                      -0.6473
# ET                   -0.3568  0.2695                      -0.5974
# RF                   -0.3780  0.2263                      -0.6148
# AdaB                 -0.4179  0.1446                      -0.6464
# GBM                  -0.3566  0.2701                      -0.5971

# %%
atom6.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                  -0.6822                             -0.2385    -2.5000
# Bag                   -0.5202                             -0.1832    -2.1500
# ET                    -0.4833                             -0.1727    -1.8800
# RF                    -0.4905                             -0.1750    -1.9400
# AdaB                  -0.5095                             -0.1838    -2.0764
# GBM                   -0.4771                             -0.1698    -2.0370
#
#       neg_mean_squared_error      r2  neg_root_mean_squared_error
# Tree                 -0.7581 -0.6329                      -0.8707
# Bag                  -0.4173  0.1013                      -0.6460
# ET                   -0.3602  0.2242                      -0.6002
# RF                   -0.3750  0.1923                      -0.6124
# AdaB                 -0.4014  0.1353                      -0.6336
# GBM                  -0.3514  0.2430                      -0.5928
