# %% [markdown]
# # Trying a pipeline-based approach

# %%
import pandas as pd
import numpy as np

train_data = pd.read_csv("train.csv")
train_data.head()
# Out:
#         text_id                                          full_text  cohesion  \
# 0  0016926B079C  I think that students would benefit from learn...       3.5
# 1  0022683E9EA5  When a problem is a change you have to let it ...       2.5
# 2  00299B378633  Dear, Principal\n\nIf u change the school poli...       3.0
# 3  003885A45F42  The best time in life is when you become yours...       4.5
# 4  0049B1DF5CCC  Small act of kindness can impact in other peop...       2.5
#
#    syntax  vocabulary  phraseology  grammar  conventions
# 0     3.5         3.0          3.0      4.0          3.0
# 1     2.5         3.0          2.0      2.0          2.5
# 2     3.5         3.0          3.0      3.0          2.5
# 3     4.5         4.5          4.5      4.0          5.0
# 4     3.0         3.0          3.0      2.5          2.5

# %%
story = []
for i in train_data['full_text']:
    story.append(i.lower().replace("\n", "").strip())

# %%
story = np.array(story).reshape(-1, 1)
story.shape
# Out:
# (3911, 1)

# %%
cohesion = np.array(train_data['cohesion']).astype(float)
syntax = np.array(train_data['syntax']).astype(float)
vocabulary = np.array(train_data['vocabulary']).astype(float)
phraseology = np.array(train_data['phraseology']).astype(float)
grammar = np.array(train_data['grammar']).astype(float)
conventions = np.array(train_data['conventions']).astype(float)
conventions.shape
# Out:
# (3911,)

# %%
test_data = pd.read_csv("test.csv")
test_data
# Out:
#         text_id                                          full_text
# 0  0000C359D63E  when a person has no experience on a job their...
# 1  000BAD50D026  Do you think students would benefit from being...
# 2  00367BB2546B  Thomas Jefferson once states that "it is wonde...

# %%
story_pred = []
for i in test_data['full_text']:
    story_pred.append(i.lower().replace("\n", "").strip())
story_pred = np.array(story_pred).reshape(-1, 1)

# %%
from atom import ATOMRegressor

atom1 = ATOMRegressor(story, cohesion, test_size = 0.33, random_state = 42, verbose = 2)
atom2 = ATOMRegressor(story, syntax, test_size = 0.33, random_state = 42, verbose = 2)
atom3 = ATOMRegressor(story, vocabulary, test_size = 0.33, random_state = 42, verbose = 2)
atom4 = ATOMRegressor(story, phraseology, test_size = 0.33, random_state = 42, verbose = 2)
atom5 = ATOMRegressor(story, grammar, test_size = 0.33, random_state = 42, verbose = 2)
atom6 = ATOMRegressor(story, conventions, test_size = 0.33, random_state = 42, verbose = 2)
# Out:
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# Outlier values: 4 (0.1%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290
#
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# Outlier values: 17 (0.3%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290
#
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# Outlier values: 23 (0.4%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290
#
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# Outlier values: 3 (0.1%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290
#
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290
#
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# Outlier values: 8 (0.2%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290

# %%
atom1.dataset
# Out:
#                                                  corpus  target
# 0     i agreed that the greater of us lies and not i...     3.5
# 1     the most enjoyable educational activity would ...     3.0
# 2     people always argue when it comes to does posi...     3.0
# 3     i dont like becuase the student forget all inf...     3.0
# 4     a first impression is the key to succes, becau...     3.0
# ...                                                 ...     ...
# 3906  why does most people want multiple advice when...     3.5
# 3907  make sure you have your seat belts. that is th...     2.5
# 3908  people can check out books, shop and play game...     3.0
# 3909  doing projects at school is really fun when it...     4.0
# 3910  people say first impressions are almost imposs...     3.5
#
# [3911 rows x 2 columns]

# %%
atom1.textclean()
atom2.textclean()
atom3.textclean()
atom4.textclean()
atom5.textclean()
atom6.textclean()
# Out:
# Fitting TextCleaner...
# Cleaning the corpus...
#  --> Decoding unicode characters to ascii.
#  --> Converting text to lower case.
#  --> Dropping 0 emails from 0 documents.
#  --> Dropping 0 URL links from 0 documents.
#  --> Dropping 0 HTML tags from 0 documents.
#  --> Dropping 3 emojis from 3 documents.
#  --> Dropping 2847 numbers from 994 documents.
#  --> Dropping punctuation from the text.
# Fitting TextCleaner...
# Cleaning the corpus...
#  --> Decoding unicode characters to ascii.
#  --> Converting text to lower case.
#  --> Dropping 0 emails from 0 documents.
#  --> Dropping 0 URL links from 0 documents.
#  --> Dropping 0 HTML tags from 0 documents.
#  --> Dropping 3 emojis from 3 documents.
#  --> Dropping 2847 numbers from 994 documents.
#  --> Dropping punctuation from the text.
# Fitting TextCleaner...
# Cleaning the corpus...
#  --> Decoding unicode characters to ascii.
#  --> Converting text to lower case.
#  --> Dropping 0 emails from 0 documents.
#  --> Dropping 0 URL links from 0 documents.
#  --> Dropping 0 HTML tags from 0 documents.
#  --> Dropping 3 emojis from 3 documents.
#  --> Dropping 2847 numbers from 994 documents.
#  --> Dropping punctuation from the text.
# Fitting TextCleaner...
# Cleaning the corpus...
#  --> Decoding unicode characters to ascii.
#  --> Converting text to lower case.
#  --> Dropping 0 emails from 0 documents.
#  --> Dropping 0 URL links from 0 documents.
#  --> Dropping 0 HTML tags from 0 documents.
#  --> Dropping 3 emojis from 3 documents.
#  --> Dropping 2847 numbers from 994 documents.
#  --> Dropping punctuation from the text.
# Fitting TextCleaner...
# Cleaning the corpus...
#  --> Decoding unicode characters to ascii.
#  --> Converting text to lower case.
#  --> Dropping 0 emails from 0 documents.
#  --> Dropping 0 URL links from 0 documents.
#  --> Dropping 0 HTML tags from 0 documents.
#  --> Dropping 3 emojis from 3 documents.
#  --> Dropping 2847 numbers from 994 documents.
#  --> Dropping punctuation from the text.
# Fitting TextCleaner...
# Cleaning the corpus...
#  --> Decoding unicode characters to ascii.
#  --> Converting text to lower case.
#  --> Dropping 0 emails from 0 documents.
#  --> Dropping 0 URL links from 0 documents.
#  --> Dropping 0 HTML tags from 0 documents.
#  --> Dropping 3 emojis from 3 documents.
#  --> Dropping 2847 numbers from 994 documents.
#  --> Dropping punctuation from the text.

# %%
atom1.tokenize()
atom2.tokenize()
atom3.tokenize()
atom4.tokenize()
atom5.tokenize()
atom6.tokenize()
# Out:
# Fitting Tokenizer...
# Tokenizing the corpus...
# Fitting Tokenizer...
# Tokenizing the corpus...
# Fitting Tokenizer...
# Tokenizing the corpus...
# Fitting Tokenizer...
# Tokenizing the corpus...
# Fitting Tokenizer...
# Tokenizing the corpus...
# Fitting Tokenizer...
# Tokenizing the corpus...

# %%
atom1.vectorize(strategy = 'bow')
atom2.vectorize(strategy = 'bow')
atom3.vectorize(strategy = 'bow')
atom4.vectorize(strategy = 'bow')
atom5.vectorize(strategy = 'bow')
atom6.vectorize(strategy = 'bow')
# Out:
# Fitting Vectorizer...
# Vectorizing the corpus...
# Fitting Vectorizer...
# Vectorizing the corpus...
# Fitting Vectorizer...
# Vectorizing the corpus...
# Fitting Vectorizer...
# Vectorizing the corpus...
# Fitting Vectorizer...
# Vectorizing the corpus...
# Fitting Vectorizer...
# Vectorizing the corpus...

# %%
atom1.available_models()
# Out:
#    acronym                            model                      estimator  \
# 0     AdaB                         AdaBoost              AdaBoostRegressor
# 1      ARD  AutomaticRelevanceDetermination                  ARDRegression
# 2      Bag                          Bagging               BaggingRegressor
# 3       BR                    BayesianRidge                  BayesianRidge
# 4     CatB                         CatBoost              CatBoostRegressor
# 5     Tree                     DecisionTree          DecisionTreeRegressor
# 6    Dummy                            Dummy                 DummyRegressor
# 7       EN                       ElasticNet                     ElasticNet
# 8    ETree                        ExtraTree             ExtraTreeRegressor
# 9       ET                       ExtraTrees            ExtraTreesRegressor
# 10      GP                  GaussianProcess       GaussianProcessRegressor
# 11     GBM                 GradientBoosting      GradientBoostingRegressor
# 12   Huber                  HuberRegression                 HuberRegressor
# 13    hGBM             HistGradientBoosting  HistGradientBoostingRegressor
# 14     KNN                KNearestNeighbors            KNeighborsRegressor
# 15   Lasso                            Lasso                          Lasso
# 16    Lars             LeastAngleRegression                           Lars
# 17     LGB                         LightGBM                  LGBMRegressor
# 18    lSVM                        LinearSVM                      LinearSVR
# 19     MLP             MultiLayerPerceptron                   MLPRegressor
# 20     OLS             OrdinaryLeastSquares               LinearRegression
# 21     OMP        OrthogonalMatchingPursuit      OrthogonalMatchingPursuit
# 22      PA                PassiveAggressive     PassiveAggressiveRegressor
# 23     RNN           RadiusNearestNeighbors       RadiusNeighborsRegressor
# 24      RF                     RandomForest          RandomForestRegressor
# 25   Ridge                            Ridge                          Ridge
# 26     SGD        StochasticGradientDescent                   SGDRegressor
# 27     SVM             SupportVectorMachine                            SVR
# 28     XGB                          XGBoost                   XGBRegressor
#
#                       module  needs_scaling  accepts_sparse  has_validation  \
# 0            sklearnensemble          False            True           False
# 1        sklearnlinear_model           True           False           False
# 2            sklearnensemble          False            True           False
# 3        sklearnlinear_model           True           False           False
# 4           catboostcatboost           True            True            True
# 5                sklearntree          False            True           False
# 6               sklearndummy          False           False           False
# 7        sklearnlinear_model           True            True           False
# 8                sklearntree          False            True           False
# 9            sklearnensemble          False            True           False
# 10   sklearngaussian_process          False           False           False
# 11           sklearnensemble          False            True           False
# 12       sklearnlinear_model           True           False           False
# 13           sklearnensemble          False           False           False
# 14          sklearnneighbors           True            True           False
# 15       sklearnlinear_model           True            True           False
# 16       sklearnlinear_model           True           False           False
# 17  lightgbmlightgbm.sklearn           True            True            True
# 18                sklearnsvm           True            True           False
# 19     sklearnneural_network           True            True            True
# 20       sklearnlinear_model           True            True           False
# 21       sklearnlinear_model           True           False           False
# 22       sklearnlinear_model           True            True            True
# 23          sklearnneighbors           True            True           False
# 24           sklearnensemble          False            True           False
# 25       sklearnlinear_model           True            True           False
# 26       sklearnlinear_model           True            True            True
# 27                sklearnsvm           True            True           False
# 28            xgboostxgboost           True            True            True
#
#             supports_engines
# 0                    sklearn
# 1                    sklearn
# 2                    sklearn
# 3                    sklearn
# 4                   catboost
# 5                    sklearn
# 6                    sklearn
# 7   sklearn, sklearnex, cuml
# 8                    sklearn
# 9                    sklearn
# 10                   sklearn
# 11                   sklearn
# 12                   sklearn
# 13                   sklearn
# 14  sklearn, sklearnex, cuml
# 15  sklearn, sklearnex, cuml
# 16                   sklearn
# 17                  lightgbm
# 18             sklearn, cuml
# 19                   sklearn
# 20  sklearn, sklearnex, cuml
# 21                   sklearn
# 22                   sklearn
# 23                   sklearn
# 24  sklearn, sklearnex, cuml
# 25  sklearn, sklearnex, cuml
# 26                   sklearn
# 27  sklearn, sklearnex, cuml
# 28                   xgboost

# %%
atom1.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
atom2.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
atom3.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
atom4.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
atom5.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
atom6.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
# Out:
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for DecisionTree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.6886
# Time elapsed: 29.636s
# -------------------------------------------------
# Total time: 29.636s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0654
# Test evaluation --> neg_mean_squared_error: -0.3627
# Time elapsed: 44.494s
# -------------------------------------------------
# Total time: 44.494s
#
#
# Results for ExtraTrees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.3336
# Time elapsed: 05m:23s
# -------------------------------------------------
# Total time: 05m:23s
#
#
# Results for RandomForest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0466
# Test evaluation --> neg_mean_squared_error: -0.3384
# Time elapsed: 03m:26s
# -------------------------------------------------
# Total time: 03m:26s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.3225
# Test evaluation --> neg_mean_squared_error: -0.3586
# Time elapsed: 41.410s
# -------------------------------------------------
# Total time: 41.410s
#
#
# Results for GradientBoosting:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.2125
# Test evaluation --> neg_mean_squared_error: -0.3329
# Time elapsed: 44.283s
# -------------------------------------------------
# Total time: 44.283s
#
#
# Final results ==================== >>
# Total time: 11m:29s
# -------------------------------------
# DecisionTree     --> neg_mean_squared_error: -0.6886 ~
# Bagging          --> neg_mean_squared_error: -0.3627 ~
# ExtraTrees       --> neg_mean_squared_error: -0.3336 ~
# RandomForest     --> neg_mean_squared_error: -0.3384 ~
# AdaBoost         --> neg_mean_squared_error: -0.3586 ~
# GradientBoosting --> neg_mean_squared_error: -0.3329 ~ !
#
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for DecisionTree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.6287
# Time elapsed: 32.245s
# -------------------------------------------------
# Total time: 32.245s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0579
# Test evaluation --> neg_mean_squared_error: -0.3428
# Time elapsed: 49.463s
# -------------------------------------------------
# Total time: 49.463s
#
#
# Results for ExtraTrees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.3042
# Time elapsed: 05m:23s
# -------------------------------------------------
# Total time: 05m:23s
#
#
# Results for RandomForest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0435
# Test evaluation --> neg_mean_squared_error: -0.3142
# Time elapsed: 03m:09s
# -------------------------------------------------
# Total time: 03m:09s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.2927
# Test evaluation --> neg_mean_squared_error: -0.3363
# Time elapsed: 34.101s
# -------------------------------------------------
# Total time: 34.101s
#
#
# Results for GradientBoosting:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.2014
# Test evaluation --> neg_mean_squared_error: -0.309
# Time elapsed: 43.466s
# -------------------------------------------------
# Total time: 43.466s
#
#
# Final results ==================== >>
# Total time: 11m:12s
# -------------------------------------
# DecisionTree     --> neg_mean_squared_error: -0.6287 ~
# Bagging          --> neg_mean_squared_error: -0.3428 ~
# ExtraTrees       --> neg_mean_squared_error: -0.3042 ~ !
# RandomForest     --> neg_mean_squared_error: -0.3142 ~
# AdaBoost         --> neg_mean_squared_error: -0.3363 ~
# GradientBoosting --> neg_mean_squared_error: -0.309 ~
#
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for DecisionTree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.5101
# Time elapsed: 31.455s
# -------------------------------------------------
# Total time: 31.455s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0453
# Test evaluation --> neg_mean_squared_error: -0.2792
# Time elapsed: 41.472s
# -------------------------------------------------
# Total time: 41.472s
#
#
# Results for ExtraTrees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.2556
# Time elapsed: 05m:20s
# -------------------------------------------------
# Total time: 05m:20s
#
#
# Results for RandomForest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0336
# Test evaluation --> neg_mean_squared_error: -0.2637
# Time elapsed: 02m:54s
# -------------------------------------------------
# Total time: 02m:54s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.2182
# Test evaluation --> neg_mean_squared_error: -0.2763
# Time elapsed: 40.302s
# -------------------------------------------------
# Total time: 40.302s
#
#
# Results for GradientBoosting:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.1512
# Test evaluation --> neg_mean_squared_error: -0.2544
# Time elapsed: 47.069s
# -------------------------------------------------
# Total time: 47.069s
#
#
# Final results ==================== >>
# Total time: 10m:54s
# -------------------------------------
# DecisionTree     --> neg_mean_squared_error: -0.5101 ~
# Bagging          --> neg_mean_squared_error: -0.2792 ~
# ExtraTrees       --> neg_mean_squared_error: -0.2556 ~
# RandomForest     --> neg_mean_squared_error: -0.2637 ~
# AdaBoost         --> neg_mean_squared_error: -0.2763 ~
# GradientBoosting --> neg_mean_squared_error: -0.2544 ~ !
#
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for DecisionTree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.6376
# Time elapsed: 36.705s
# -------------------------------------------------
# Total time: 36.705s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0583
# Test evaluation --> neg_mean_squared_error: -0.3542
# Time elapsed: 51.479s
# -------------------------------------------------
# Total time: 51.479s
#
#
# Results for ExtraTrees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.3049
# Time elapsed: 05m:18s
# -------------------------------------------------
# Total time: 05m:18s
#
#
# Results for RandomForest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0442
# Test evaluation --> neg_mean_squared_error: -0.3203
# Time elapsed: 02m:39s
# -------------------------------------------------
# Total time: 02m:39s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.3102
# Test evaluation --> neg_mean_squared_error: -0.3424
# Time elapsed: 33.861s
# -------------------------------------------------
# Total time: 33.861s
#
#
# Results for GradientBoosting:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.2004
# Test evaluation --> neg_mean_squared_error: -0.3041
# Time elapsed: 43.610s
# -------------------------------------------------
# Total time: 43.610s
#
#
# Final results ==================== >>
# Total time: 10m:43s
# -------------------------------------
# DecisionTree     --> neg_mean_squared_error: -0.6376 ~
# Bagging          --> neg_mean_squared_error: -0.3542 ~
# ExtraTrees       --> neg_mean_squared_error: -0.3049 ~
# RandomForest     --> neg_mean_squared_error: -0.3203 ~
# AdaBoost         --> neg_mean_squared_error: -0.3424 ~
# GradientBoosting --> neg_mean_squared_error: -0.3041 ~ !
#
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for DecisionTree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.7428
# Time elapsed: 35.702s
# -------------------------------------------------
# Total time: 35.702s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0706
# Test evaluation --> neg_mean_squared_error: -0.4101
# Time elapsed: 47.469s
# -------------------------------------------------
# Total time: 47.469s
#
#
# Results for ExtraTrees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.3641
# Time elapsed: 05m:37s
# -------------------------------------------------
# Total time: 05m:37s
#
#
# Results for RandomForest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.052
# Test evaluation --> neg_mean_squared_error: -0.3777
# Time elapsed: 03m:04s
# -------------------------------------------------
# Total time: 03m:04s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.3792
# Test evaluation --> neg_mean_squared_error: -0.4182
# Time elapsed: 38.288s
# -------------------------------------------------
# Total time: 38.288s
#
#
# Results for GradientBoosting:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.2384
# Test evaluation --> neg_mean_squared_error: -0.3572
# Time elapsed: 40.869s
# -------------------------------------------------
# Total time: 40.869s
#
#
# Final results ==================== >>
# Total time: 11m:23s
# -------------------------------------
# DecisionTree     --> neg_mean_squared_error: -0.7428 ~
# Bagging          --> neg_mean_squared_error: -0.4101 ~
# ExtraTrees       --> neg_mean_squared_error: -0.3641 ~
# RandomForest     --> neg_mean_squared_error: -0.3777 ~
# AdaBoost         --> neg_mean_squared_error: -0.4182 ~
# GradientBoosting --> neg_mean_squared_error: -0.3572 ~ !
#
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for DecisionTree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.7502
# Time elapsed: 32.123s
# -------------------------------------------------
# Total time: 32.123s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0679
# Test evaluation --> neg_mean_squared_error: -0.4069
# Time elapsed: 48.096s
# -------------------------------------------------
# Total time: 48.096s
#
#
# Results for ExtraTrees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.3611
# Time elapsed: 05m:26s
# -------------------------------------------------
# Total time: 05m:26s
#
#
# Results for RandomForest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0487
# Test evaluation --> neg_mean_squared_error: -0.3765
# Time elapsed: 02m:57s
# -------------------------------------------------
# Total time: 02m:57s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.3338
# Test evaluation --> neg_mean_squared_error: -0.3984
# Time elapsed: 32.779s
# -------------------------------------------------
# Total time: 32.779s
#
#
# Results for GradientBoosting:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.2329
# Test evaluation --> neg_mean_squared_error: -0.362
# Time elapsed: 39.819s
# -------------------------------------------------
# Total time: 39.819s
#
#
# Final results ==================== >>
# Total time: 10m:55s
# -------------------------------------
# DecisionTree     --> neg_mean_squared_error: -0.7502 ~
# Bagging          --> neg_mean_squared_error: -0.4069 ~
# ExtraTrees       --> neg_mean_squared_error: -0.3611 ~ !
# RandomForest     --> neg_mean_squared_error: -0.3765 ~
# AdaBoost         --> neg_mean_squared_error: -0.3984 ~
# GradientBoosting --> neg_mean_squared_error: -0.362 ~

# %%
atom1.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                  -0.6360                             -0.2180    -3.0000
# Bag                   -0.4848                             -0.1698    -1.9500
# ET                    -0.4672                             -0.1641    -1.8900
# RF                    -0.4715                             -0.1654    -1.9300
# AdaB                  -0.4875                             -0.1699    -2.0726
# GBM                   -0.4679                             -0.1645    -1.8261
#
#       neg_mean_squared_error      r2  neg_root_mean_squared_error
# Tree                 -0.6886 -0.5662                      -0.8298
# Bag                  -0.3627  0.1749                      -0.6023
# ET                   -0.3336  0.2412                      -0.5776
# RF                   -0.3384  0.2302                      -0.5817
# AdaB                 -0.3586  0.1844                      -0.5988
# GBM                  -0.3329  0.2427                      -0.5770

# %%
atom2.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                  -0.6078                             -0.2140    -3.0000
# Bag                   -0.4667                             -0.1665    -1.9500
# ET                    -0.4368                             -0.1574    -2.1800
# RF                    -0.4453                             -0.1600    -2.1350
# AdaB                  -0.4645                             -0.1707    -2.0445
# GBM                   -0.4413                             -0.1594    -2.1355
#
#       neg_mean_squared_error      r2  neg_root_mean_squared_error
# Tree                 -0.6287 -0.5175                      -0.7929
# Bag                  -0.3428  0.1726                      -0.5855
# ET                   -0.3042  0.2656                      -0.5516
# RF                   -0.3142  0.2415                      -0.5605
# AdaB                 -0.3363  0.1881                      -0.5799
# GBM                  -0.3090  0.2542                      -0.5559

# %%
atom3.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                  -0.5264                             -0.1697    -2.5000
# Bag                   -0.4094                             -0.1330    -2.3500
# ET                    -0.3897                             -0.1270    -2.0750
# RF                    -0.3977                             -0.1294    -2.1000
# AdaB                  -0.4050                             -0.1322    -2.0041
# GBM                   -0.3888                             -0.1274    -2.0607
#
#       neg_mean_squared_error      r2  neg_root_mean_squared_error
# Tree                 -0.5101 -0.4523                      -0.7142
# Bag                  -0.2792  0.2049                      -0.5284
# ET                   -0.2556  0.2723                      -0.5056
# RF                   -0.2637  0.2491                      -0.5136
# AdaB                 -0.2763  0.2133                      -0.5256
# GBM                  -0.2544  0.2756                      -0.5044

# %%
atom4.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                  -0.6147                             -0.2073    -3.0000
# Bag                   -0.4723                             -0.1619    -2.1500
# ET                    -0.4428                             -0.1529    -1.7600
# RF                    -0.4536                             -0.1563    -1.8900
# AdaB                  -0.4716                             -0.1641    -1.9511
# GBM                   -0.4414                             -0.1530    -1.8958
#
#       neg_mean_squared_error      r2  neg_root_mean_squared_error
# Tree                 -0.6376 -0.4938                      -0.7985
# Bag                  -0.3542  0.1700                      -0.5952
# ET                   -0.3049  0.2857                      -0.5522
# RF                   -0.3203  0.2495                      -0.5660
# AdaB                 -0.3424  0.1978                      -0.5852
# GBM                  -0.3041  0.2874                      -0.5515

# %%
atom5.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                  -0.6740                             -0.2341    -3.0000
# Bag                   -0.5183                             -0.1834    -2.2000
# ET                    -0.4923                             -0.1743    -2.0900
# RF                    -0.5040                             -0.1782    -2.2100
# AdaB                  -0.5328                             -0.1948    -2.1613
# GBM                   -0.4858                             -0.1742    -2.0356
#
#       neg_mean_squared_error      r2  neg_root_mean_squared_error
# Tree                 -0.7428 -0.5206                      -0.8619
# Bag                  -0.4101  0.1605                      -0.6404
# ET                   -0.3641  0.2546                      -0.6034
# RF                   -0.3777  0.2267                      -0.6146
# AdaB                 -0.4182  0.1440                      -0.6467
# GBM                  -0.3572  0.2688                      -0.5976

# %%
atom6.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                  -0.6671                             -0.2325    -3.0000
# Bag                   -0.5107                             -0.1818    -2.0500
# ET                    -0.4818                             -0.1717    -1.9800
# RF                    -0.4938                             -0.1759    -2.0250
# AdaB                  -0.5121                             -0.1856    -2.0609
# GBM                   -0.4850                             -0.1721    -2.1260
#
#       neg_mean_squared_error      r2  neg_root_mean_squared_error
# Tree                 -0.7502 -0.6158                      -0.8661
# Bag                  -0.4069  0.1236                      -0.6379
# ET                   -0.3611  0.2223                      -0.6009
# RF                   -0.3765  0.1891                      -0.6136
# AdaB                 -0.3984  0.1418                      -0.6312
# GBM                  -0.3620  0.2202                      -0.6017
