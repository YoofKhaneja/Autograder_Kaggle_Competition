# %% [markdown]
# # Trying a pipeline-based approach

# %%
import pandas as pd
import numpy as np

train_data = pd.read_csv("/kaggle/input/feedback-prize-english-language-learning/train.csv")
train_data.head()
# Out:
#         text_id                                          full_text  cohesion  \
# 0  0016926B079C  I think that students would benefit from learn...       3.5
# 1  0022683E9EA5  When a problem is a change you have to let it ...       2.5
# 2  00299B378633  Dear, Principal\n\nIf u change the school poli...       3.0
# 3  003885A45F42  The best time in life is when you become yours...       4.5
# 4  0049B1DF5CCC  Small act of kindness can impact in other peop...       2.5
#
#    syntax  vocabulary  phraseology  grammar  conventions
# 0     3.5         3.0          3.0      4.0          3.0
# 1     2.5         3.0          2.0      2.0          2.5
# 2     3.5         3.0          3.0      3.0          2.5
# 3     4.5         4.5          4.5      4.0          5.0
# 4     3.0         3.0          3.0      2.5          2.5

# %%
story = []
for i in train_data['full_text']:
    story.append(i.lower().replace("\n", "").strip())

# %%
story = np.array(story).reshape(-1, 1)
story.shape
# Out:
# (3911, 1)

# %%
cohesion = np.array(train_data['cohesion']).astype(float)
syntax = np.array(train_data['syntax']).astype(float)
vocabulary = np.array(train_data['vocabulary']).astype(float)
phraseology = np.array(train_data['phraseology']).astype(float)
grammar = np.array(train_data['grammar']).astype(float)
conventions = np.array(train_data['conventions']).astype(float)
conventions.shape
# Out:
# (3911,)

# %%
test_data = pd.read_csv("/kaggle/input/feedback-prize-english-language-learning/test.csv")
test_data
# Out:
#         text_id                                          full_text
# 0  0000C359D63E  when a person has no experience on a job their...
# 1  000BAD50D026  Do you think students would benefit from being...
# 2  00367BB2546B  Thomas Jefferson once states that "it is wonde...

# %%
story_pred = []
for i in test_data['full_text']:
    story_pred.append(i.lower().replace("\n", "").strip())
story_pred = np.array(story_pred).reshape(-1, 1)

# %%
from atom import ATOMRegressor

atom1 = ATOMRegressor(story, cohesion, test_size = 0.33, random_state = 42, verbose = 2)
atom2 = ATOMRegressor(story, syntax, test_size = 0.33, random_state = 42, verbose = 2)
atom3 = ATOMRegressor(story, vocabulary, test_size = 0.33, random_state = 42, verbose = 2)
atom4 = ATOMRegressor(story, phraseology, test_size = 0.33, random_state = 42, verbose = 2)
atom5 = ATOMRegressor(story, grammar, test_size = 0.33, random_state = 42, verbose = 2)
atom6 = ATOMRegressor(story, conventions, test_size = 0.33, random_state = 42, verbose = 2)
# Out:
# Woodwork may not support Python 3.7 in next non-bugfix release.
# Featuretools may not support Python 3.7 in next non-bugfix release.
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# Outlier values: 6 (0.1%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290
#
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# Outlier values: 23 (0.4%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290
#
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# Outlier values: 1 (0.0%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290
#
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# Outlier values: 8 (0.2%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290
#
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290
#
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# Outlier values: 9 (0.2%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290

# %%
atom1.dataset
# Out:
#                                                  corpus  target
# 0     the great artist michelangelo i thinking he is...     2.0
# 1     one of the things i want to acumplish in the f...     2.5
# 2     its always good to ask people how it feels or ...     3.0
# 3     in order for students to have a good experienc...     3.0
# 4     dear, principal,i will like to star in saying ...     3.5
# ...                                                 ...     ...
# 3906  i think an enjoyable educational activity for ...     4.0
# 3907  some people may say that oppocite but to start...     3.5
# 3908  "unles you try to do somthing beyond what you ...     2.5
# 3909  having activities after school are good ideas ...     4.0
# 3910  explain how small acts of kindness can have a ...     3.5
#
# [3911 rows x 2 columns]

# %%
atom1.textclean()
atom2.textclean()
atom3.textclean()
atom4.textclean()
atom5.textclean()
atom6.textclean()
# Out:
# Cleaning the corpus...
#  --> Decoding unicode characters to ascii.
#  --> Converting text to lower case.
#  --> Dropping 0 emails from 0 documents.
#  --> Dropping 0 URL links from 0 documents.
#  --> Dropping 0 HTML tags from 0 documents.
#  --> Dropping 3 emojis from 3 documents.
#  --> Dropping 2847 numbers from 994 documents.
#  --> Dropping punctuation from the text.
# Cleaning the corpus...
#  --> Decoding unicode characters to ascii.
#  --> Converting text to lower case.
#  --> Dropping 0 emails from 0 documents.
#  --> Dropping 0 URL links from 0 documents.
#  --> Dropping 0 HTML tags from 0 documents.
#  --> Dropping 3 emojis from 3 documents.
#  --> Dropping 2847 numbers from 994 documents.
#  --> Dropping punctuation from the text.
# Cleaning the corpus...
#  --> Decoding unicode characters to ascii.
#  --> Converting text to lower case.
#  --> Dropping 0 emails from 0 documents.
#  --> Dropping 0 URL links from 0 documents.
#  --> Dropping 0 HTML tags from 0 documents.
#  --> Dropping 3 emojis from 3 documents.
#  --> Dropping 2847 numbers from 994 documents.
#  --> Dropping punctuation from the text.
# Cleaning the corpus...
#  --> Decoding unicode characters to ascii.
#  --> Converting text to lower case.
#  --> Dropping 0 emails from 0 documents.
#  --> Dropping 0 URL links from 0 documents.
#  --> Dropping 0 HTML tags from 0 documents.
#  --> Dropping 3 emojis from 3 documents.
#  --> Dropping 2847 numbers from 994 documents.
#  --> Dropping punctuation from the text.
# Cleaning the corpus...
#  --> Decoding unicode characters to ascii.
#  --> Converting text to lower case.
#  --> Dropping 0 emails from 0 documents.
#  --> Dropping 0 URL links from 0 documents.
#  --> Dropping 0 HTML tags from 0 documents.
#  --> Dropping 3 emojis from 3 documents.
#  --> Dropping 2847 numbers from 994 documents.
#  --> Dropping punctuation from the text.
# Cleaning the corpus...
#  --> Decoding unicode characters to ascii.
#  --> Converting text to lower case.
#  --> Dropping 0 emails from 0 documents.
#  --> Dropping 0 URL links from 0 documents.
#  --> Dropping 0 HTML tags from 0 documents.
#  --> Dropping 3 emojis from 3 documents.
#  --> Dropping 2847 numbers from 994 documents.
#  --> Dropping punctuation from the text.

# %%
atom1.tokenize()
atom2.tokenize()
atom3.tokenize()
atom4.tokenize()
atom5.tokenize()
atom6.tokenize()
# Out:
# Tokenizing the corpus...
# Tokenizing the corpus...
# Tokenizing the corpus...
# Tokenizing the corpus...
# Tokenizing the corpus...
# Tokenizing the corpus...

# %%
atom1.vectorize(strategy = 'tfidf')
atom2.vectorize(strategy = 'tfidf')
atom3.vectorize(strategy = 'tfidf')
atom4.vectorize(strategy = 'tfidf')
atom5.vectorize(strategy = 'tfidf')
atom6.vectorize(strategy = 'tfidf')
# Out:
# Fitting Vectorizer...
# Vectorizing the corpus...
# Fitting Vectorizer...
# Vectorizing the corpus...
# Fitting Vectorizer...
# Vectorizing the corpus...
# Fitting Vectorizer...
# Vectorizing the corpus...
# Fitting Vectorizer...
# Vectorizing the corpus...
# Fitting Vectorizer...
# Vectorizing the corpus...

# %%
atom1.available_models()
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>
#    acronym                          fullname                      estimator  \
# 0    Dummy                   Dummy Estimator                 DummyRegressor
# 1       GP                  Gaussian Process       GaussianProcessRegressor
# 2      OLS            Ordinary Least Squares               LinearRegression
# 3    Ridge                   Ridge Estimator                          Ridge
# 4    Lasso                  Lasso Regression                          Lasso
# 5       EN             ElasticNet Regression                     ElasticNet
# 6     Lars            Least Angle Regression                           Lars
# 7       BR                    Bayesian Ridge                  BayesianRidge
# 8      ARD  Automatic Relevant Determination                  ARDRegression
# 9    Huber                  Huber Regression                 HuberRegressor
# 10     KNN               K-Nearest Neighbors            KNeighborsRegressor
# 11     RNN          Radius Nearest Neighbors       RadiusNeighborsRegressor
# 12    Tree                     Decision Tree          DecisionTreeRegressor
# 13     Bag                           Bagging               BaggingRegressor
# 14      ET                       Extra-Trees            ExtraTreesRegressor
# 15      RF                     Random Forest          RandomForestRegressor
# 16    AdaB                          AdaBoost              AdaBoostRegressor
# 17     GBM         Gradient Boosting Machine      GradientBoostingRegressor
# 18    hGBM                           HistGBM  HistGradientBoostingRegressor
# 19     XGB                           XGBoost                   XGBRegressor
# 20     LGB                          LightGBM                  LGBMRegressor
# 21    CatB                          CatBoost              CatBoostRegressor
# 22    lSVM                        Linear SVM                      LinearSVR
# 23    kSVM                        Kernel SVM                            SVR
# 24      PA                Passive Aggressive     PassiveAggressiveRegressor
# 25     SGD       Stochastic Gradient Descent                   SGDRegressor
# 26     MLP            Multi-layer Perceptron                   MLPRegressor
#
#                                                module needs_scaling  \
# 0                                       sklearn.dummy         False
# 1                       sklearn.gaussian_process._gpr         False
# 2                          sklearn.linear_model._base          True
# 3                         sklearn.linear_model._ridge          True
# 4            sklearn.linear_model._coordinate_descent          True
# 5            sklearn.linear_model._coordinate_descent          True
# 6                   sklearn.linear_model._least_angle          True
# 7                         sklearn.linear_model._bayes          True
# 8                         sklearn.linear_model._bayes          True
# 9                         sklearn.linear_model._huber          True
# 10                      sklearn.neighbors._regression          True
# 11                      sklearn.neighbors._regression          True
# 12                              sklearn.tree._classes         False
# 13                          sklearn.ensemble._bagging         False
# 14                           sklearn.ensemble._forest         False
# 15                           sklearn.ensemble._forest         False
# 16                  sklearn.ensemble._weight_boosting         False
# 17                               sklearn.ensemble._gb         False
# 18  sklearn.ensemble._hist_gradient_boosting.gradi...         False
# 19                                    xgboost.sklearn          True
# 20                                   lightgbm.sklearn          True
# 21                                      catboost.core          True
# 22                               sklearn.svm._classes          True
# 23                               sklearn.svm._classes          True
# 24           sklearn.linear_model._passive_aggressive          True
# 25          sklearn.linear_model._stochastic_gradient          True
# 26      sklearn.neural_network._multilayer_perceptron          True
#
#    accepts_sparse supports_gpu
# 0           False        False
# 1           False        False
# 2            True         True
# 3            True         True
# 4            True         True
# 5            True         True
# 6           False         True
# 7           False        False
# 8           False        False
# 9           False        False
# 10           True         True
# 11           True        False
# 12           True        False
# 13           True        False
# 14           True        False
# 15           True         True
# 16           True        False
# 17           True        False
# 18          False        False
# 19           True         True
# 20           True         True
# 21           True         True
# 22           True         True
# 23           True         True
# 24           True        False
# 25           True        False
# 26           True        False

# %%
atom1.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
atom2.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
atom3.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
atom4.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
atom5.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
atom6.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
# Out:
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for Decision Tree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.6595
# Time elapsed: 54.080s
# -------------------------------------------------
# Total time: 54.080s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0663
# Test evaluation --> neg_mean_squared_error: -0.3563
# Time elapsed: 1m:05s
# -------------------------------------------------
# Total time: 1m:05s
#
#
# Results for Extra-Trees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.3224
# Time elapsed: 4m:35s
# -------------------------------------------------
# Total time: 4m:35s
#
#
# Results for Random Forest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0478
# Test evaluation --> neg_mean_squared_error: -0.3335
# Time elapsed: 3m:20s
# -------------------------------------------------
# Total time: 3m:20s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.3037
# Test evaluation --> neg_mean_squared_error: -0.3352
# Time elapsed: 1m:03s
# -------------------------------------------------
# Total time: 1m:03s
#
#
# Results for Gradient Boosting Machine:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.1993
# Test evaluation --> neg_mean_squared_error: -0.3202
# Time elapsed: 1m:13s
# -------------------------------------------------
# Total time: 1m:13s
#
#
# Final results ==================== >>
# Duration: 12m:10s
# -------------------------------------
# Decision Tree             --> neg_mean_squared_error: -0.6595 ~
# Bagging                   --> neg_mean_squared_error: -0.3563 ~
# Extra-Trees               --> neg_mean_squared_error: -0.3224 ~
# Random Forest             --> neg_mean_squared_error: -0.3335 ~
# AdaBoost                  --> neg_mean_squared_error: -0.3352 ~
# Gradient Boosting Machine --> neg_mean_squared_error: -0.3202 ~ !
#
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for Decision Tree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.6703
# Time elapsed: 1m:00s
# -------------------------------------------------
# Total time: 1m:00s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0615
# Test evaluation --> neg_mean_squared_error: -0.3463
# Time elapsed: 1m:08s
# -------------------------------------------------
# Total time: 1m:08s
#
#
# Results for Extra-Trees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.3079
# Time elapsed: 4m:37s
# -------------------------------------------------
# Total time: 4m:37s
#
#
# Results for Random Forest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0446
# Test evaluation --> neg_mean_squared_error: -0.3204
# Time elapsed: 3m:13s
# -------------------------------------------------
# Total time: 3m:13s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.2728
# Test evaluation --> neg_mean_squared_error: -0.3327
# Time elapsed: 57.420s
# -------------------------------------------------
# Total time: 57.420s
#
#
# Results for Gradient Boosting Machine:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.1876
# Test evaluation --> neg_mean_squared_error: -0.3051
# Time elapsed: 1m:08s
# -------------------------------------------------
# Total time: 1m:08s
#
#
# Final results ==================== >>
# Duration: 12m:03s
# -------------------------------------
# Decision Tree             --> neg_mean_squared_error: -0.6703 ~
# Bagging                   --> neg_mean_squared_error: -0.3463 ~
# Extra-Trees               --> neg_mean_squared_error: -0.3079 ~
# Random Forest             --> neg_mean_squared_error: -0.3204 ~
# AdaBoost                  --> neg_mean_squared_error: -0.3327 ~
# Gradient Boosting Machine --> neg_mean_squared_error: -0.3051 ~ !
#
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for Decision Tree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.4665
# Time elapsed: 52.972s
# -------------------------------------------------
# Total time: 52.972s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0503
# Test evaluation --> neg_mean_squared_error: -0.2718
# Time elapsed: 1m:07s
# -------------------------------------------------
# Total time: 1m:07s
#
#
# Results for Extra-Trees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.2452
# Time elapsed: 4m:22s
# -------------------------------------------------
# Total time: 4m:22s
#
#
# Results for Random Forest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0346
# Test evaluation --> neg_mean_squared_error: -0.2541
# Time elapsed: 3m:05s
# -------------------------------------------------
# Total time: 3m:05s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.2131
# Test evaluation --> neg_mean_squared_error: -0.257
# Time elapsed: 56.730s
# -------------------------------------------------
# Total time: 56.730s
#
#
# Results for Gradient Boosting Machine:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.1422
# Test evaluation --> neg_mean_squared_error: -0.2503
# Time elapsed: 1m:05s
# -------------------------------------------------
# Total time: 1m:05s
#
#
# Final results ==================== >>
# Duration: 11m:29s
# -------------------------------------
# Decision Tree             --> neg_mean_squared_error: -0.4665 ~
# Bagging                   --> neg_mean_squared_error: -0.2718 ~
# Extra-Trees               --> neg_mean_squared_error: -0.2452 ~ !
# Random Forest             --> neg_mean_squared_error: -0.2541 ~
# AdaBoost                  --> neg_mean_squared_error: -0.257 ~
# Gradient Boosting Machine --> neg_mean_squared_error: -0.2503 ~
#
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for Decision Tree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.5961
# Time elapsed: 52.414s
# -------------------------------------------------
# Total time: 52.414s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0646
# Test evaluation --> neg_mean_squared_error: -0.3271
# Time elapsed: 1m:04s
# -------------------------------------------------
# Total time: 1m:04s
#
#
# Results for Extra-Trees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.2935
# Time elapsed: 4m:27s
# -------------------------------------------------
# Total time: 4m:27s
#
#
# Results for Random Forest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0445
# Test evaluation --> neg_mean_squared_error: -0.3052
# Time elapsed: 3m:11s
# -------------------------------------------------
# Total time: 3m:11s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.2929
# Test evaluation --> neg_mean_squared_error: -0.3304
# Time elapsed: 57.511s
# -------------------------------------------------
# Total time: 57.511s
#
#
# Results for Gradient Boosting Machine:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.1855
# Test evaluation --> neg_mean_squared_error: -0.296
# Time elapsed: 1m:06s
# -------------------------------------------------
# Total time: 1m:06s
#
#
# Final results ==================== >>
# Duration: 11m:38s
# -------------------------------------
# Decision Tree             --> neg_mean_squared_error: -0.5961 ~
# Bagging                   --> neg_mean_squared_error: -0.3271 ~
# Extra-Trees               --> neg_mean_squared_error: -0.2935 ~ !
# Random Forest             --> neg_mean_squared_error: -0.3052 ~
# AdaBoost                  --> neg_mean_squared_error: -0.3304 ~
# Gradient Boosting Machine --> neg_mean_squared_error: -0.296 ~
#
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for Decision Tree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.7318
# Time elapsed: 51.977s
# -------------------------------------------------
# Total time: 51.977s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0726
# Test evaluation --> neg_mean_squared_error: -0.3928
# Time elapsed: 1m:06s
# -------------------------------------------------
# Total time: 1m:06s
#
#
# Results for Extra-Trees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.3613
# Time elapsed: 4m:43s
# -------------------------------------------------
# Total time: 4m:43s
#
#
# Results for Random Forest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0519
# Test evaluation --> neg_mean_squared_error: -0.3654
# Time elapsed: 3m:18s
# -------------------------------------------------
# Total time: 3m:18s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.3577
# Test evaluation --> neg_mean_squared_error: -0.3897
# Time elapsed: 59.149s
# -------------------------------------------------
# Total time: 59.149s
#
#
# Results for Gradient Boosting Machine:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.2236
# Test evaluation --> neg_mean_squared_error: -0.355
# Time elapsed: 1m:06s
# -------------------------------------------------
# Total time: 1m:06s
#
#
# Final results ==================== >>
# Duration: 12m:04s
# -------------------------------------
# Decision Tree             --> neg_mean_squared_error: -0.7318 ~
# Bagging                   --> neg_mean_squared_error: -0.3928 ~
# Extra-Trees               --> neg_mean_squared_error: -0.3613 ~
# Random Forest             --> neg_mean_squared_error: -0.3654 ~
# AdaBoost                  --> neg_mean_squared_error: -0.3897 ~
# Gradient Boosting Machine --> neg_mean_squared_error: -0.355 ~ !
#
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for Decision Tree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.7791
# Time elapsed: 53.035s
# -------------------------------------------------
# Total time: 53.035s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0713
# Test evaluation --> neg_mean_squared_error: -0.3926
# Time elapsed: 1m:05s
# -------------------------------------------------
# Total time: 1m:05s
#
#
# Results for Extra-Trees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.3538
# Time elapsed: 4m:43s
# -------------------------------------------------
# Total time: 4m:43s
#
#
# Results for Random Forest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0498
# Test evaluation --> neg_mean_squared_error: -0.3735
# Time elapsed: 3m:22s
# -------------------------------------------------
# Total time: 3m:22s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.3239
# Test evaluation --> neg_mean_squared_error: -0.3854
# Time elapsed: 59.674s
# -------------------------------------------------
# Total time: 59.674s
#
#
# Results for Gradient Boosting Machine:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.2172
# Test evaluation --> neg_mean_squared_error: -0.3497
# Time elapsed: 1m:05s
# -------------------------------------------------
# Total time: 1m:05s
#
#
# Final results ==================== >>
# Duration: 12m:06s
# -------------------------------------
# Decision Tree             --> neg_mean_squared_error: -0.7791 ~
# Bagging                   --> neg_mean_squared_error: -0.3926 ~
# Extra-Trees               --> neg_mean_squared_error: -0.3538 ~
# Random Forest             --> neg_mean_squared_error: -0.3735 ~
# AdaBoost                  --> neg_mean_squared_error: -0.3854 ~
# Gradient Boosting Machine --> neg_mean_squared_error: -0.3497 ~ !

# %%
atom1.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                -0.626744                           -0.214347  -3.000000
# Bag                 -0.477171                           -0.166809  -2.150000
# ET                  -0.457957                           -0.161002  -2.080000
# RF                  -0.463488                           -0.163074  -2.060000
# AdaB                -0.464671                           -0.164608  -2.045814
# GBM                 -0.453934                           -0.159253  -2.100850
#
#       neg_mean_squared_error  neg_mean_squared_log_error        r2  \
# Tree               -0.659496                   -0.041499 -0.536787
# Bag                -0.356273                   -0.022368  0.169796
# ET                 -0.322362                   -0.020439  0.248817
# RF                 -0.333540                   -0.021143  0.222770
# AdaB               -0.335156                   -0.021342  0.219004
# GBM                -0.320189                   -0.020235  0.253881
#
#       neg_root_mean_squared_error
# Tree                    -0.812094
# Bag                     -0.596886
# ET                      -0.567769
# RF                      -0.577529
# AdaB                    -0.578927
# GBM                     -0.565853

# %%
atom2.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                -0.627519                           -0.223587  -2.500000
# Bag                 -0.471744                           -0.171242  -2.450000
# ET                  -0.446647                           -0.162053  -2.045000
# RF                  -0.453829                           -0.164800  -2.175000
# AdaB                -0.466567                           -0.171230  -2.224566
# GBM                 -0.442287                           -0.160370  -1.944459
#
#       neg_mean_squared_error  neg_mean_squared_log_error        r2  \
# Tree               -0.670349                   -0.043523 -0.622536
# Bag                -0.346343                   -0.022687  0.161699
# ET                 -0.307936                   -0.020313  0.254661
# RF                 -0.320388                   -0.021092  0.224522
# AdaB               -0.332702                   -0.022081  0.194716
# GBM                -0.305084                   -0.020122  0.261564
#
#       neg_root_mean_squared_error
# Tree                    -0.818748
# Bag                     -0.588509
# ET                      -0.554920
# RF                      -0.566028
# AdaB                    -0.576803
# GBM                     -0.552344

# %%
atom3.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                -0.519767                           -0.170249  -2.500000
# Bag                 -0.412597                           -0.136720  -1.750000
# ET                  -0.386829                           -0.128754  -1.945000
# RF                  -0.393729                           -0.130886  -1.920000
# AdaB                -0.399189                           -0.134313  -1.985294
# GBM                 -0.388929                           -0.129470  -1.996141
#
#       neg_mean_squared_error  neg_mean_squared_log_error        r2  \
# Tree               -0.466473                   -0.026938 -0.398032
# Bag                -0.271835                   -0.015927  0.185302
# ET                 -0.245198                   -0.014487  0.265136
# RF                 -0.254095                   -0.014963  0.238471
# AdaB               -0.256961                   -0.015277  0.229880
# GBM                -0.250311                   -0.014722  0.249812
#
#       neg_root_mean_squared_error
# Tree                    -0.682988
# Bag                     -0.521378
# ET                      -0.495175
# RF                      -0.504078
# AdaB                    -0.506913
# GBM                     -0.500311

# %%
atom4.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                -0.590698                           -0.200414  -2.500000
# Bag                 -0.462907                           -0.161141  -1.750000
# ET                  -0.440651                           -0.153583  -1.695000
# RF                  -0.448419                           -0.155837  -1.760000
# AdaB                -0.464194                           -0.160840  -1.804441
# GBM                 -0.440533                           -0.153495  -1.754707
#
#       neg_mean_squared_error  neg_mean_squared_log_error        r2  \
# Tree               -0.596124                   -0.036906 -0.400737
# Bag                -0.327083                   -0.020478  0.231439
# ET                 -0.293527                   -0.018407  0.310288
# RF                 -0.305193                   -0.019032  0.282877
# AdaB               -0.330435                   -0.020553  0.223563
# GBM                -0.296021                   -0.018573  0.304428
#
#       neg_root_mean_squared_error
# Tree                    -0.772091
# Bag                     -0.571912
# ET                      -0.541781
# RF                      -0.552442
# AdaB                    -0.574835
# GBM                     -0.544078

# %%
atom5.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                -0.658140                           -0.229690  -3.000000
# Bag                 -0.504651                           -0.178183  -2.100000
# ET                  -0.488329                           -0.173409  -2.260000
# RF                  -0.491713                           -0.174959  -2.160000
# AdaB                -0.511716                           -0.187631  -2.137584
# GBM                 -0.480825                           -0.171037  -1.976782
#
#       neg_mean_squared_error  neg_mean_squared_log_error        r2  \
# Tree               -0.731783                   -0.046290 -0.508170
# Bag                -0.392764                   -0.024679  0.190533
# ET                 -0.361263                   -0.022809  0.255453
# RF                 -0.365411                   -0.023112  0.246906
# AdaB               -0.389699                   -0.025254  0.196850
# GBM                -0.354992                   -0.022404  0.268378
#
#       neg_root_mean_squared_error
# Tree                    -0.855443
# Bag                     -0.626709
# ET                      -0.601052
# RF                      -0.604492
# AdaB                    -0.624258
# GBM                     -0.595812

# %%
atom6.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                -0.685271                           -0.240170  -2.500000
# Bag                 -0.501240                           -0.180045  -2.100000
# ET                  -0.480178                           -0.172716  -2.055000
# RF                  -0.490341                           -0.176158  -1.960000
# AdaB                -0.504203                           -0.185672  -1.983616
# GBM                 -0.473977                           -0.170295  -2.052750
#
#       neg_mean_squared_error  neg_mean_squared_log_error        r2  \
# Tree               -0.779070                   -0.049389 -0.696822
# Bag                -0.392636                   -0.025233  0.144836
# ET                 -0.353815                   -0.022814  0.229388
# RF                 -0.373452                   -0.024028  0.186619
# AdaB               -0.385367                   -0.025338  0.160667
# GBM                -0.349651                   -0.022567  0.238456
#
#       neg_root_mean_squared_error
# Tree                    -0.882649
# Bag                     -0.626606
# ET                      -0.594823
# RF                      -0.611107
# AdaB                    -0.620779
# GBM                     -0.591313
