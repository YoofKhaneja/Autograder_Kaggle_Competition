# %% [markdown]
# # Trying a pipeline-based approach

# %%
import pandas as pd
import numpy as np

train_data = pd.read_csv("/content/drive/MyDrive/B565 Data/train.csv")
train_data.head()
# Out:
#         text_id                                          full_text  cohesion  \
# 0  0016926B079C  I think that students would benefit from learn...       3.5
# 1  0022683E9EA5  When a problem is a change you have to let it ...       2.5
# 2  00299B378633  Dear, Principal\n\nIf u change the school poli...       3.0
# 3  003885A45F42  The best time in life is when you become yours...       4.5
# 4  0049B1DF5CCC  Small act of kindness can impact in other peop...       2.5
#
#    syntax  vocabulary  phraseology  grammar  conventions
# 0     3.5         3.0          3.0      4.0          3.0
# 1     2.5         3.0          2.0      2.0          2.5
# 2     3.5         3.0          3.0      3.0          2.5
# 3     4.5         4.5          4.5      4.0          5.0
# 4     3.0         3.0          3.0      2.5          2.5

# %%
story = []
for i in train_data['full_text']:
    story.append(i.lower().replace("\n", "").strip())

# %%
story = np.array(story).reshape(-1, 1)
story.shape
# Out:
# (3911, 1)

# %%
cohesion = np.array(train_data['cohesion']).astype(float)
syntax = np.array(train_data['syntax']).astype(float)
vocabulary = np.array(train_data['vocabulary']).astype(float)
phraseology = np.array(train_data['phraseology']).astype(float)
grammar = np.array(train_data['grammar']).astype(float)
conventions = np.array(train_data['conventions']).astype(float)
conventions.shape
# Out:
# (3911,)

# %%
test_data = pd.read_csv("/content/drive/MyDrive/B565 Data/test.csv")
test_data
# Out:
#         text_id                                          full_text
# 0  0000C359D63E  when a person has no experience on a job their...
# 1  000BAD50D026  Do you think students would benefit from being...
# 2  00367BB2546B  Thomas Jefferson once states that "it is wonde...

# %%
story_pred = []
for i in test_data['full_text']:
    story_pred.append(i.lower().replace("\n", "").strip())
story_pred = np.array(story_pred).reshape(-1, 1)

# %%
from atom import ATOMRegressor

atom1 = ATOMRegressor(story, cohesion, test_size = 0.33, random_state = 42, verbose = 2)
atom2 = ATOMRegressor(story, syntax, test_size = 0.33, random_state = 42, verbose = 2)
atom3 = ATOMRegressor(story, vocabulary, test_size = 0.33, random_state = 42, verbose = 2)
atom4 = ATOMRegressor(story, phraseology, test_size = 0.33, random_state = 42, verbose = 2)
atom5 = ATOMRegressor(story, grammar, test_size = 0.33, random_state = 42, verbose = 2)
atom6 = ATOMRegressor(story, conventions, test_size = 0.33, random_state = 42, verbose = 2)
# Out:
# Woodwork may not support Python 3.7 in next non-bugfix release.
# Featuretools may not support Python 3.7 in next non-bugfix release.
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# Outlier values: 6 (0.1%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290
#
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# Outlier values: 23 (0.4%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290
#
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# Outlier values: 1 (0.0%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290
#
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# Outlier values: 8 (0.2%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290
#
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290
#
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# Outlier values: 9 (0.2%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290

# %%
atom1.dataset
# Out:
#                                                  corpus  target
# 0     the great artist michelangelo i thinking he is...     2.0
# 1     one of the things i want to acumplish in the f...     2.5
# 2     its always good to ask people how it feels or ...     3.0
# 3     in order for students to have a good experienc...     3.0
# 4     dear, principal,i will like to star in saying ...     3.5
# ...                                                 ...     ...
# 3906  i think an enjoyable educational activity for ...     4.0
# 3907  some people may say that oppocite but to start...     3.5
# 3908  "unles you try to do somthing beyond what you ...     2.5
# 3909  having activities after school are good ideas ...     4.0
# 3910  explain how small acts of kindness can have a ...     3.5
#
# [3911 rows x 2 columns]

# %%
atom1.textclean()
atom2.textclean()
atom3.textclean()
atom4.textclean()
atom5.textclean()
atom6.textclean()
# Out:
# Cleaning the corpus...
#  --> Decoding unicode characters to ascii.
#  --> Converting text to lower case.
#  --> Dropping 0 emails from 0 documents.
#  --> Dropping 0 URL links from 0 documents.
#  --> Dropping 0 HTML tags from 0 documents.
#  --> Dropping 3 emojis from 3 documents.
#  --> Dropping 2847 numbers from 994 documents.
#  --> Dropping punctuation from the text.
# Cleaning the corpus...
#  --> Decoding unicode characters to ascii.
#  --> Converting text to lower case.
#  --> Dropping 0 emails from 0 documents.
#  --> Dropping 0 URL links from 0 documents.
#  --> Dropping 0 HTML tags from 0 documents.
#  --> Dropping 3 emojis from 3 documents.
#  --> Dropping 2847 numbers from 994 documents.
#  --> Dropping punctuation from the text.
# Cleaning the corpus...
#  --> Decoding unicode characters to ascii.
#  --> Converting text to lower case.
#  --> Dropping 0 emails from 0 documents.
#  --> Dropping 0 URL links from 0 documents.
#  --> Dropping 0 HTML tags from 0 documents.
#  --> Dropping 3 emojis from 3 documents.
#  --> Dropping 2847 numbers from 994 documents.
#  --> Dropping punctuation from the text.
# Cleaning the corpus...
#  --> Decoding unicode characters to ascii.
#  --> Converting text to lower case.
#  --> Dropping 0 emails from 0 documents.
#  --> Dropping 0 URL links from 0 documents.
#  --> Dropping 0 HTML tags from 0 documents.
#  --> Dropping 3 emojis from 3 documents.
#  --> Dropping 2847 numbers from 994 documents.
#  --> Dropping punctuation from the text.
# Cleaning the corpus...
#  --> Decoding unicode characters to ascii.
#  --> Converting text to lower case.
#  --> Dropping 0 emails from 0 documents.
#  --> Dropping 0 URL links from 0 documents.
#  --> Dropping 0 HTML tags from 0 documents.
#  --> Dropping 3 emojis from 3 documents.
#  --> Dropping 2847 numbers from 994 documents.
#  --> Dropping punctuation from the text.
# Cleaning the corpus...
#  --> Decoding unicode characters to ascii.
#  --> Converting text to lower case.
#  --> Dropping 0 emails from 0 documents.
#  --> Dropping 0 URL links from 0 documents.
#  --> Dropping 0 HTML tags from 0 documents.
#  --> Dropping 3 emojis from 3 documents.
#  --> Dropping 2847 numbers from 994 documents.
#  --> Dropping punctuation from the text.

# %%
atom1.tokenize(bigram_freq = 100)
atom2.tokenize(bigram_freq = 100)
atom3.tokenize(bigram_freq = 100)
atom4.tokenize(bigram_freq = 100)
atom5.tokenize(bigram_freq = 100)
atom6.tokenize(bigram_freq = 100)
# Out:
# Tokenizing the corpus...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
#  --> Creating 2215 bigrams on 721393 locations.
# Tokenizing the corpus...
#  --> Creating 2215 bigrams on 721393 locations.
# Tokenizing the corpus...
#  --> Creating 2215 bigrams on 721393 locations.
# Tokenizing the corpus...
#  --> Creating 2215 bigrams on 721393 locations.
# Tokenizing the corpus...
#  --> Creating 2215 bigrams on 721393 locations.
# Tokenizing the corpus...
#  --> Creating 2215 bigrams on 721393 locations.

# %%
atom1.vectorize(strategy = 'tfidf')
atom2.vectorize(strategy = 'tfidf')
atom3.vectorize(strategy = 'tfidf')
atom4.vectorize(strategy = 'tfidf')
atom5.vectorize(strategy = 'tfidf')
atom6.vectorize(strategy = 'tfidf')
# Out:
# Fitting Vectorizer...
# Vectorizing the corpus...
# Fitting Vectorizer...
# Vectorizing the corpus...
# Fitting Vectorizer...
# Vectorizing the corpus...
# Fitting Vectorizer...
# Vectorizing the corpus...
# Fitting Vectorizer...
# Vectorizing the corpus...
# Fitting Vectorizer...
# Vectorizing the corpus...

# %%
atom1.available_models()
# Out:
#    acronym                          fullname                      estimator  \
# 0    Dummy                   Dummy Estimator                 DummyRegressor
# 1       GP                  Gaussian Process       GaussianProcessRegressor
# 2      OLS            Ordinary Least Squares               LinearRegression
# 3    Ridge                   Ridge Estimator                          Ridge
# 4    Lasso                  Lasso Regression                          Lasso
# 5       EN             ElasticNet Regression                     ElasticNet
# 6     Lars            Least Angle Regression                           Lars
# 7       BR                    Bayesian Ridge                  BayesianRidge
# 8      ARD  Automatic Relevant Determination                  ARDRegression
# 9    Huber                  Huber Regression                 HuberRegressor
# 10     KNN               K-Nearest Neighbors            KNeighborsRegressor
# 11     RNN          Radius Nearest Neighbors       RadiusNeighborsRegressor
# 12    Tree                     Decision Tree          DecisionTreeRegressor
# 13     Bag                           Bagging               BaggingRegressor
# 14      ET                       Extra-Trees            ExtraTreesRegressor
# 15      RF                     Random Forest          RandomForestRegressor
# 16    AdaB                          AdaBoost              AdaBoostRegressor
# 17     GBM         Gradient Boosting Machine      GradientBoostingRegressor
# 18    hGBM                           HistGBM  HistGradientBoostingRegressor
# 19     XGB                           XGBoost                   XGBRegressor
# 20     LGB                          LightGBM                  LGBMRegressor
# 21    CatB                          CatBoost              CatBoostRegressor
# 22    lSVM                        Linear SVM                      LinearSVR
# 23    kSVM                        Kernel SVM                            SVR
# 24      PA                Passive Aggressive     PassiveAggressiveRegressor
# 25     SGD       Stochastic Gradient Descent                   SGDRegressor
# 26     MLP            Multi-layer Perceptron                   MLPRegressor
#
#                                                module needs_scaling  \
# 0                                       sklearn.dummy         False
# 1                       sklearn.gaussian_process._gpr         False
# 2                          sklearn.linear_model._base          True
# 3                         sklearn.linear_model._ridge          True
# 4            sklearn.linear_model._coordinate_descent          True
# 5            sklearn.linear_model._coordinate_descent          True
# 6                   sklearn.linear_model._least_angle          True
# 7                         sklearn.linear_model._bayes          True
# 8                         sklearn.linear_model._bayes          True
# 9                         sklearn.linear_model._huber          True
# 10                      sklearn.neighbors._regression          True
# 11                      sklearn.neighbors._regression          True
# 12                              sklearn.tree._classes         False
# 13                          sklearn.ensemble._bagging         False
# 14                           sklearn.ensemble._forest         False
# 15                           sklearn.ensemble._forest         False
# 16                  sklearn.ensemble._weight_boosting         False
# 17                               sklearn.ensemble._gb         False
# 18  sklearn.ensemble._hist_gradient_boosting.gradi...         False
# 19                                    xgboost.sklearn          True
# 20                                   lightgbm.sklearn          True
# 21                                      catboost.core          True
# 22                               sklearn.svm._classes          True
# 23                               sklearn.svm._classes          True
# 24           sklearn.linear_model._passive_aggressive          True
# 25          sklearn.linear_model._stochastic_gradient          True
# 26      sklearn.neural_network._multilayer_perceptron          True
#
#    accepts_sparse supports_gpu
# 0           False        False
# 1           False        False
# 2            True         True
# 3            True         True
# 4            True         True
# 5            True         True
# 6           False         True
# 7           False        False
# 8           False        False
# 9           False        False
# 10           True         True
# 11           True        False
# 12           True        False
# 13           True        False
# 14           True        False
# 15           True         True
# 16           True        False
# 17           True        False
# 18          False        False
# 19           True         True
# 20           True         True
# 21           True         True
# 22           True         True
# 23           True         True
# 24           True        False
# 25           True        False
# 26           True        False

# %%
atom1.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
atom2.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
atom3.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
atom4.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
atom5.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
atom6.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
# Out:
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for Decision Tree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.7118
# Time elapsed: 52.835s
# -------------------------------------------------
# Total time: 52.835s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0696
# Test evaluation --> neg_mean_squared_error: -0.386
# Time elapsed: 1m:15s
# -------------------------------------------------
# Total time: 1m:15s
#
#
# Results for Extra-Trees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.3309
# Time elapsed: 5m:10s
# -------------------------------------------------
# Total time: 5m:10s
#
#
# Results for Random Forest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0483
# Test evaluation --> neg_mean_squared_error: -0.3354
# Time elapsed: 3m:55s
# -------------------------------------------------
# Total time: 3m:55s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.3008
# Test evaluation --> neg_mean_squared_error: -0.3537
# Time elapsed: 59.052s
# -------------------------------------------------
# Total time: 59.052s
#
#
# Results for Gradient Boosting Machine:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.2049
# Test evaluation --> neg_mean_squared_error: -0.3365
# Time elapsed: 1m:14s
# -------------------------------------------------
# Total time: 1m:14s
#
#
# Final results ==================== >>
# Duration: 13m:26s
# -------------------------------------
# Decision Tree             --> neg_mean_squared_error: -0.7118 ~
# Bagging                   --> neg_mean_squared_error: -0.386 ~
# Extra-Trees               --> neg_mean_squared_error: -0.3309 ~ !
# Random Forest             --> neg_mean_squared_error: -0.3354 ~
# AdaBoost                  --> neg_mean_squared_error: -0.3537 ~
# Gradient Boosting Machine --> neg_mean_squared_error: -0.3365 ~
#
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for Decision Tree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.6806
# Time elapsed: 54.434s
# -------------------------------------------------
# Total time: 54.434s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0624
# Test evaluation --> neg_mean_squared_error: -0.3466
# Time elapsed: 1m:09s
# -------------------------------------------------
# Total time: 1m:09s
#
#
# Results for Extra-Trees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.3135
# Time elapsed: 5m:16s
# -------------------------------------------------
# Total time: 5m:16s
#
#
# Results for Random Forest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0454
# Test evaluation --> neg_mean_squared_error: -0.3198
# Time elapsed: 3m:57s
# -------------------------------------------------
# Total time: 3m:57s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.2931
# Test evaluation --> neg_mean_squared_error: -0.3463
# Time elapsed: 59.362s
# -------------------------------------------------
# Total time: 59.362s
#
#
# Results for Gradient Boosting Machine:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.1927
# Test evaluation --> neg_mean_squared_error: -0.3117
# Time elapsed: 1m:08s
# -------------------------------------------------
# Total time: 1m:08s
#
#
# Final results ==================== >>
# Duration: 13m:24s
# -------------------------------------
# Decision Tree             --> neg_mean_squared_error: -0.6806 ~
# Bagging                   --> neg_mean_squared_error: -0.3466 ~
# Extra-Trees               --> neg_mean_squared_error: -0.3135 ~
# Random Forest             --> neg_mean_squared_error: -0.3198 ~
# AdaBoost                  --> neg_mean_squared_error: -0.3463 ~
# Gradient Boosting Machine --> neg_mean_squared_error: -0.3117 ~ !
#
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for Decision Tree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.5382
# Time elapsed: 53.363s
# -------------------------------------------------
# Total time: 53.363s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.052
# Test evaluation --> neg_mean_squared_error: -0.2762
# Time elapsed: 1m:10s
# -------------------------------------------------
# Total time: 1m:10s
#
#
# Results for Extra-Trees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.2499
# Time elapsed: 5m:09s
# -------------------------------------------------
# Total time: 5m:09s
#
#
# Results for Random Forest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0357
# Test evaluation --> neg_mean_squared_error: -0.2542
# Time elapsed: 3m:52s
# -------------------------------------------------
# Total time: 3m:52s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.2186
# Test evaluation --> neg_mean_squared_error: -0.263
# Time elapsed: 58.728s
# -------------------------------------------------
# Total time: 58.729s
#
#
# Results for Gradient Boosting Machine:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.1443
# Test evaluation --> neg_mean_squared_error: -0.2483
# Time elapsed: 1m:08s
# -------------------------------------------------
# Total time: 1m:08s
#
#
# Final results ==================== >>
# Duration: 13m:11s
# -------------------------------------
# Decision Tree             --> neg_mean_squared_error: -0.5382 ~
# Bagging                   --> neg_mean_squared_error: -0.2762 ~
# Extra-Trees               --> neg_mean_squared_error: -0.2499 ~
# Random Forest             --> neg_mean_squared_error: -0.2542 ~
# AdaBoost                  --> neg_mean_squared_error: -0.263 ~
# Gradient Boosting Machine --> neg_mean_squared_error: -0.2483 ~ !
#
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for Decision Tree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.6581
# Time elapsed: 59.630s
# -------------------------------------------------
# Total time: 59.630s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0636
# Test evaluation --> neg_mean_squared_error: -0.3481
# Time elapsed: 1m:08s
# -------------------------------------------------
# Total time: 1m:08s
#
#
# Results for Extra-Trees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.305
# Time elapsed: 5m:12s
# -------------------------------------------------
# Total time: 5m:12s
#
#
# Results for Random Forest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0458
# Test evaluation --> neg_mean_squared_error: -0.3154
# Time elapsed: 3m:52s
# -------------------------------------------------
# Total time: 3m:52s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.2986
# Test evaluation --> neg_mean_squared_error: -0.3371
# Time elapsed: 1m:04s
# -------------------------------------------------
# Total time: 1m:04s
#
#
# Results for Gradient Boosting Machine:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.186
# Test evaluation --> neg_mean_squared_error: -0.3078
# Time elapsed: 1m:09s
# -------------------------------------------------
# Total time: 1m:09s
#
#
# Final results ==================== >>
# Duration: 13m:24s
# -------------------------------------
# Decision Tree             --> neg_mean_squared_error: -0.6581 ~
# Bagging                   --> neg_mean_squared_error: -0.3481 ~
# Extra-Trees               --> neg_mean_squared_error: -0.305 ~ !
# Random Forest             --> neg_mean_squared_error: -0.3154 ~
# AdaBoost                  --> neg_mean_squared_error: -0.3371 ~
# Gradient Boosting Machine --> neg_mean_squared_error: -0.3078 ~
#
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for Decision Tree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.7835
# Time elapsed: 54.752s
# -------------------------------------------------
# Total time: 54.752s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.074
# Test evaluation --> neg_mean_squared_error: -0.3993
# Time elapsed: 1m:10s
# -------------------------------------------------
# Total time: 1m:10s
#
#
# Results for Extra-Trees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.3599
# Time elapsed: 5m:30s
# -------------------------------------------------
# Total time: 5m:30s
#
#
# Results for Random Forest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0532
# Test evaluation --> neg_mean_squared_error: -0.3719
# Time elapsed: 4m:08s
# -------------------------------------------------
# Total time: 4m:08s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.3706
# Test evaluation --> neg_mean_squared_error: -0.4237
# Time elapsed: 1m:01s
# -------------------------------------------------
# Total time: 1m:01s
#
#
# Results for Gradient Boosting Machine:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.2274
# Test evaluation --> neg_mean_squared_error: -0.3723
# Time elapsed: 1m:15s
# -------------------------------------------------
# Total time: 1m:15s
#
#
# Final results ==================== >>
# Duration: 13m:59s
# -------------------------------------
# Decision Tree             --> neg_mean_squared_error: -0.7835 ~
# Bagging                   --> neg_mean_squared_error: -0.3993 ~
# Extra-Trees               --> neg_mean_squared_error: -0.3599 ~ !
# Random Forest             --> neg_mean_squared_error: -0.3719 ~
# AdaBoost                  --> neg_mean_squared_error: -0.4237 ~
# Gradient Boosting Machine --> neg_mean_squared_error: -0.3723 ~
#
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for Decision Tree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.6754
# Time elapsed: 54.797s
# -------------------------------------------------
# Total time: 54.797s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.07
# Test evaluation --> neg_mean_squared_error: -0.4087
# Time elapsed: 1m:12s
# -------------------------------------------------
# Total time: 1m:12s
#
#
# Results for Extra-Trees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.3603
# Time elapsed: 5m:35s
# -------------------------------------------------
# Total time: 5m:35s
#
#
# Results for Random Forest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0512
# Test evaluation --> neg_mean_squared_error: -0.3729
# Time elapsed: 4m:12s
# -------------------------------------------------
# Total time: 4m:12s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.3348
# Test evaluation --> neg_mean_squared_error: -0.395
# Time elapsed: 59.621s
# -------------------------------------------------
# Total time: 59.622s
#
#
# Results for Gradient Boosting Machine:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.2232
# Test evaluation --> neg_mean_squared_error: -0.362
# Time elapsed: 1m:15s
# -------------------------------------------------
# Total time: 1m:15s
#
#
# Final results ==================== >>
# Duration: 14m:08s
# -------------------------------------
# Decision Tree             --> neg_mean_squared_error: -0.6754 ~
# Bagging                   --> neg_mean_squared_error: -0.4087 ~
# Extra-Trees               --> neg_mean_squared_error: -0.3603 ~ !
# Random Forest             --> neg_mean_squared_error: -0.3729 ~
# AdaBoost                  --> neg_mean_squared_error: -0.395 ~
# Gradient Boosting Machine --> neg_mean_squared_error: -0.362 ~

# %%
atom1.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                -0.656977                           -0.226396  -2.500000
# Bag                 -0.499651                           -0.174217  -2.300000
# ET                  -0.463872                           -0.163180  -2.250000
# RF                  -0.468783                           -0.164927  -2.080000
# AdaB                -0.475893                           -0.167095  -2.114493
# GBM                 -0.468966                           -0.164852  -2.069105
#
#       neg_mean_squared_error  neg_mean_squared_log_error        r2  \
# Tree               -0.711822                   -0.044867 -0.658719
# Bag                -0.386041                   -0.024210  0.100431
# ET                 -0.330886                   -0.021015  0.228955
# RF                 -0.335392                   -0.021297  0.218455
# AdaB               -0.353652                   -0.022339  0.175903
# GBM                -0.336470                   -0.021356  0.215942
#
#       neg_root_mean_squared_error
# Tree                    -0.843695
# Bag                     -0.621322
# ET                      -0.575227
# RF                      -0.579130
# AdaB                    -0.594687
# GBM                     -0.580060

# %%
atom2.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                -0.640310                           -0.227309  -3.000000
# Bag                 -0.472171                           -0.170387  -2.050000
# ET                  -0.452283                           -0.164150  -1.915000
# RF                  -0.456841                           -0.165687  -1.940000
# AdaB                -0.476371                           -0.173235  -2.340810
# GBM                 -0.451571                           -0.164613  -1.877838
#
#       neg_mean_squared_error  neg_mean_squared_log_error        r2  \
# Tree               -0.680620                   -0.044389 -0.647397
# Bag                -0.346574                   -0.022654  0.161141
# ET                 -0.313450                   -0.020674  0.241314
# RF                 -0.319832                   -0.021080  0.225867
# AdaB               -0.346345                   -0.022830  0.161695
# GBM                -0.311704                   -0.020732  0.245540
#
#       neg_root_mean_squared_error
# Tree                    -0.824997
# Bag                     -0.588705
# ET                      -0.559866
# RF                      -0.565537
# AdaB                    -0.588510
# GBM                     -0.558305

# %%
atom3.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                -0.544574                           -0.179572  -2.500000
# Bag                 -0.408643                           -0.136116  -2.000000
# ET                  -0.390411                           -0.130455  -1.945000
# RF                  -0.391663                           -0.130765  -1.990000
# AdaB                -0.395676                           -0.132803  -1.850000
# GBM                 -0.384742                           -0.128779  -1.991632
#
#       neg_mean_squared_error  neg_mean_squared_log_error        r2  \
# Tree               -0.538178                   -0.031047 -0.612935
# Bag                -0.276184                   -0.016253  0.172269
# ET                 -0.249912                   -0.014855  0.251006
# RF                 -0.254211                   -0.015082  0.238122
# AdaB               -0.262979                   -0.015583  0.211845
# GBM                -0.248262                   -0.014765  0.255952
#
#       neg_root_mean_squared_error
# Tree                    -0.733606
# Bag                     -0.525532
# ET                      -0.499912
# RF                      -0.504194
# AdaB                    -0.512815
# GBM                     -0.498259

# %%
atom4.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                -0.627132                           -0.215074  -2.500000
# Bag                 -0.485194                           -0.168670  -1.750000
# ET                  -0.450279                           -0.157414  -1.740000
# RF                  -0.457380                           -0.159436  -1.675000
# AdaB                -0.470532                           -0.166456  -1.771645
# GBM                 -0.450711                           -0.157775  -1.676659
#
#       neg_mean_squared_error  neg_mean_squared_log_error        r2  \
# Tree               -0.658140                   -0.041049 -0.546457
# Bag                -0.348112                   -0.021780  0.182026
# ET                 -0.304957                   -0.019194  0.283429
# RF                 -0.315421                   -0.019765  0.258842
# AdaB               -0.337122                   -0.021372  0.207851
# GBM                -0.307828                   -0.019410  0.276684
#
#       neg_root_mean_squared_error
# Tree                    -0.811258
# Bag                     -0.590011
# ET                      -0.552229
# RF                      -0.561624
# AdaB                    -0.580622
# GBM                     -0.554823

# %%
atom5.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                -0.691860                           -0.239286  -3.000000
# Bag                 -0.513566                           -0.182283  -2.150000
# ET                  -0.491539                           -0.175131  -2.085000
# RF                  -0.498194                           -0.177694  -2.045000
# AdaB                -0.531583                           -0.194662  -2.245772
# GBM                 -0.495365                           -0.177314  -2.068565
#
#       neg_mean_squared_error  neg_mean_squared_log_error        r2  \
# Tree               -0.783527                   -0.050449 -0.614812
# Bag                -0.399283                   -0.025263  0.177097
# ET                 -0.359893                   -0.022860  0.258277
# RF                 -0.371855                   -0.023587  0.233625
# AdaB               -0.423681                   -0.027405  0.126813
# GBM                -0.372287                   -0.023708  0.232733
#
#       neg_root_mean_squared_error
# Tree                    -0.885171
# Bag                     -0.631888
# ET                      -0.599911
# RF                      -0.609799
# AdaB                    -0.650908
# GBM                     -0.610154

# %%
atom6.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                -0.635271                           -0.223493  -3.000000
# Bag                 -0.510581                           -0.182965  -2.200000
# ET                  -0.481868                           -0.173277  -2.040000
# RF                  -0.491105                           -0.176780  -2.100000
# AdaB                -0.504676                           -0.185653  -2.111927
# GBM                 -0.486140                           -0.175736  -2.156200
#
#       neg_mean_squared_error  neg_mean_squared_log_error        r2  \
# Tree               -0.675388                   -0.042499 -0.471001
# Bag                -0.408715                   -0.026171  0.109814
# ET                 -0.360290                   -0.023239  0.215286
# RF                 -0.372926                   -0.024036  0.187763
# AdaB               -0.394994                   -0.025911  0.139699
# GBM                -0.362047                   -0.023534  0.211458
#
#       neg_root_mean_squared_error
# Tree                    -0.821820
# Bag                     -0.639308
# ET                      -0.600241
# RF                      -0.610677
# AdaB                    -0.628485
# GBM                     -0.601703
