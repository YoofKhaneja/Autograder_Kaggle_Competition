# %% [markdown]
# # Trying a pipeline-based approach

# %%
import pandas as pd
import numpy as np

train_data = pd.read_csv("/kaggle/input/feedback-prize-english-language-learning/train.csv")
train_data.head()
# Out:
#         text_id                                          full_text  cohesion  \
# 0  0016926B079C  I think that students would benefit from learn...       3.5
# 1  0022683E9EA5  When a problem is a change you have to let it ...       2.5
# 2  00299B378633  Dear, Principal\n\nIf u change the school poli...       3.0
# 3  003885A45F42  The best time in life is when you become yours...       4.5
# 4  0049B1DF5CCC  Small act of kindness can impact in other peop...       2.5
#
#    syntax  vocabulary  phraseology  grammar  conventions
# 0     3.5         3.0          3.0      4.0          3.0
# 1     2.5         3.0          2.0      2.0          2.5
# 2     3.5         3.0          3.0      3.0          2.5
# 3     4.5         4.5          4.5      4.0          5.0
# 4     3.0         3.0          3.0      2.5          2.5

# %%
story = []
for i in train_data['full_text']:
    story.append(i.lower().replace("\n", "").strip())

# %%
story = np.array(story).reshape(-1, 1)
story.shape
# Out:
# (3911, 1)

# %%
cohesion = np.array(train_data['cohesion']).astype(float)
syntax = np.array(train_data['syntax']).astype(float)
vocabulary = np.array(train_data['vocabulary']).astype(float)
phraseology = np.array(train_data['phraseology']).astype(float)
grammar = np.array(train_data['grammar']).astype(float)
conventions = np.array(train_data['conventions']).astype(float)
conventions.shape
# Out:
# (3911,)

# %%
test_data = pd.read_csv("/kaggle/input/feedback-prize-english-language-learning/test.csv")
test_data
# Out:
#         text_id                                          full_text
# 0  0000C359D63E  when a person has no experience on a job their...
# 1  000BAD50D026  Do you think students would benefit from being...
# 2  00367BB2546B  Thomas Jefferson once states that "it is wonde...

# %%
story_pred = []
for i in test_data['full_text']:
    story_pred.append(i.lower().replace("\n", "").strip())
story_pred = np.array(story_pred).reshape(-1, 1)

# %%
from atom import ATOMRegressor

atom1 = ATOMRegressor(story, cohesion, test_size = 0.33, random_state = 42, verbose = 2)
atom2 = ATOMRegressor(story, syntax, test_size = 0.33, random_state = 42, verbose = 2)
atom3 = ATOMRegressor(story, vocabulary, test_size = 0.33, random_state = 42, verbose = 2)
atom4 = ATOMRegressor(story, phraseology, test_size = 0.33, random_state = 42, verbose = 2)
atom5 = ATOMRegressor(story, grammar, test_size = 0.33, random_state = 42, verbose = 2)
atom6 = ATOMRegressor(story, conventions, test_size = 0.33, random_state = 42, verbose = 2)
# Out:
# Woodwork may not support Python 3.7 in next non-bugfix release.
# Featuretools may not support Python 3.7 in next non-bugfix release.
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# Outlier values: 6 (0.1%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290
#
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# Outlier values: 23 (0.4%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290
#
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# Outlier values: 1 (0.0%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290
#
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# Outlier values: 8 (0.2%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290
#
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290
#
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# Outlier values: 9 (0.2%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290

# %%
atom1.dataset
# Out:
#                                                  corpus  target
# 0     the great artist michelangelo i thinking he is...     2.0
# 1     one of the things i want to acumplish in the f...     2.5
# 2     its always good to ask people how it feels or ...     3.0
# 3     in order for students to have a good experienc...     3.0
# 4     dear, principal,i will like to star in saying ...     3.5
# ...                                                 ...     ...
# 3906  i think an enjoyable educational activity for ...     4.0
# 3907  some people may say that oppocite but to start...     3.5
# 3908  "unles you try to do somthing beyond what you ...     2.5
# 3909  having activities after school are good ideas ...     4.0
# 3910  explain how small acts of kindness can have a ...     3.5
#
# [3911 rows x 2 columns]

# %%
atom1.tokenize()
atom2.tokenize()
atom3.tokenize()
atom4.tokenize()
atom5.tokenize()
atom6.tokenize()
# Out:
# Tokenizing the corpus...
# Tokenizing the corpus...
# Tokenizing the corpus...
# Tokenizing the corpus...
# Tokenizing the corpus...
# Tokenizing the corpus...

# %%
atom1.vectorize(strategy = 'tfidf')
atom2.vectorize(strategy = 'tfidf')
atom3.vectorize(strategy = 'tfidf')
atom4.vectorize(strategy = 'tfidf')
atom5.vectorize(strategy = 'tfidf')
atom6.vectorize(strategy = 'tfidf')
# Out:
# Fitting Vectorizer...
# Vectorizing the corpus...
# Fitting Vectorizer...
# Vectorizing the corpus...
# Fitting Vectorizer...
# Vectorizing the corpus...
# Fitting Vectorizer...
# Vectorizing the corpus...
# Fitting Vectorizer...
# Vectorizing the corpus...
# Fitting Vectorizer...
# Vectorizing the corpus...

# %%
atom1.available_models()
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>
#    acronym                          fullname                      estimator  \
# 0    Dummy                   Dummy Estimator                 DummyRegressor
# 1       GP                  Gaussian Process       GaussianProcessRegressor
# 2      OLS            Ordinary Least Squares               LinearRegression
# 3    Ridge                   Ridge Estimator                          Ridge
# 4    Lasso                  Lasso Regression                          Lasso
# 5       EN             ElasticNet Regression                     ElasticNet
# 6     Lars            Least Angle Regression                           Lars
# 7       BR                    Bayesian Ridge                  BayesianRidge
# 8      ARD  Automatic Relevant Determination                  ARDRegression
# 9    Huber                  Huber Regression                 HuberRegressor
# 10     KNN               K-Nearest Neighbors            KNeighborsRegressor
# 11     RNN          Radius Nearest Neighbors       RadiusNeighborsRegressor
# 12    Tree                     Decision Tree          DecisionTreeRegressor
# 13     Bag                           Bagging               BaggingRegressor
# 14      ET                       Extra-Trees            ExtraTreesRegressor
# 15      RF                     Random Forest          RandomForestRegressor
# 16    AdaB                          AdaBoost              AdaBoostRegressor
# 17     GBM         Gradient Boosting Machine      GradientBoostingRegressor
# 18    hGBM                           HistGBM  HistGradientBoostingRegressor
# 19     XGB                           XGBoost                   XGBRegressor
# 20     LGB                          LightGBM                  LGBMRegressor
# 21    CatB                          CatBoost              CatBoostRegressor
# 22    lSVM                        Linear SVM                      LinearSVR
# 23    kSVM                        Kernel SVM                            SVR
# 24      PA                Passive Aggressive     PassiveAggressiveRegressor
# 25     SGD       Stochastic Gradient Descent                   SGDRegressor
# 26     MLP            Multi-layer Perceptron                   MLPRegressor
#
#                                                module needs_scaling  \
# 0                                       sklearn.dummy         False
# 1                       sklearn.gaussian_process._gpr         False
# 2                          sklearn.linear_model._base          True
# 3                         sklearn.linear_model._ridge          True
# 4            sklearn.linear_model._coordinate_descent          True
# 5            sklearn.linear_model._coordinate_descent          True
# 6                   sklearn.linear_model._least_angle          True
# 7                         sklearn.linear_model._bayes          True
# 8                         sklearn.linear_model._bayes          True
# 9                         sklearn.linear_model._huber          True
# 10                      sklearn.neighbors._regression          True
# 11                      sklearn.neighbors._regression          True
# 12                              sklearn.tree._classes         False
# 13                          sklearn.ensemble._bagging         False
# 14                           sklearn.ensemble._forest         False
# 15                           sklearn.ensemble._forest         False
# 16                  sklearn.ensemble._weight_boosting         False
# 17                               sklearn.ensemble._gb         False
# 18  sklearn.ensemble._hist_gradient_boosting.gradi...         False
# 19                                    xgboost.sklearn          True
# 20                                   lightgbm.sklearn          True
# 21                                      catboost.core          True
# 22                               sklearn.svm._classes          True
# 23                               sklearn.svm._classes          True
# 24           sklearn.linear_model._passive_aggressive          True
# 25          sklearn.linear_model._stochastic_gradient          True
# 26      sklearn.neural_network._multilayer_perceptron          True
#
#    accepts_sparse supports_gpu
# 0           False        False
# 1           False        False
# 2            True         True
# 3            True         True
# 4            True         True
# 5            True         True
# 6           False         True
# 7           False        False
# 8           False        False
# 9           False        False
# 10           True         True
# 11           True        False
# 12           True        False
# 13           True        False
# 14           True        False
# 15           True         True
# 16           True        False
# 17           True        False
# 18          False        False
# 19           True         True
# 20           True         True
# 21           True         True
# 22           True         True
# 23           True         True
# 24           True        False
# 25           True        False
# 26           True        False

# %%
atom1.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
atom2.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
atom3.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
atom4.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
atom5.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
atom6.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
# Out:
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for Decision Tree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.6905
# Time elapsed: 34.889s
# -------------------------------------------------
# Total time: 34.889s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0665
# Test evaluation --> neg_mean_squared_error: -0.3724
# Time elapsed: 45.341s
# -------------------------------------------------
# Total time: 45.341s
#
#
# Results for Extra-Trees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.3148
# Time elapsed: 3m:44s
# -------------------------------------------------
# Total time: 3m:44s
#
#
# Results for Random Forest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0473
# Test evaluation --> neg_mean_squared_error: -0.3304
# Time elapsed: 2m:38s
# -------------------------------------------------
# Total time: 2m:38s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.301
# Test evaluation --> neg_mean_squared_error: -0.3358
# Time elapsed: 39.126s
# -------------------------------------------------
# Total time: 39.126s
#
#
# Results for Gradient Boosting Machine:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.1977
# Test evaluation --> neg_mean_squared_error: -0.3162
# Time elapsed: 47.381s
# -------------------------------------------------
# Total time: 47.381s
#
#
# Final results ==================== >>
# Duration: 9m:09s
# -------------------------------------
# Decision Tree             --> neg_mean_squared_error: -0.6905 ~
# Bagging                   --> neg_mean_squared_error: -0.3724 ~
# Extra-Trees               --> neg_mean_squared_error: -0.3148 ~ !
# Random Forest             --> neg_mean_squared_error: -0.3304 ~
# AdaBoost                  --> neg_mean_squared_error: -0.3358 ~
# Gradient Boosting Machine --> neg_mean_squared_error: -0.3162 ~
#
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for Decision Tree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.6444
# Time elapsed: 35.020s
# -------------------------------------------------
# Total time: 35.020s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0609
# Test evaluation --> neg_mean_squared_error: -0.3514
# Time elapsed: 45.749s
# -------------------------------------------------
# Total time: 45.749s
#
#
# Results for Extra-Trees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.304
# Time elapsed: 3m:45s
# -------------------------------------------------
# Total time: 3m:45s
#
#
# Results for Random Forest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0443
# Test evaluation --> neg_mean_squared_error: -0.3204
# Time elapsed: 2m:39s
# -------------------------------------------------
# Total time: 2m:39s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.2734
# Test evaluation --> neg_mean_squared_error: -0.3315
# Time elapsed: 39.408s
# -------------------------------------------------
# Total time: 39.408s
#
#
# Results for Gradient Boosting Machine:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.1871
# Test evaluation --> neg_mean_squared_error: -0.307
# Time elapsed: 46.986s
# -------------------------------------------------
# Total time: 46.986s
#
#
# Final results ==================== >>
# Duration: 9m:11s
# -------------------------------------
# Decision Tree             --> neg_mean_squared_error: -0.6444 ~
# Bagging                   --> neg_mean_squared_error: -0.3514 ~
# Extra-Trees               --> neg_mean_squared_error: -0.304 ~ !
# Random Forest             --> neg_mean_squared_error: -0.3204 ~
# AdaBoost                  --> neg_mean_squared_error: -0.3315 ~
# Gradient Boosting Machine --> neg_mean_squared_error: -0.307 ~
#
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for Decision Tree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.4905
# Time elapsed: 34.371s
# -------------------------------------------------
# Total time: 34.372s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0496
# Test evaluation --> neg_mean_squared_error: -0.2638
# Time elapsed: 44.837s
# -------------------------------------------------
# Total time: 44.837s
#
#
# Results for Extra-Trees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.2439
# Time elapsed: 3m:34s
# -------------------------------------------------
# Total time: 3m:34s
#
#
# Results for Random Forest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0346
# Test evaluation --> neg_mean_squared_error: -0.2513
# Time elapsed: 2m:36s
# -------------------------------------------------
# Total time: 2m:36s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.2083
# Test evaluation --> neg_mean_squared_error: -0.2627
# Time elapsed: 39.841s
# -------------------------------------------------
# Total time: 39.841s
#
#
# Results for Gradient Boosting Machine:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.1402
# Test evaluation --> neg_mean_squared_error: -0.2481
# Time elapsed: 46.948s
# -------------------------------------------------
# Total time: 46.948s
#
#
# Final results ==================== >>
# Duration: 8m:56s
# -------------------------------------
# Decision Tree             --> neg_mean_squared_error: -0.4905 ~
# Bagging                   --> neg_mean_squared_error: -0.2638 ~
# Extra-Trees               --> neg_mean_squared_error: -0.2439 ~ !
# Random Forest             --> neg_mean_squared_error: -0.2513 ~
# AdaBoost                  --> neg_mean_squared_error: -0.2627 ~
# Gradient Boosting Machine --> neg_mean_squared_error: -0.2481 ~
#
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for Decision Tree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.6118
# Time elapsed: 34.044s
# -------------------------------------------------
# Total time: 34.044s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0622
# Test evaluation --> neg_mean_squared_error: -0.3262
# Time elapsed: 45.511s
# -------------------------------------------------
# Total time: 45.511s
#
#
# Results for Extra-Trees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.2958
# Time elapsed: 3m:42s
# -------------------------------------------------
# Total time: 3m:42s
#
#
# Results for Random Forest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0447
# Test evaluation --> neg_mean_squared_error: -0.3026
# Time elapsed: 2m:37s
# -------------------------------------------------
# Total time: 2m:37s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.3079
# Test evaluation --> neg_mean_squared_error: -0.3388
# Time elapsed: 42.049s
# -------------------------------------------------
# Total time: 42.050s
#
#
# Results for Gradient Boosting Machine:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.1876
# Test evaluation --> neg_mean_squared_error: -0.2903
# Time elapsed: 48.098s
# -------------------------------------------------
# Total time: 48.098s
#
#
# Final results ==================== >>
# Duration: 9m:08s
# -------------------------------------
# Decision Tree             --> neg_mean_squared_error: -0.6118 ~
# Bagging                   --> neg_mean_squared_error: -0.3262 ~
# Extra-Trees               --> neg_mean_squared_error: -0.2958 ~
# Random Forest             --> neg_mean_squared_error: -0.3026 ~
# AdaBoost                  --> neg_mean_squared_error: -0.3388 ~
# Gradient Boosting Machine --> neg_mean_squared_error: -0.2903 ~ !
#
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for Decision Tree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.7442
# Time elapsed: 34.006s
# -------------------------------------------------
# Total time: 34.006s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0739
# Test evaluation --> neg_mean_squared_error: -0.3997
# Time elapsed: 45.994s
# -------------------------------------------------
# Total time: 45.994s
#
#
# Results for Extra-Trees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.3515
# Time elapsed: 3m:50s
# -------------------------------------------------
# Total time: 3m:50s
#
#
# Results for Random Forest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0522
# Test evaluation --> neg_mean_squared_error: -0.3605
# Time elapsed: 2m:39s
# -------------------------------------------------
# Total time: 2m:39s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.3511
# Test evaluation --> neg_mean_squared_error: -0.3916
# Time elapsed: 39.674s
# -------------------------------------------------
# Total time: 39.674s
#
#
# Results for Gradient Boosting Machine:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.2174
# Test evaluation --> neg_mean_squared_error: -0.3521
# Time elapsed: 47.073s
# -------------------------------------------------
# Total time: 47.073s
#
#
# Final results ==================== >>
# Duration: 9m:16s
# -------------------------------------
# Decision Tree             --> neg_mean_squared_error: -0.7442 ~
# Bagging                   --> neg_mean_squared_error: -0.3997 ~
# Extra-Trees               --> neg_mean_squared_error: -0.3515 ~ !
# Random Forest             --> neg_mean_squared_error: -0.3605 ~
# AdaBoost                  --> neg_mean_squared_error: -0.3916 ~
# Gradient Boosting Machine --> neg_mean_squared_error: -0.3521 ~
#
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for Decision Tree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.7143
# Time elapsed: 36.179s
# -------------------------------------------------
# Total time: 36.180s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0707
# Test evaluation --> neg_mean_squared_error: -0.3961
# Time elapsed: 46.430s
# -------------------------------------------------
# Total time: 46.431s
#
#
# Results for Extra-Trees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.3497
# Time elapsed: 3m:48s
# -------------------------------------------------
# Total time: 3m:48s
#
#
# Results for Random Forest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0503
# Test evaluation --> neg_mean_squared_error: -0.3654
# Time elapsed: 2m:40s
# -------------------------------------------------
# Total time: 2m:40s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.3226
# Test evaluation --> neg_mean_squared_error: -0.3816
# Time elapsed: 39.469s
# -------------------------------------------------
# Total time: 39.469s
#
#
# Results for Gradient Boosting Machine:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.2107
# Test evaluation --> neg_mean_squared_error: -0.3425
# Time elapsed: 47.020s
# -------------------------------------------------
# Total time: 47.020s
#
#
# Final results ==================== >>
# Duration: 9m:17s
# -------------------------------------
# Decision Tree             --> neg_mean_squared_error: -0.7143 ~
# Bagging                   --> neg_mean_squared_error: -0.3961 ~
# Extra-Trees               --> neg_mean_squared_error: -0.3497 ~
# Random Forest             --> neg_mean_squared_error: -0.3654 ~
# AdaBoost                  --> neg_mean_squared_error: -0.3816 ~
# Gradient Boosting Machine --> neg_mean_squared_error: -0.3425 ~ !

# %%
atom1.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                -0.629070                           -0.217657  -3.000000
# Bag                 -0.491473                           -0.172058  -2.050000
# ET                  -0.454070                           -0.159435  -1.950000
# RF                  -0.462717                           -0.162639  -1.955000
# AdaB                -0.463884                           -0.162245  -1.933438
# GBM                 -0.450396                           -0.157791  -2.021971
#
#       neg_mean_squared_error  neg_mean_squared_log_error        r2  \
# Tree               -0.690504                   -0.043243 -0.609043
# Bag                -0.372403                   -0.023493  0.132210
# ET                 -0.314830                   -0.019958  0.266370
# RF                 -0.330374                   -0.020931  0.230149
# AdaB               -0.335830                   -0.021168  0.217435
# GBM                -0.316166                   -0.019919  0.263256
#
#       neg_root_mean_squared_error
# Tree                    -0.830966
# Bag                     -0.610248
# ET                      -0.561097
# RF                      -0.574781
# AdaB                    -0.579508
# GBM                     -0.562286

# %%
atom2.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                -0.615116                           -0.219130  -2.500000
# Bag                 -0.476163                           -0.171910  -2.100000
# ET                  -0.442915                           -0.160575  -1.995000
# RF                  -0.455880                           -0.164909  -2.040000
# AdaB                -0.463273                           -0.169895  -2.110998
# GBM                 -0.443511                           -0.160930  -1.881220
#
#       neg_mean_squared_error  neg_mean_squared_log_error        r2  \
# Tree               -0.644380                   -0.040990 -0.559680
# Bag                -0.351440                   -0.022910  0.149362
# ET                 -0.304019                   -0.020042  0.264141
# RF                 -0.320382                   -0.021029  0.224537
# AdaB               -0.331550                   -0.021999  0.197505
# GBM                -0.306981                   -0.020276  0.256972
#
#       neg_root_mean_squared_error
# Tree                    -0.802733
# Bag                     -0.592824
# ET                      -0.551379
# RF                      -0.566023
# AdaB                    -0.575804
# GBM                     -0.554059

# %%
atom3.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                -0.532946                           -0.174002  -2.500000
# Bag                 -0.402946                           -0.133461  -1.950000
# ET                  -0.385733                           -0.128135  -1.910000
# RF                  -0.393027                           -0.130382  -1.835000
# AdaB                -0.404015                           -0.135348  -1.856737
# GBM                 -0.388365                           -0.129225  -2.017709
#
#       neg_mean_squared_error  neg_mean_squared_log_error        r2  \
# Tree               -0.490504                   -0.028537 -0.470053
# Bag                -0.263806                   -0.015470  0.209366
# ET                 -0.243917                   -0.014381  0.268973
# RF                 -0.251294                   -0.014768  0.246864
# AdaB               -0.262737                   -0.015498  0.212569
# GBM                -0.248103                   -0.014645  0.256430
#
#       neg_root_mean_squared_error
# Tree                    -0.700360
# Bag                     -0.513621
# ET                      -0.493880
# RF                      -0.501293
# AdaB                    -0.512579
# GBM                     -0.498099

# %%
atom4.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                -0.601938                           -0.204575  -3.000000
# Bag                 -0.465775                           -0.161169  -1.750000
# ET                  -0.443674                           -0.154380  -1.715000
# RF                  -0.448535                           -0.155616  -1.755000
# AdaB                -0.470015                           -0.162839  -1.787571
# GBM                 -0.435305                           -0.151905  -1.720491
#
#       neg_mean_squared_error  neg_mean_squared_log_error        r2  \
# Tree               -0.611822                   -0.037747 -0.437622
# Bag                -0.326157                   -0.020243  0.233616
# ET                 -0.295776                   -0.018511  0.305002
# RF                 -0.302574                   -0.018844  0.289029
# AdaB               -0.338824                   -0.021063  0.203852
# GBM                -0.290251                   -0.018236  0.317985
#
#       neg_root_mean_squared_error
# Tree                    -0.782190
# Bag                     -0.571102
# ET                      -0.543853
# RF                      -0.550067
# AdaB                    -0.582086
# GBM                     -0.538750

# %%
atom5.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                -0.672868                           -0.233109  -2.500000
# Bag                 -0.513256                           -0.182173  -2.200000
# ET                  -0.482132                           -0.170976  -2.140000
# RF                  -0.486167                           -0.172590  -2.085000
# AdaB                -0.510931                           -0.186167  -2.167283
# GBM                 -0.480369                           -0.170856  -2.065322
#
#       neg_mean_squared_error  neg_mean_squared_log_error        r2  \
# Tree               -0.744186                   -0.046867 -0.533732
# Bag                -0.399663                   -0.025154  0.176314
# ET                 -0.351490                   -0.022152  0.275596
# RF                 -0.360533                   -0.022713  0.256959
# AdaB               -0.391608                   -0.025270  0.192915
# GBM                -0.352067                   -0.022263  0.274407
#
#       neg_root_mean_squared_error
# Tree                    -0.862662
# Bag                     -0.632189
# ET                      -0.592866
# RF                      -0.600444
# AdaB                    -0.625786
# GBM                     -0.593352

# %%
atom6.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                -0.651938                           -0.229933  -3.000000
# Bag                 -0.504496                           -0.180131  -2.250000
# ET                  -0.475872                           -0.171290  -2.050000
# RF                  -0.487822                           -0.175607  -2.050000
# AdaB                -0.499622                           -0.183340  -2.090667
# GBM                 -0.472317                           -0.169886  -1.938375
#
#       neg_mean_squared_error  neg_mean_squared_log_error        r2  \
# Tree               -0.714341                   -0.045054 -0.555842
# Bag                -0.396050                   -0.025312  0.137398
# ET                 -0.349744                   -0.022564  0.238254
# RF                 -0.365370                   -0.023590  0.204221
# AdaB               -0.381559                   -0.025036  0.168962
# GBM                -0.342500                   -0.022211  0.254032
#
#       neg_root_mean_squared_error
# Tree                    -0.845187
# Bag                     -0.629325
# ET                      -0.591392
# RF                      -0.604458
# AdaB                    -0.617704
# GBM                     -0.585235
