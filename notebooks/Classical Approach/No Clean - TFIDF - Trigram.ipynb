# %% [markdown]
# # Trying a pipeline-based approach

# %%
import pandas as pd
import numpy as np

train_data = pd.read_csv("/content/drive/MyDrive/B565 Data/train.csv")
train_data.head()
# Out:
#         text_id                                          full_text  cohesion  \
# 0  0016926B079C  I think that students would benefit from learn...       3.5
# 1  0022683E9EA5  When a problem is a change you have to let it ...       2.5
# 2  00299B378633  Dear, Principal\n\nIf u change the school poli...       3.0
# 3  003885A45F42  The best time in life is when you become yours...       4.5
# 4  0049B1DF5CCC  Small act of kindness can impact in other peop...       2.5
#
#    syntax  vocabulary  phraseology  grammar  conventions
# 0     3.5         3.0          3.0      4.0          3.0
# 1     2.5         3.0          2.0      2.0          2.5
# 2     3.5         3.0          3.0      3.0          2.5
# 3     4.5         4.5          4.5      4.0          5.0
# 4     3.0         3.0          3.0      2.5          2.5

# %%
story = []
for i in train_data['full_text']:
    story.append(i.lower().replace("\n", "").strip())

# %%
story = np.array(story).reshape(-1, 1)
story.shape
# Out:
# (3911, 1)

# %%
cohesion = np.array(train_data['cohesion']).astype(float)
syntax = np.array(train_data['syntax']).astype(float)
vocabulary = np.array(train_data['vocabulary']).astype(float)
phraseology = np.array(train_data['phraseology']).astype(float)
grammar = np.array(train_data['grammar']).astype(float)
conventions = np.array(train_data['conventions']).astype(float)
conventions.shape
# Out:
# (3911,)

# %%
test_data = pd.read_csv("/content/drive/MyDrive/B565 Data/test.csv")
test_data
# Out:
#         text_id                                          full_text
# 0  0000C359D63E  when a person has no experience on a job their...
# 1  000BAD50D026  Do you think students would benefit from being...
# 2  00367BB2546B  Thomas Jefferson once states that "it is wonde...

# %%
story_pred = []
for i in test_data['full_text']:
    story_pred.append(i.lower().replace("\n", "").strip())
story_pred = np.array(story_pred).reshape(-1, 1)

# %%
from atom import ATOMRegressor

atom1 = ATOMRegressor(story, cohesion, test_size = 0.33, random_state = 42, verbose = 2)
atom2 = ATOMRegressor(story, syntax, test_size = 0.33, random_state = 42, verbose = 2)
atom3 = ATOMRegressor(story, vocabulary, test_size = 0.33, random_state = 42, verbose = 2)
atom4 = ATOMRegressor(story, phraseology, test_size = 0.33, random_state = 42, verbose = 2)
atom5 = ATOMRegressor(story, grammar, test_size = 0.33, random_state = 42, verbose = 2)
atom6 = ATOMRegressor(story, conventions, test_size = 0.33, random_state = 42, verbose = 2)
# Out:
# Woodwork may not support Python 3.7 in next non-bugfix release.
# Featuretools may not support Python 3.7 in next non-bugfix release.
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# Outlier values: 6 (0.1%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290
#
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# Outlier values: 23 (0.4%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290
#
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# Outlier values: 1 (0.0%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290
#
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# Outlier values: 8 (0.2%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290
#
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290
#
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# Outlier values: 9 (0.2%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290

# %%
atom1.dataset
# Out:
#                                                  corpus  target
# 0     the great artist michelangelo i thinking he is...     2.0
# 1     one of the things i want to acumplish in the f...     2.5
# 2     its always good to ask people how it feels or ...     3.0
# 3     in order for students to have a good experienc...     3.0
# 4     dear, principal,i will like to star in saying ...     3.5
# ...                                                 ...     ...
# 3906  i think an enjoyable educational activity for ...     4.0
# 3907  some people may say that oppocite but to start...     3.5
# 3908  "unles you try to do somthing beyond what you ...     2.5
# 3909  having activities after school are good ideas ...     4.0
# 3910  explain how small acts of kindness can have a ...     3.5
#
# [3911 rows x 2 columns]

# %%
atom1.tokenize(trigram_freq = 100)
atom2.tokenize(trigram_freq = 100)
atom3.tokenize(trigram_freq = 100)
atom4.tokenize(trigram_freq = 100)
atom5.tokenize(trigram_freq = 100)
atom6.tokenize(trigram_freq = 100)
# Out:
# Tokenizing the corpus...
#  --> Creating 836 trigrams on 166162 locations.
# Tokenizing the corpus...
#  --> Creating 836 trigrams on 166162 locations.
# Tokenizing the corpus...
#  --> Creating 836 trigrams on 166162 locations.
# Tokenizing the corpus...
#  --> Creating 836 trigrams on 166162 locations.
# Tokenizing the corpus...
#  --> Creating 836 trigrams on 166162 locations.
# Tokenizing the corpus...
#  --> Creating 836 trigrams on 166162 locations.

# %%
atom1.vectorize(strategy = 'tfidf')
atom2.vectorize(strategy = 'tfidf')
atom3.vectorize(strategy = 'tfidf')
atom4.vectorize(strategy = 'tfidf')
atom5.vectorize(strategy = 'tfidf')
atom6.vectorize(strategy = 'tfidf')
# Out:
# Fitting Vectorizer...
# Vectorizing the corpus...
# Fitting Vectorizer...
# Vectorizing the corpus...
# Fitting Vectorizer...
# Vectorizing the corpus...
# Fitting Vectorizer...
# Vectorizing the corpus...
# Fitting Vectorizer...
# Vectorizing the corpus...
# Fitting Vectorizer...
# Vectorizing the corpus...

# %%
atom1.available_models()
# Out:
#    acronym                          fullname                      estimator  \
# 0    Dummy                   Dummy Estimator                 DummyRegressor
# 1       GP                  Gaussian Process       GaussianProcessRegressor
# 2      OLS            Ordinary Least Squares               LinearRegression
# 3    Ridge                   Ridge Estimator                          Ridge
# 4    Lasso                  Lasso Regression                          Lasso
# 5       EN             ElasticNet Regression                     ElasticNet
# 6     Lars            Least Angle Regression                           Lars
# 7       BR                    Bayesian Ridge                  BayesianRidge
# 8      ARD  Automatic Relevant Determination                  ARDRegression
# 9    Huber                  Huber Regression                 HuberRegressor
# 10     KNN               K-Nearest Neighbors            KNeighborsRegressor
# 11     RNN          Radius Nearest Neighbors       RadiusNeighborsRegressor
# 12    Tree                     Decision Tree          DecisionTreeRegressor
# 13     Bag                           Bagging               BaggingRegressor
# 14      ET                       Extra-Trees            ExtraTreesRegressor
# 15      RF                     Random Forest          RandomForestRegressor
# 16    AdaB                          AdaBoost              AdaBoostRegressor
# 17     GBM         Gradient Boosting Machine      GradientBoostingRegressor
# 18    hGBM                           HistGBM  HistGradientBoostingRegressor
# 19     XGB                           XGBoost                   XGBRegressor
# 20     LGB                          LightGBM                  LGBMRegressor
# 21    CatB                          CatBoost              CatBoostRegressor
# 22    lSVM                        Linear SVM                      LinearSVR
# 23    kSVM                        Kernel SVM                            SVR
# 24      PA                Passive Aggressive     PassiveAggressiveRegressor
# 25     SGD       Stochastic Gradient Descent                   SGDRegressor
# 26     MLP            Multi-layer Perceptron                   MLPRegressor
#
#                                                module needs_scaling  \
# 0                                       sklearn.dummy         False
# 1                       sklearn.gaussian_process._gpr         False
# 2                          sklearn.linear_model._base          True
# 3                         sklearn.linear_model._ridge          True
# 4            sklearn.linear_model._coordinate_descent          True
# 5            sklearn.linear_model._coordinate_descent          True
# 6                   sklearn.linear_model._least_angle          True
# 7                         sklearn.linear_model._bayes          True
# 8                         sklearn.linear_model._bayes          True
# 9                         sklearn.linear_model._huber          True
# 10                      sklearn.neighbors._regression          True
# 11                      sklearn.neighbors._regression          True
# 12                              sklearn.tree._classes         False
# 13                          sklearn.ensemble._bagging         False
# 14                           sklearn.ensemble._forest         False
# 15                           sklearn.ensemble._forest         False
# 16                  sklearn.ensemble._weight_boosting         False
# 17                               sklearn.ensemble._gb         False
# 18  sklearn.ensemble._hist_gradient_boosting.gradi...         False
# 19                                    xgboost.sklearn          True
# 20                                   lightgbm.sklearn          True
# 21                                      catboost.core          True
# 22                               sklearn.svm._classes          True
# 23                               sklearn.svm._classes          True
# 24           sklearn.linear_model._passive_aggressive          True
# 25          sklearn.linear_model._stochastic_gradient          True
# 26      sklearn.neural_network._multilayer_perceptron          True
#
#    accepts_sparse supports_gpu
# 0           False        False
# 1           False        False
# 2            True         True
# 3            True         True
# 4            True         True
# 5            True         True
# 6           False         True
# 7           False        False
# 8           False        False
# 9           False        False
# 10           True         True
# 11           True        False
# 12           True        False
# 13           True        False
# 14           True        False
# 15           True         True
# 16           True        False
# 17           True        False
# 18          False        False
# 19           True         True
# 20           True         True
# 21           True         True
# 22           True         True
# 23           True         True
# 24           True        False
# 25           True        False
# 26           True        False

# %%
atom1.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
atom2.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
atom3.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
atom4.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
atom5.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
atom6.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
# Out:
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for Decision Tree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.6775
# Time elapsed: 36.762s
# -------------------------------------------------
# Total time: 36.762s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0655
# Test evaluation --> neg_mean_squared_error: -0.3614
# Time elapsed: 51.185s
# -------------------------------------------------
# Total time: 51.186s
#
#
# Results for Extra-Trees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.3188
# Time elapsed: 4m:06s
# -------------------------------------------------
# Total time: 4m:06s
#
#
# Results for Random Forest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0477
# Test evaluation --> neg_mean_squared_error: -0.3355
# Time elapsed: 2m:51s
# -------------------------------------------------
# Total time: 2m:51s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.3066
# Test evaluation --> neg_mean_squared_error: -0.3399
# Time elapsed: 41.539s
# -------------------------------------------------
# Total time: 41.539s
#
#
# Results for Gradient Boosting Machine:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.1967
# Test evaluation --> neg_mean_squared_error: -0.3156
# Time elapsed: 56.938s
# -------------------------------------------------
# Total time: 56.939s
#
#
# Final results ==================== >>
# Duration: 10m:04s
# -------------------------------------
# Decision Tree             --> neg_mean_squared_error: -0.6775 ~
# Bagging                   --> neg_mean_squared_error: -0.3614 ~
# Extra-Trees               --> neg_mean_squared_error: -0.3188 ~
# Random Forest             --> neg_mean_squared_error: -0.3355 ~
# AdaBoost                  --> neg_mean_squared_error: -0.3399 ~
# Gradient Boosting Machine --> neg_mean_squared_error: -0.3156 ~ !
#
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for Decision Tree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.6655
# Time elapsed: 36.317s
# -------------------------------------------------
# Total time: 36.317s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0627
# Test evaluation --> neg_mean_squared_error: -0.3462
# Time elapsed: 49.174s
# -------------------------------------------------
# Total time: 49.174s
#
#
# Results for Extra-Trees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.3038
# Time elapsed: 3m:58s
# -------------------------------------------------
# Total time: 3m:58s
#
#
# Results for Random Forest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0447
# Test evaluation --> neg_mean_squared_error: -0.3196
# Time elapsed: 2m:58s
# -------------------------------------------------
# Total time: 2m:58s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.2746
# Test evaluation --> neg_mean_squared_error: -0.3223
# Time elapsed: 41.815s
# -------------------------------------------------
# Total time: 41.815s
#
#
# Results for Gradient Boosting Machine:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.187
# Test evaluation --> neg_mean_squared_error: -0.3069
# Time elapsed: 49.204s
# -------------------------------------------------
# Total time: 49.204s
#
#
# Final results ==================== >>
# Duration: 9m:52s
# -------------------------------------
# Decision Tree             --> neg_mean_squared_error: -0.6655 ~
# Bagging                   --> neg_mean_squared_error: -0.3462 ~
# Extra-Trees               --> neg_mean_squared_error: -0.3038 ~ !
# Random Forest             --> neg_mean_squared_error: -0.3196 ~
# AdaBoost                  --> neg_mean_squared_error: -0.3223 ~
# Gradient Boosting Machine --> neg_mean_squared_error: -0.3069 ~
#
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for Decision Tree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.5238
# Time elapsed: 36.627s
# -------------------------------------------------
# Total time: 36.627s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0504
# Test evaluation --> neg_mean_squared_error: -0.269
# Time elapsed: 54.502s
# -------------------------------------------------
# Total time: 54.502s
#
#
# Results for Extra-Trees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.2429
# Time elapsed: 3m:56s
# -------------------------------------------------
# Total time: 3m:56s
#
#
# Results for Random Forest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0349
# Test evaluation --> neg_mean_squared_error: -0.2507
# Time elapsed: 2m:51s
# -------------------------------------------------
# Total time: 2m:51s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.2047
# Test evaluation --> neg_mean_squared_error: -0.2558
# Time elapsed: 47.053s
# -------------------------------------------------
# Total time: 47.053s
#
#
# Results for Gradient Boosting Machine:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.1426
# Test evaluation --> neg_mean_squared_error: -0.251
# Time elapsed: 48.713s
# -------------------------------------------------
# Total time: 48.713s
#
#
# Final results ==================== >>
# Duration: 9m:54s
# -------------------------------------
# Decision Tree             --> neg_mean_squared_error: -0.5238 ~
# Bagging                   --> neg_mean_squared_error: -0.269 ~
# Extra-Trees               --> neg_mean_squared_error: -0.2429 ~ !
# Random Forest             --> neg_mean_squared_error: -0.2507 ~
# AdaBoost                  --> neg_mean_squared_error: -0.2558 ~
# Gradient Boosting Machine --> neg_mean_squared_error: -0.251 ~
#
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for Decision Tree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.5899
# Time elapsed: 34.977s
# -------------------------------------------------
# Total time: 34.977s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0629
# Test evaluation --> neg_mean_squared_error: -0.3272
# Time elapsed: 47.463s
# -------------------------------------------------
# Total time: 47.463s
#
#
# Results for Extra-Trees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.2963
# Time elapsed: 4m:00s
# -------------------------------------------------
# Total time: 4m:00s
#
#
# Results for Random Forest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0447
# Test evaluation --> neg_mean_squared_error: -0.3076
# Time elapsed: 2m:55s
# -------------------------------------------------
# Total time: 2m:55s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.2974
# Test evaluation --> neg_mean_squared_error: -0.3317
# Time elapsed: 41.251s
# -------------------------------------------------
# Total time: 41.251s
#
#
# Results for Gradient Boosting Machine:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.1889
# Test evaluation --> neg_mean_squared_error: -0.2946
# Time elapsed: 54.096s
# -------------------------------------------------
# Total time: 54.097s
#
#
# Final results ==================== >>
# Duration: 9m:53s
# -------------------------------------
# Decision Tree             --> neg_mean_squared_error: -0.5899 ~
# Bagging                   --> neg_mean_squared_error: -0.3272 ~
# Extra-Trees               --> neg_mean_squared_error: -0.2963 ~
# Random Forest             --> neg_mean_squared_error: -0.3076 ~
# AdaBoost                  --> neg_mean_squared_error: -0.3317 ~
# Gradient Boosting Machine --> neg_mean_squared_error: -0.2946 ~ !
#
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for Decision Tree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.7574
# Time elapsed: 36.019s
# -------------------------------------------------
# Total time: 36.020s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0737
# Test evaluation --> neg_mean_squared_error: -0.3993
# Time elapsed: 49.841s
# -------------------------------------------------
# Total time: 49.842s
#
#
# Results for Extra-Trees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.352
# Time elapsed: 4m:01s
# -------------------------------------------------
# Total time: 4m:01s
#
#
# Results for Random Forest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0526
# Test evaluation --> neg_mean_squared_error: -0.3617
# Time elapsed: 2m:58s
# -------------------------------------------------
# Total time: 2m:58s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.3507
# Test evaluation --> neg_mean_squared_error: -0.3867
# Time elapsed: 42.773s
# -------------------------------------------------
# Total time: 42.773s
#
#
# Results for Gradient Boosting Machine:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.2174
# Test evaluation --> neg_mean_squared_error: -0.3597
# Time elapsed: 50.856s
# -------------------------------------------------
# Total time: 50.856s
#
#
# Final results ==================== >>
# Duration: 9m:58s
# -------------------------------------
# Decision Tree             --> neg_mean_squared_error: -0.7574 ~
# Bagging                   --> neg_mean_squared_error: -0.3993 ~
# Extra-Trees               --> neg_mean_squared_error: -0.352 ~ !
# Random Forest             --> neg_mean_squared_error: -0.3617 ~
# AdaBoost                  --> neg_mean_squared_error: -0.3867 ~
# Gradient Boosting Machine --> neg_mean_squared_error: -0.3597 ~
#
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for Decision Tree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.6692
# Time elapsed: 37.405s
# -------------------------------------------------
# Total time: 37.405s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0741
# Test evaluation --> neg_mean_squared_error: -0.3887
# Time elapsed: 55.443s
# -------------------------------------------------
# Total time: 55.444s
#
#
# Results for Extra-Trees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.3444
# Time elapsed: 4m:13s
# -------------------------------------------------
# Total time: 4m:13s
#
#
# Results for Random Forest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0495
# Test evaluation --> neg_mean_squared_error: -0.3595
# Time elapsed: 2m:52s
# -------------------------------------------------
# Total time: 2m:52s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.3146
# Test evaluation --> neg_mean_squared_error: -0.3778
# Time elapsed: 45.318s
# -------------------------------------------------
# Total time: 45.319s
#
#
# Results for Gradient Boosting Machine:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.2108
# Test evaluation --> neg_mean_squared_error: -0.3444
# Time elapsed: 48.628s
# -------------------------------------------------
# Total time: 48.629s
#
#
# Final results ==================== >>
# Duration: 10m:12s
# -------------------------------------
# Decision Tree             --> neg_mean_squared_error: -0.6692 ~
# Bagging                   --> neg_mean_squared_error: -0.3887 ~
# Extra-Trees               --> neg_mean_squared_error: -0.3444 ~ !
# Random Forest             --> neg_mean_squared_error: -0.3595 ~
# AdaBoost                  --> neg_mean_squared_error: -0.3778 ~
# Gradient Boosting Machine --> neg_mean_squared_error: -0.3444 ~

# %%
atom1.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                -0.635659                           -0.219241  -3.000000
# Bag                 -0.482364                           -0.169237  -2.050000
# ET                  -0.457636                           -0.161069  -2.040000
# RF                  -0.466202                           -0.164027  -2.050000
# AdaB                -0.466538                           -0.163541  -2.055659
# GBM                 -0.451023                           -0.158512  -2.033973
#
#       neg_mean_squared_error  neg_mean_squared_log_error        r2  \
# Tree               -0.677519                   -0.043292 -0.578786
# Bag                -0.361401                   -0.022750  0.157847
# ET                 -0.318787                   -0.020293  0.257148
# RF                 -0.335519                   -0.021278  0.218158
# AdaB               -0.339927                   -0.021504  0.207888
# GBM                -0.315580                   -0.020045  0.264621
#
#       neg_root_mean_squared_error
# Tree                    -0.823116
# Bag                     -0.601167
# ET                      -0.564613
# RF                      -0.579240
# AdaB                    -0.583032
# GBM                     -0.561765

# %%
atom2.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                -0.628682                           -0.224523  -3.000000
# Bag                 -0.470000                           -0.169920  -2.100000
# ET                  -0.442128                           -0.160351  -2.015000
# RF                  -0.452895                           -0.164306  -1.990000
# AdaB                -0.455776                           -0.166676  -2.163462
# GBM                 -0.445247                           -0.161671  -1.937611
#
#       neg_mean_squared_error  neg_mean_squared_log_error        r2  \
# Tree               -0.665504                   -0.043550 -0.610809
# Bag                -0.346221                   -0.022669  0.161995
# ET                 -0.303841                   -0.020049  0.264572
# RF                 -0.319572                   -0.021051  0.226497
# AdaB               -0.322255                   -0.021390  0.220002
# GBM                -0.306890                   -0.020300  0.257192
#
#       neg_root_mean_squared_error
# Tree                    -0.815784
# Bag                     -0.588405
# ET                      -0.551218
# RF                      -0.565307
# AdaB                    -0.567675
# GBM                     -0.553977

# %%
atom3.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                -0.538372                           -0.176263  -2.500000
# Bag                 -0.407713                           -0.135448  -2.000000
# ET                  -0.385163                           -0.128295  -2.105000
# RF                  -0.393047                           -0.130702  -1.965000
# AdaB                -0.397524                           -0.133014  -2.056064
# GBM                 -0.391511                           -0.130423  -2.132153
#
#       neg_mean_squared_error  neg_mean_squared_log_error        r2  \
# Tree               -0.523837                   -0.029994 -0.569954
# Bag                -0.268975                   -0.015834  0.193875
# ET                 -0.242934                   -0.014385  0.271921
# RF                 -0.250674                   -0.014786  0.248722
# AdaB               -0.255808                   -0.015130  0.233336
# GBM                -0.250982                   -0.014826  0.247800
#
#       neg_root_mean_squared_error
# Tree                    -0.723766
# Bag                     -0.518628
# ET                      -0.492883
# RF                      -0.500674
# AdaB                    -0.505775
# GBM                     -0.500981

# %%
atom4.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                -0.589147                           -0.202859  -2.500000
# Bag                 -0.463682                           -0.161394  -2.000000
# ET                  -0.443733                           -0.154970  -1.895000
# RF                  -0.452089                           -0.157657  -1.960000
# AdaB                -0.469664                           -0.163518  -1.785264
# GBM                 -0.440941                           -0.154200  -1.908667
#
#       neg_mean_squared_error  neg_mean_squared_log_error        r2  \
# Tree               -0.589922                   -0.035987 -0.386164
# Bag                -0.327165                   -0.020489  0.231248
# ET                 -0.296294                   -0.018645  0.303786
# RF                 -0.307553                   -0.019305  0.277330
# AdaB               -0.331685                   -0.020754  0.220625
# GBM                -0.294628                   -0.018611  0.307700
#
#       neg_root_mean_squared_error
# Tree                    -0.768064
# Bag                     -0.571983
# ET                      -0.544329
# RF                      -0.554575
# AdaB                    -0.575921
# GBM                     -0.542797

# %%
atom5.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                -0.676744                           -0.235894  -3.000000
# Bag                 -0.509380                           -0.180312  -2.100000
# ET                  -0.483574                           -0.171937  -1.895000
# RF                  -0.491171                           -0.174971  -1.960000
# AdaB                -0.509095                           -0.186697  -2.209302
# GBM                 -0.486350                           -0.173768  -2.071590
#
#       neg_mean_squared_error  neg_mean_squared_log_error        r2  \
# Tree               -0.757364                   -0.047409 -0.560892
# Bag                -0.399333                   -0.025152  0.176993
# ET                 -0.352000                   -0.022297  0.274544
# RF                 -0.361695                   -0.022927  0.254563
# AdaB               -0.386681                   -0.025135  0.203070
# GBM                -0.359684                   -0.022900  0.258708
#
#       neg_root_mean_squared_error
# Tree                    -0.870267
# Bag                     -0.631928
# ET                      -0.593296
# RF                      -0.601411
# AdaB                    -0.621837
# GBM                     -0.599737

# %%
atom6.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                -0.632946                           -0.220231  -3.500000
# Bag                 -0.502209                           -0.179625  -2.200000
# ET                  -0.472860                           -0.170038  -1.960000
# RF                  -0.482961                           -0.173791  -2.100000
# AdaB                -0.498002                           -0.182064  -2.064024
# GBM                 -0.470131                           -0.169913  -1.958751
#
#       neg_mean_squared_error  neg_mean_squared_log_error        r2  \
# Tree               -0.669186                   -0.042892 -0.457494
# Bag                -0.388711                   -0.024910  0.153383
# ET                 -0.344371                   -0.022232  0.249956
# RF                 -0.359533                   -0.023220  0.216934
# AdaB               -0.377827                   -0.024703  0.177089
# GBM                -0.344444                   -0.022393  0.249798
#
#       neg_root_mean_squared_error
# Tree                    -0.818038
# Bag                     -0.623467
# ET                      -0.586832
# RF                      -0.599610
# AdaB                    -0.614676
# GBM                     -0.586893
