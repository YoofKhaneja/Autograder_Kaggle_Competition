# %% [markdown]
# # Trying a pipeline-based approach

# %%
import pandas as pd
import numpy as np

train_data = pd.read_csv("/content/drive/MyDrive/B565 Data/train.csv")
train_data.head()
# Out:
#         text_id                                          full_text  cohesion  \
# 0  0016926B079C  I think that students would benefit from learn...       3.5
# 1  0022683E9EA5  When a problem is a change you have to let it ...       2.5
# 2  00299B378633  Dear, Principal\n\nIf u change the school poli...       3.0
# 3  003885A45F42  The best time in life is when you become yours...       4.5
# 4  0049B1DF5CCC  Small act of kindness can impact in other peop...       2.5
#
#    syntax  vocabulary  phraseology  grammar  conventions
# 0     3.5         3.0          3.0      4.0          3.0
# 1     2.5         3.0          2.0      2.0          2.5
# 2     3.5         3.0          3.0      3.0          2.5
# 3     4.5         4.5          4.5      4.0          5.0
# 4     3.0         3.0          3.0      2.5          2.5

# %%
story = []
for i in train_data['full_text']:
    story.append(i.lower().replace("\n", "").strip())

# %%
story = np.array(story).reshape(-1, 1)
story.shape
# Out:
# (3911, 1)

# %%
cohesion = np.array(train_data['cohesion']).astype(float)
syntax = np.array(train_data['syntax']).astype(float)
vocabulary = np.array(train_data['vocabulary']).astype(float)
phraseology = np.array(train_data['phraseology']).astype(float)
grammar = np.array(train_data['grammar']).astype(float)
conventions = np.array(train_data['conventions']).astype(float)
conventions.shape
# Out:
# (3911,)

# %%
test_data = pd.read_csv("/content/drive/MyDrive/B565 Data/test.csv")
test_data
# Out:
#         text_id                                          full_text
# 0  0000C359D63E  when a person has no experience on a job their...
# 1  000BAD50D026  Do you think students would benefit from being...
# 2  00367BB2546B  Thomas Jefferson once states that "it is wonde...

# %%
story_pred = []
for i in test_data['full_text']:
    story_pred.append(i.lower().replace("\n", "").strip())
story_pred = np.array(story_pred).reshape(-1, 1)

# %%
from atom import ATOMRegressor

atom1 = ATOMRegressor(story, cohesion, test_size = 0.33, random_state = 42, verbose = 2)
atom2 = ATOMRegressor(story, syntax, test_size = 0.33, random_state = 42, verbose = 2)
atom3 = ATOMRegressor(story, vocabulary, test_size = 0.33, random_state = 42, verbose = 2)
atom4 = ATOMRegressor(story, phraseology, test_size = 0.33, random_state = 42, verbose = 2)
atom5 = ATOMRegressor(story, grammar, test_size = 0.33, random_state = 42, verbose = 2)
atom6 = ATOMRegressor(story, conventions, test_size = 0.33, random_state = 42, verbose = 2)
# Out:
# Woodwork may not support Python 3.7 in next non-bugfix release.
# Featuretools may not support Python 3.7 in next non-bugfix release.
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# Outlier values: 6 (0.1%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290
#
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# Outlier values: 23 (0.4%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290
#
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# Outlier values: 1 (0.0%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290
#
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# Outlier values: 8 (0.2%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290
#
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290
#
# << ================== ATOM ================== >>
# Algorithm task: regression.
#
# Dataset stats ==================== >>
# Shape: (3911, 2)
# Memory: 9.21 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# Outlier values: 9 (0.2%)
# -------------------------------------
# Train set size: 2621
# Test set size: 1290

# %%
atom1.dataset
# Out:
#                                                  corpus  target
# 0     the great artist michelangelo i thinking he is...     2.0
# 1     one of the things i want to acumplish in the f...     2.5
# 2     its always good to ask people how it feels or ...     3.0
# 3     in order for students to have a good experienc...     3.0
# 4     dear, principal,i will like to star in saying ...     3.5
# ...                                                 ...     ...
# 3906  i think an enjoyable educational activity for ...     4.0
# 3907  some people may say that oppocite but to start...     3.5
# 3908  "unles you try to do somthing beyond what you ...     2.5
# 3909  having activities after school are good ideas ...     4.0
# 3910  explain how small acts of kindness can have a ...     3.5
#
# [3911 rows x 2 columns]

# %%
atom1.textclean()
atom2.textclean()
atom3.textclean()
atom4.textclean()
atom5.textclean()
atom6.textclean()
# Out:
# Cleaning the corpus...
#  --> Decoding unicode characters to ascii.
#  --> Converting text to lower case.
#  --> Dropping 0 emails from 0 documents.
#  --> Dropping 0 URL links from 0 documents.
#  --> Dropping 0 HTML tags from 0 documents.
#  --> Dropping 3 emojis from 3 documents.
#  --> Dropping 2847 numbers from 994 documents.
#  --> Dropping punctuation from the text.
# Cleaning the corpus...
#  --> Decoding unicode characters to ascii.
#  --> Converting text to lower case.
#  --> Dropping 0 emails from 0 documents.
#  --> Dropping 0 URL links from 0 documents.
#  --> Dropping 0 HTML tags from 0 documents.
#  --> Dropping 3 emojis from 3 documents.
#  --> Dropping 2847 numbers from 994 documents.
#  --> Dropping punctuation from the text.
# Cleaning the corpus...
#  --> Decoding unicode characters to ascii.
#  --> Converting text to lower case.
#  --> Dropping 0 emails from 0 documents.
#  --> Dropping 0 URL links from 0 documents.
#  --> Dropping 0 HTML tags from 0 documents.
#  --> Dropping 3 emojis from 3 documents.
#  --> Dropping 2847 numbers from 994 documents.
#  --> Dropping punctuation from the text.
# Cleaning the corpus...
#  --> Decoding unicode characters to ascii.
#  --> Converting text to lower case.
#  --> Dropping 0 emails from 0 documents.
#  --> Dropping 0 URL links from 0 documents.
#  --> Dropping 0 HTML tags from 0 documents.
#  --> Dropping 3 emojis from 3 documents.
#  --> Dropping 2847 numbers from 994 documents.
#  --> Dropping punctuation from the text.
# Cleaning the corpus...
#  --> Decoding unicode characters to ascii.
#  --> Converting text to lower case.
#  --> Dropping 0 emails from 0 documents.
#  --> Dropping 0 URL links from 0 documents.
#  --> Dropping 0 HTML tags from 0 documents.
#  --> Dropping 3 emojis from 3 documents.
#  --> Dropping 2847 numbers from 994 documents.
#  --> Dropping punctuation from the text.
# Cleaning the corpus...
#  --> Decoding unicode characters to ascii.
#  --> Converting text to lower case.
#  --> Dropping 0 emails from 0 documents.
#  --> Dropping 0 URL links from 0 documents.
#  --> Dropping 0 HTML tags from 0 documents.
#  --> Dropping 3 emojis from 3 documents.
#  --> Dropping 2847 numbers from 994 documents.
#  --> Dropping punctuation from the text.

# %%
atom1.tokenize(trigram_freq = 100)
atom2.tokenize(trigram_freq = 100)
atom3.tokenize(trigram_freq = 100)
atom4.tokenize(trigram_freq = 100)
atom5.tokenize(trigram_freq = 100)
atom6.tokenize(trigram_freq = 100)
# Out:
# Tokenizing the corpus...
#  --> Creating 656 trigrams on 126742 locations.
# Tokenizing the corpus...
#  --> Creating 656 trigrams on 126742 locations.
# Tokenizing the corpus...
#  --> Creating 656 trigrams on 126742 locations.
# Tokenizing the corpus...
#  --> Creating 656 trigrams on 126742 locations.
# Tokenizing the corpus...
#  --> Creating 656 trigrams on 126742 locations.
# Tokenizing the corpus...
#  --> Creating 656 trigrams on 126742 locations.

# %%
atom1.vectorize(strategy = 'tfidf')
atom2.vectorize(strategy = 'tfidf')
atom3.vectorize(strategy = 'tfidf')
atom4.vectorize(strategy = 'tfidf')
atom5.vectorize(strategy = 'tfidf')
atom6.vectorize(strategy = 'tfidf')
# Out:
# Fitting Vectorizer...
# Vectorizing the corpus...
# Fitting Vectorizer...
# Vectorizing the corpus...
# Fitting Vectorizer...
# Vectorizing the corpus...
# Fitting Vectorizer...
# Vectorizing the corpus...
# Fitting Vectorizer...
# Vectorizing the corpus...
# Fitting Vectorizer...
# Vectorizing the corpus...

# %%
atom1.available_models()
# Out:
#    acronym                          fullname                      estimator  \
# 0    Dummy                   Dummy Estimator                 DummyRegressor
# 1       GP                  Gaussian Process       GaussianProcessRegressor
# 2      OLS            Ordinary Least Squares               LinearRegression
# 3    Ridge                   Ridge Estimator                          Ridge
# 4    Lasso                  Lasso Regression                          Lasso
# 5       EN             ElasticNet Regression                     ElasticNet
# 6     Lars            Least Angle Regression                           Lars
# 7       BR                    Bayesian Ridge                  BayesianRidge
# 8      ARD  Automatic Relevant Determination                  ARDRegression
# 9    Huber                  Huber Regression                 HuberRegressor
# 10     KNN               K-Nearest Neighbors            KNeighborsRegressor
# 11     RNN          Radius Nearest Neighbors       RadiusNeighborsRegressor
# 12    Tree                     Decision Tree          DecisionTreeRegressor
# 13     Bag                           Bagging               BaggingRegressor
# 14      ET                       Extra-Trees            ExtraTreesRegressor
# 15      RF                     Random Forest          RandomForestRegressor
# 16    AdaB                          AdaBoost              AdaBoostRegressor
# 17     GBM         Gradient Boosting Machine      GradientBoostingRegressor
# 18    hGBM                           HistGBM  HistGradientBoostingRegressor
# 19     XGB                           XGBoost                   XGBRegressor
# 20     LGB                          LightGBM                  LGBMRegressor
# 21    CatB                          CatBoost              CatBoostRegressor
# 22    lSVM                        Linear SVM                      LinearSVR
# 23    kSVM                        Kernel SVM                            SVR
# 24      PA                Passive Aggressive     PassiveAggressiveRegressor
# 25     SGD       Stochastic Gradient Descent                   SGDRegressor
# 26     MLP            Multi-layer Perceptron                   MLPRegressor
#
#                                                module needs_scaling  \
# 0                                       sklearn.dummy         False
# 1                       sklearn.gaussian_process._gpr         False
# 2                          sklearn.linear_model._base          True
# 3                         sklearn.linear_model._ridge          True
# 4            sklearn.linear_model._coordinate_descent          True
# 5            sklearn.linear_model._coordinate_descent          True
# 6                   sklearn.linear_model._least_angle          True
# 7                         sklearn.linear_model._bayes          True
# 8                         sklearn.linear_model._bayes          True
# 9                         sklearn.linear_model._huber          True
# 10                      sklearn.neighbors._regression          True
# 11                      sklearn.neighbors._regression          True
# 12                              sklearn.tree._classes         False
# 13                          sklearn.ensemble._bagging         False
# 14                           sklearn.ensemble._forest         False
# 15                           sklearn.ensemble._forest         False
# 16                  sklearn.ensemble._weight_boosting         False
# 17                               sklearn.ensemble._gb         False
# 18  sklearn.ensemble._hist_gradient_boosting.gradi...         False
# 19                                    xgboost.sklearn          True
# 20                                   lightgbm.sklearn          True
# 21                                      catboost.core          True
# 22                               sklearn.svm._classes          True
# 23                               sklearn.svm._classes          True
# 24           sklearn.linear_model._passive_aggressive          True
# 25          sklearn.linear_model._stochastic_gradient          True
# 26      sklearn.neural_network._multilayer_perceptron          True
#
#    accepts_sparse supports_gpu
# 0           False        False
# 1           False        False
# 2            True         True
# 3            True         True
# 4            True         True
# 5            True         True
# 6           False         True
# 7           False        False
# 8           False        False
# 9           False        False
# 10           True         True
# 11           True        False
# 12           True        False
# 13           True        False
# 14           True        False
# 15           True         True
# 16           True        False
# 17           True        False
# 18          False        False
# 19           True         True
# 20           True         True
# 21           True         True
# 22           True         True
# 23           True         True
# 24           True        False
# 25           True        False
# 26           True        False

# %%
atom1.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
atom2.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
atom3.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
atom4.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
atom5.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
atom6.run(models = ['Tree', 'Bag', 'ET', 'RF', 'AdaB', 'GBM'], metric = 'mse')
# Out:
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for Decision Tree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.6934
# Time elapsed: 49.444s
# -------------------------------------------------
# Total time: 49.445s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0662
# Test evaluation --> neg_mean_squared_error: -0.3602
# Time elapsed: 1m:02s
# -------------------------------------------------
# Total time: 1m:02s
#
#
# Results for Extra-Trees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.3241
# Time elapsed: 4m:14s
# -------------------------------------------------
# Total time: 4m:14s
#
#
# Results for Random Forest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0482
# Test evaluation --> neg_mean_squared_error: -0.3345
# Time elapsed: 3m:03s
# -------------------------------------------------
# Total time: 3m:03s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.3102
# Test evaluation --> neg_mean_squared_error: -0.3427
# Time elapsed: 55.332s
# -------------------------------------------------
# Total time: 55.332s
#
#
# Results for Gradient Boosting Machine:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.2036
# Test evaluation --> neg_mean_squared_error: -0.327
# Time elapsed: 1m:03s
# -------------------------------------------------
# Total time: 1m:03s
#
#
# Final results ==================== >>
# Duration: 11m:07s
# -------------------------------------
# Decision Tree             --> neg_mean_squared_error: -0.6934 ~
# Bagging                   --> neg_mean_squared_error: -0.3602 ~
# Extra-Trees               --> neg_mean_squared_error: -0.3241 ~ !
# Random Forest             --> neg_mean_squared_error: -0.3345 ~
# AdaBoost                  --> neg_mean_squared_error: -0.3427 ~
# Gradient Boosting Machine --> neg_mean_squared_error: -0.327 ~
#
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for Decision Tree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.6298
# Time elapsed: 49.949s
# -------------------------------------------------
# Total time: 49.950s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0622
# Test evaluation --> neg_mean_squared_error: -0.3533
# Time elapsed: 1m:08s
# -------------------------------------------------
# Total time: 1m:08s
#
#
# Results for Extra-Trees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.3047
# Time elapsed: 4m:20s
# -------------------------------------------------
# Total time: 4m:20s
#
#
# Results for Random Forest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0444
# Test evaluation --> neg_mean_squared_error: -0.3189
# Time elapsed: 3m:10s
# -------------------------------------------------
# Total time: 3m:10s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.2873
# Test evaluation --> neg_mean_squared_error: -0.332
# Time elapsed: 58.075s
# -------------------------------------------------
# Total time: 58.075s
#
#
# Results for Gradient Boosting Machine:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.1856
# Test evaluation --> neg_mean_squared_error: -0.311
# Time elapsed: 1m:03s
# -------------------------------------------------
# Total time: 1m:03s
#
#
# Final results ==================== >>
# Duration: 11m:28s
# -------------------------------------
# Decision Tree             --> neg_mean_squared_error: -0.6298 ~
# Bagging                   --> neg_mean_squared_error: -0.3533 ~
# Extra-Trees               --> neg_mean_squared_error: -0.3047 ~ !
# Random Forest             --> neg_mean_squared_error: -0.3189 ~
# AdaBoost                  --> neg_mean_squared_error: -0.332 ~
# Gradient Boosting Machine --> neg_mean_squared_error: -0.311 ~
#
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for Decision Tree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.5221
# Time elapsed: 49.871s
# -------------------------------------------------
# Total time: 49.871s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0513
# Test evaluation --> neg_mean_squared_error: -0.2734
# Time elapsed: 1m:04s
# -------------------------------------------------
# Total time: 1m:04s
#
#
# Results for Extra-Trees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.2467
# Time elapsed: 4m:06s
# -------------------------------------------------
# Total time: 4m:06s
#
#
# Results for Random Forest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0351
# Test evaluation --> neg_mean_squared_error: -0.2526
# Time elapsed: 3m:08s
# -------------------------------------------------
# Total time: 3m:08s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.2089
# Test evaluation --> neg_mean_squared_error: -0.2643
# Time elapsed: 54.965s
# -------------------------------------------------
# Total time: 54.965s
#
#
# Results for Gradient Boosting Machine:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.143
# Test evaluation --> neg_mean_squared_error: -0.2519
# Time elapsed: 1m:10s
# -------------------------------------------------
# Total time: 1m:10s
#
#
# Final results ==================== >>
# Duration: 11m:12s
# -------------------------------------
# Decision Tree             --> neg_mean_squared_error: -0.5221 ~
# Bagging                   --> neg_mean_squared_error: -0.2734 ~
# Extra-Trees               --> neg_mean_squared_error: -0.2467 ~ !
# Random Forest             --> neg_mean_squared_error: -0.2526 ~
# AdaBoost                  --> neg_mean_squared_error: -0.2643 ~
# Gradient Boosting Machine --> neg_mean_squared_error: -0.2519 ~
#
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for Decision Tree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.613
# Time elapsed: 50.996s
# -------------------------------------------------
# Total time: 50.996s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0655
# Test evaluation --> neg_mean_squared_error: -0.3353
# Time elapsed: 1m:02s
# -------------------------------------------------
# Total time: 1m:02s
#
#
# Results for Extra-Trees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.3009
# Time elapsed: 4m:17s
# -------------------------------------------------
# Total time: 4m:17s
#
#
# Results for Random Forest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0451
# Test evaluation --> neg_mean_squared_error: -0.3083
# Time elapsed: 3m:08s
# -------------------------------------------------
# Total time: 3m:08s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.3025
# Test evaluation --> neg_mean_squared_error: -0.33
# Time elapsed: 55.221s
# -------------------------------------------------
# Total time: 55.221s
#
#
# Results for Gradient Boosting Machine:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.1877
# Test evaluation --> neg_mean_squared_error: -0.3008
# Time elapsed: 1m:06s
# -------------------------------------------------
# Total time: 1m:06s
#
#
# Final results ==================== >>
# Duration: 11m:19s
# -------------------------------------
# Decision Tree             --> neg_mean_squared_error: -0.613 ~
# Bagging                   --> neg_mean_squared_error: -0.3353 ~
# Extra-Trees               --> neg_mean_squared_error: -0.3009 ~
# Random Forest             --> neg_mean_squared_error: -0.3083 ~
# AdaBoost                  --> neg_mean_squared_error: -0.33 ~
# Gradient Boosting Machine --> neg_mean_squared_error: -0.3008 ~ !
#
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for Decision Tree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.7595
# Time elapsed: 50.516s
# -------------------------------------------------
# Total time: 50.516s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0741
# Test evaluation --> neg_mean_squared_error: -0.3995
# Time elapsed: 1m:04s
# -------------------------------------------------
# Total time: 1m:04s
#
#
# Results for Extra-Trees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.3579
# Time elapsed: 4m:29s
# -------------------------------------------------
# Total time: 4m:29s
#
#
# Results for Random Forest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0532
# Test evaluation --> neg_mean_squared_error: -0.3679
# Time elapsed: 3m:14s
# -------------------------------------------------
# Total time: 3m:14s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.3482
# Test evaluation --> neg_mean_squared_error: -0.391
# Time elapsed: 57.151s
# -------------------------------------------------
# Total time: 57.151s
#
#
# Results for Gradient Boosting Machine:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.2228
# Test evaluation --> neg_mean_squared_error: -0.3595
# Time elapsed: 1m:03s
# -------------------------------------------------
# Total time: 1m:03s
#
#
# Final results ==================== >>
# Duration: 11m:37s
# -------------------------------------
# Decision Tree             --> neg_mean_squared_error: -0.7595 ~
# Bagging                   --> neg_mean_squared_error: -0.3995 ~
# Extra-Trees               --> neg_mean_squared_error: -0.3579 ~ !
# Random Forest             --> neg_mean_squared_error: -0.3679 ~
# AdaBoost                  --> neg_mean_squared_error: -0.391 ~
# Gradient Boosting Machine --> neg_mean_squared_error: -0.3595 ~
#
# Training ========================= >>
# Models: Tree, Bag, ET, RF, AdaB, GBM
# Metric: neg_mean_squared_error
#
#
# Results for Decision Tree:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.7859
# Time elapsed: 55.299s
# -------------------------------------------------
# Total time: 55.299s
#
#
# Results for Bagging:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0717
# Test evaluation --> neg_mean_squared_error: -0.3923
# Time elapsed: 1m:04s
# -------------------------------------------------
# Total time: 1m:04s
#
#
# Results for Extra-Trees:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0
# Test evaluation --> neg_mean_squared_error: -0.3536
# Time elapsed: 4m:26s
# -------------------------------------------------
# Total time: 4m:26s
#
#
# Results for Random Forest:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.0504
# Test evaluation --> neg_mean_squared_error: -0.3664
# Time elapsed: 3m:13s
# -------------------------------------------------
# Total time: 3m:13s
#
#
# Results for AdaBoost:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.3339
# Test evaluation --> neg_mean_squared_error: -0.3969
# Time elapsed: 55.763s
# -------------------------------------------------
# Total time: 55.763s
#
#
# Results for Gradient Boosting Machine:
# Fit ---------------------------------------------
# Train evaluation --> neg_mean_squared_error: -0.216
# Test evaluation --> neg_mean_squared_error: -0.3471
# Time elapsed: 1m:04s
# -------------------------------------------------
# Total time: 1m:04s
#
#
# Final results ==================== >>
# Duration: 11m:38s
# -------------------------------------
# Decision Tree             --> neg_mean_squared_error: -0.7859 ~
# Bagging                   --> neg_mean_squared_error: -0.3923 ~
# Extra-Trees               --> neg_mean_squared_error: -0.3536 ~
# Random Forest             --> neg_mean_squared_error: -0.3664 ~
# AdaBoost                  --> neg_mean_squared_error: -0.3969 ~
# Gradient Boosting Machine --> neg_mean_squared_error: -0.3471 ~ !

# %%
atom1.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                -0.637984                           -0.220779  -2.500000
# Bag                 -0.479031                           -0.167406  -2.250000
# ET                  -0.457934                           -0.161382  -2.085000
# RF                  -0.463736                           -0.163659  -2.190000
# AdaB                -0.471271                           -0.164846  -2.019115
# GBM                 -0.459329                           -0.161239  -2.086885
#
#       neg_mean_squared_error  neg_mean_squared_log_error        r2  \
# Tree               -0.693411                   -0.043665 -0.615817
# Bag                -0.360242                   -0.022599  0.160547
# ET                 -0.324134                   -0.020591  0.244689
# RF                 -0.334450                   -0.021275  0.220650
# AdaB               -0.342743                   -0.021675  0.201324
# GBM                -0.327032                   -0.020664  0.237935
#
#       neg_root_mean_squared_error
# Tree                    -0.832713
# Bag                     -0.600202
# ET                      -0.569327
# RF                      -0.578317
# AdaB                    -0.585443
# GBM                     -0.571867

# %%
atom2.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                -0.613953                           -0.217285  -2.500000
# Bag                 -0.474070                           -0.172286  -2.200000
# ET                  -0.443721                           -0.161030  -2.055000
# RF                  -0.452539                           -0.164393  -2.110000
# AdaB                -0.465464                           -0.172347  -2.239726
# GBM                 -0.449288                           -0.163338  -1.931070
#
#       neg_mean_squared_error  neg_mean_squared_log_error        r2  \
# Tree               -0.629845                   -0.040838 -0.524499
# Bag                -0.353324                   -0.023263  0.144803
# ET                 -0.304722                   -0.020123  0.262440
# RF                 -0.318894                   -0.021040  0.228137
# AdaB               -0.331997                   -0.022212  0.196423
# GBM                -0.311048                   -0.020573  0.247127
#
#       neg_root_mean_squared_error
# Tree                    -0.793628
# Bag                     -0.594410
# ET                      -0.552016
# RF                      -0.564707
# AdaB                    -0.576192
# GBM                     -0.557717

# %%
atom3.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                -0.546512                           -0.178510  -3.000000
# Bag                 -0.412636                           -0.136439  -1.900000
# ET                  -0.387589                           -0.129115  -2.135000
# RF                  -0.395818                           -0.131789  -2.010000
# AdaB                -0.408938                           -0.137319  -2.257340
# GBM                 -0.393043                           -0.130820  -2.070104
#
#       neg_mean_squared_error  neg_mean_squared_log_error        r2  \
# Tree               -0.522093                   -0.029671 -0.564727
# Bag                -0.273419                   -0.015997  0.180557
# ET                 -0.246714                   -0.014606  0.260590
# RF                 -0.252621                   -0.014929  0.242889
# AdaB               -0.264302                   -0.015655  0.207879
# GBM                -0.251883                   -0.014857  0.245100
#
#       neg_root_mean_squared_error
# Tree                    -0.722560
# Bag                     -0.522894
# ET                      -0.496704
# RF                      -0.502614
# AdaB                    -0.514103
# GBM                     -0.501879

# %%
atom4.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                -0.597287                           -0.204036  -2.500000
# Bag                 -0.468450                           -0.163319  -1.950000
# ET                  -0.445225                           -0.155720  -1.880000
# RF                  -0.451981                           -0.157866  -1.895000
# AdaB                -0.470635                           -0.164432  -1.766012
# GBM                 -0.445926                           -0.156057  -1.895956
#
#       neg_mean_squared_error  neg_mean_squared_log_error        r2  \
# Tree               -0.612984                   -0.037986 -0.440354
# Bag                -0.335345                   -0.020951  0.212027
# ET                 -0.300871                   -0.018942  0.293031
# RF                 -0.308339                   -0.019374  0.275484
# AdaB               -0.330001                   -0.020715  0.224583
# GBM                -0.300843                   -0.018959  0.293098
#
#       neg_root_mean_squared_error
# Tree                    -0.782933
# Bag                     -0.579090
# ET                      -0.548517
# RF                      -0.555283
# AdaB                    -0.574457
# GBM                     -0.548491

# %%
atom5.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                -0.666279                           -0.232862  -3.000000
# Bag                 -0.511628                           -0.181749  -1.900000
# ET                  -0.488841                           -0.174119  -1.985000
# RF                  -0.494457                           -0.176062  -1.990000
# AdaB                -0.511865                           -0.186979  -2.173225
# GBM                 -0.484290                           -0.172999  -1.974664
#
#       neg_mean_squared_error  neg_mean_squared_log_error        r2  \
# Tree               -0.759496                   -0.047588 -0.565285
# Bag                -0.399535                   -0.025207  0.176578
# ET                 -0.357855                   -0.022673  0.262477
# RF                 -0.367926                   -0.023269  0.241722
# AdaB               -0.391010                   -0.025320  0.194147
# GBM                -0.359455                   -0.022800  0.259181
#
#       neg_root_mean_squared_error
# Tree                    -0.871491
# Bag                     -0.632088
# ET                      -0.598210
# RF                      -0.606569
# AdaB                    -0.625308
# GBM                     -0.599546

# %%
atom6.evaluate()
# Out:
#       neg_mean_absolute_error  neg_mean_absolute_percentage_error  max_error  \
# Tree                -0.687209                           -0.242399  -3.500000
# Bag                 -0.501085                           -0.179308  -2.300000
# ET                  -0.478957                           -0.172323  -2.085000
# RF                  -0.485682                           -0.174968  -1.975000
# AdaB                -0.512989                           -0.189037  -2.166667
# GBM                 -0.471932                           -0.169831  -2.110183
#
#       neg_mean_squared_error  neg_mean_squared_log_error        r2  \
# Tree               -0.785853                   -0.050304 -0.711595
# Bag                -0.392298                   -0.025155  0.145570
# ET                 -0.353561                   -0.022819  0.229941
# RF                 -0.366404                   -0.023694  0.201969
# AdaB               -0.396912                   -0.026050  0.135521
# GBM                -0.347094                   -0.022444  0.244027
#
#       neg_root_mean_squared_error
# Tree                    -0.886483
# Bag                     -0.626337
# ET                      -0.594610
# RF                      -0.605313
# AdaB                    -0.630010
# GBM                     -0.589147
